# %%
from astropy.table import Table
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

# %%
def open_fits(filename: str):
    """"
    Open fits file and load it as a pandas dataframe

    :param filename: location of the fits file

    :returns: data, pandas dataframe
    """
    dat = Table.read(filename, format='fits')
    data = dat.to_pandas()
    return data

# %%
# Creating file paths
folder_path = "../../Data/Fangyou_data/Original/Raw/"
files = os.listdir(folder_path)
file_paths = [folder_path + file for file in files]

# %%
data = []
for file in file_paths:
    dat = open_fits(file)
    data.append(dat)
    print(file, " has ", len(dat), " rows.")
# Out:
# ../../Data/Fangyou_data/Original/Raw/Bootes_sedfit_v1.0.fits  has  19179  rows.
# ../../Data/Fangyou_data/Original/Raw/EN1_sedfit_v1.0.fits  has  31610  rows.
# ../../Data/Fangyou_data/Original/Raw/LH_sedfit_v1.0.fits  has  31162  rows.

# %%
# Finding unique columns across the 3 datasets
all_columns = [list(data[0].columns), list(data[1].columns), list(data[2].columns)]
all_columns = [item for sublist in all_columns for item in sublist]
unique_columns, indexes = np.unique(all_columns, return_index=True)
unique_columns = [all_columns[index] for index in sorted(indexes)]

# Column for filling in all the data about which columns are in which datasets
binary_columns = np.zeros((3,len(unique_columns)))

for i, dat in enumerate(data):
    current_columns = list(dat.columns)
    for j, has_column in enumerate(unique_columns):
        if has_column in current_columns:
            binary_columns[i,j]=1

# %%
# Dataframe containing which columns are in which dataset
has_column_dataframe = pd.DataFrame(binary_columns.T, index=unique_columns, columns=["Bootes", "Elais-N1", "Lockman Hole"])

# %%
has_column_dataframe['Sum'] = has_column_dataframe.sum(axis=1)

# %%
from IPython.display import display
with pd.option_context('display.max_rows', 500):
    display(has_column_dataframe)
# Out:
#                    Bootes  Elais-N1  Lockman Hole  Sum
# Source_Name           1.0       1.0           1.0  3.0
# FLAG_DEEP             1.0       0.0           0.0  1.0
# ID                    1.0       1.0           1.0  3.0
# FLAG_OVERLAP          1.0       1.0           1.0  3.0
# Z_BEST                1.0       1.0           1.0  3.0
# z1_median             1.0       1.0           1.0  3.0
# XID+_rerun_mips       1.0       1.0           1.0  3.0
# XID+_rerun_pacs       1.0       1.0           1.0  3.0
# XID+_rerun_SPIRE      1.0       1.0           1.0  3.0
# CHANGE_FLAG_ID        1.0       1.0           1.0  3.0
# CHANGE_FLAG_ZBEST     1.0       1.0           1.0  3.0
# CHANGE_FLAG_DEEP      1.0       1.0           1.0  3.0
# CHANGE_FLAG_FIR       1.0       1.0           1.0  3.0
# FLAG_GOOD             1.0       1.0           1.0  3.0
# radioID               1.0       1.0           1.0  3.0
# u_f                   1.0       1.0           1.0  3.0
# u_e                   1.0       1.0           1.0  3.0
# u_e_raw               1.0       1.0           1.0  3.0
# Bw_f                  1.0       0.0           0.0  1.0
# Bw_e                  1.0       0.0           0.0  1.0
# Bw_e_raw              1.0       0.0           0.0  1.0
# R_f                   1.0       0.0           0.0  1.0
# R_e                   1.0       0.0           0.0  1.0
# R_e_raw               1.0       0.0           0.0  1.0
# I_f                   1.0       0.0           0.0  1.0
# I_e                   1.0       0.0           0.0  1.0
# I_e_raw               1.0       0.0           0.0  1.0
# z_f                   1.0       1.0           1.0  3.0
# z_e                   1.0       1.0           1.0  3.0
# z_e_raw               1.0       1.0           1.0  3.0
# z_Subaru_f            1.0       0.0           0.0  1.0
# z_Subaru_e            1.0       0.0           0.0  1.0
# z_Subaru_e_raw        1.0       0.0           0.0  1.0
# y_f                   1.0       1.0           0.0  2.0
# y_e                   1.0       1.0           0.0  2.0
# y_e_raw               1.0       1.0           0.0  2.0
# J_f                   1.0       1.0           1.0  3.0
# J_e                   1.0       1.0           1.0  3.0
# J_e_raw               1.0       1.0           1.0  3.0
# H_f                   1.0       0.0           0.0  1.0
# H_e                   1.0       0.0           0.0  1.0
# H_e_raw               1.0       0.0           0.0  1.0
# K_f                   1.0       1.0           1.0  3.0
# K_e                   1.0       1.0           1.0  3.0
# K_e_raw               1.0       1.0           1.0  3.0
# Ks_f                  1.0       0.0           0.0  1.0
# Ks_e                  1.0       0.0           0.0  1.0
# Ks_e_raw              1.0       0.0           0.0  1.0
# ch1_f                 1.0       0.0           0.0  1.0
# ch1_e                 1.0       0.0           0.0  1.0
# ch1_e_raw             1.0       0.0           0.0  1.0
# ch2_f                 1.0       0.0           0.0  1.0
# ch2_e                 1.0       0.0           0.0  1.0
# ch2_e_raw             1.0       0.0           0.0  1.0
# ch3_f                 1.0       0.0           0.0  1.0
# ch3_e                 1.0       0.0           0.0  1.0
# ch3_e_raw             1.0       0.0           0.0  1.0
# ch4_f                 1.0       0.0           0.0  1.0
# ch4_e                 1.0       0.0           0.0  1.0
# ch4_e_raw             1.0       0.0           0.0  1.0
# MIPS_24_f             1.0       1.0           1.0  3.0
# MIPS_24_e             1.0       1.0           1.0  3.0
# MIPS_24_e_raw         1.0       1.0           1.0  3.0
# PACS_100_f            1.0       1.0           1.0  3.0
# PACS_100_e            1.0       1.0           1.0  3.0
# PACS_100_e_raw        1.0       1.0           1.0  3.0
# PACS_160_f            1.0       1.0           1.0  3.0
# PACS_160_e            1.0       1.0           1.0  3.0
# PACS_160_e_raw        1.0       1.0           1.0  3.0
# SPIRE_250_f           1.0       1.0           1.0  3.0
# SPIRE_250_e           1.0       1.0           1.0  3.0
# SPIRE_250_e_raw       1.0       1.0           1.0  3.0
# SPIRE_350_f           1.0       1.0           1.0  3.0
# SPIRE_350_e           1.0       1.0           1.0  3.0
# SPIRE_350_e_raw       1.0       1.0           1.0  3.0
# SPIRE_500_f           1.0       1.0           1.0  3.0
# SPIRE_500_e           1.0       1.0           1.0  3.0
# SPIRE_500_e_raw       1.0       1.0           1.0  3.0
# g_f                   0.0       1.0           1.0  2.0
# g_e                   0.0       1.0           1.0  2.0
# g_e_raw               0.0       1.0           1.0  2.0
# r_f                   0.0       1.0           1.0  2.0
# r_e                   0.0       1.0           1.0  2.0
# r_e_raw               0.0       1.0           1.0  2.0
# i_f                   0.0       1.0           0.0  1.0
# i_e                   0.0       1.0           0.0  1.0
# i_e_raw               0.0       1.0           0.0  1.0
# g_hsc_f               0.0       1.0           0.0  1.0
# g_hsc_e               0.0       1.0           0.0  1.0
# g_hsc_e_raw           0.0       1.0           0.0  1.0
# r_hsc_f               0.0       1.0           0.0  1.0
# r_hsc_e               0.0       1.0           0.0  1.0
# r_hsc_e_raw           0.0       1.0           0.0  1.0
# i_hsc_f               0.0       1.0           0.0  1.0
# i_hsc_e               0.0       1.0           0.0  1.0
# i_hsc_e_raw           0.0       1.0           0.0  1.0
# z_hsc_f               0.0       1.0           0.0  1.0
# z_hsc_e               0.0       1.0           0.0  1.0
# z_hsc_e_raw           0.0       1.0           0.0  1.0
# y_hsc_f               0.0       1.0           0.0  1.0
# y_hsc_e               0.0       1.0           0.0  1.0
# y_hsc_e_raw           0.0       1.0           0.0  1.0
# nb921_hsc_f           0.0       1.0           0.0  1.0
# nb921_hsc_e           0.0       1.0           0.0  1.0
# nb921_hsc_e_raw       0.0       1.0           0.0  1.0
# ch1_swire_f           0.0       1.0           1.0  2.0
# ch1_swire_e           0.0       1.0           1.0  2.0
# ch1_swire_e_raw       0.0       1.0           1.0  2.0
# ch2_swire_f           0.0       1.0           1.0  2.0
# ch2_swire_e           0.0       1.0           1.0  2.0
# ch2_swire_e_raw       0.0       1.0           1.0  2.0
# ch3_swire_f           0.0       1.0           1.0  2.0
# ch3_swire_e           0.0       1.0           1.0  2.0
# ch3_swire_e_raw       0.0       1.0           1.0  2.0
# ch4_swire_f           0.0       1.0           1.0  2.0
# ch4_swire_e           0.0       1.0           1.0  2.0
# ch4_swire_e_raw       0.0       1.0           1.0  2.0
# ch1_servs_f           0.0       1.0           1.0  2.0
# ch1_servs_e           0.0       1.0           1.0  2.0
# ch1_servs_e_raw       0.0       1.0           1.0  2.0
# ch2_servs_f           0.0       1.0           1.0  2.0
# ch2_servs_e           0.0       1.0           1.0  2.0
# ch2_servs_e_raw       0.0       1.0           1.0  2.0
# g_rcs_f               0.0       0.0           1.0  1.0
# g_rcs_e               0.0       0.0           1.0  1.0
# g_rcs_e_raw           0.0       0.0           1.0  1.0
# r_rcs_f               0.0       0.0           1.0  1.0
# r_rcs_e               0.0       0.0           1.0  1.0
# r_rcs_e_raw           0.0       0.0           1.0  1.0
# i_rcs_f               0.0       0.0           1.0  1.0
# i_rcs_e               0.0       0.0           1.0  1.0
# i_rcs_e_raw           0.0       0.0           1.0  1.0
# z_rcs_f               0.0       0.0           1.0  1.0
# z_rcs_e               0.0       0.0           1.0  1.0
# z_rcs_e_raw           0.0       0.0           1.0  1.0

# %%
has_column_dataframe['Sum'].value_counts().plot(kind='bar')

# %%
print("Bootes NaN's per column:\n")

print(data[0].isna().sum().to_string())
# Out:
# Bootes NaN's per column:
#
# Source_Name             0
# FLAG_DEEP             600
# ID                    600
# FLAG_OVERLAP          600
# Z_BEST                916
# z1_median             929
# XID+_rerun_mips         0
# XID+_rerun_pacs         0
# XID+_rerun_SPIRE        0
# CHANGE_FLAG_ID          0
# CHANGE_FLAG_ZBEST       0
# CHANGE_FLAG_DEEP        0
# CHANGE_FLAG_FIR         0
# FLAG_GOOD               0
# radioID                 0
# u_f                  2386
# u_e                  2386
# u_e_raw              2386
# Bw_f                 1246
# Bw_e                 1246
# Bw_e_raw             1239
# R_f                  1100
# R_e                  1100
# R_e_raw              1085
# I_f                   976
# I_e                   976
# I_e_raw               957
# z_f                  5149
# z_e                  5149
# z_e_raw              4917
# z_Subaru_f           2643
# z_Subaru_e           2643
# z_Subaru_e_raw       2112
# y_f                  2414
# y_e                  2414
# y_e_raw              2336
# J_f                  1150
# J_e                  1150
# J_e_raw              1137
# H_f                  1063
# H_e                  1063
# H_e_raw              1044
# K_f                  8353
# K_e                  8353
# K_e_raw              8276
# Ks_f                 1084
# Ks_e                 1084
# Ks_e_raw             1062
# ch1_f                 605
# ch1_e                 605
# ch1_e_raw             600
# ch2_f                 600
# ch2_e                 600
# ch2_e_raw             600
# ch3_f                 642
# ch3_e                 642
# ch3_e_raw             642
# ch4_f                 652
# ch4_e                 652
# ch4_e_raw             652
# MIPS_24_f            1573
# MIPS_24_e            1573
# MIPS_24_e_raw        1573
# PACS_100_f           1048
# PACS_100_e           1048
# PACS_100_e_raw       1048
# PACS_160_f           1048
# PACS_160_e           1048
# PACS_160_e_raw       1048
# SPIRE_250_f           718
# SPIRE_250_e           718
# SPIRE_250_e_raw       718
# SPIRE_350_f           718
# SPIRE_350_e           718
# SPIRE_350_e_raw       718
# SPIRE_500_f           718
# SPIRE_500_e           718
# SPIRE_500_e_raw       718

# %%
print("EN1 NaN's per column:\n")

print(data[1].isna().sum().to_string())
# Out:
# EN1 NaN's per column:
#
# Source_Name              0
# ID                     771
# FLAG_OVERLAP           771
# Z_BEST                1072
# z1_median             1083
# XID+_rerun_mips          0
# XID+_rerun_pacs          0
# XID+_rerun_SPIRE         0
# CHANGE_FLAG_ID           0
# CHANGE_FLAG_ZBEST        0
# CHANGE_FLAG_DEEP         0
# CHANGE_FLAG_FIR          0
# FLAG_GOOD                0
# radioID                  0
# u_f                    828
# u_e                    828
# u_e_raw                828
# g_f                    840
# g_e                    840
# g_e_raw                818
# r_f                    845
# r_e                    845
# r_e_raw                838
# i_f                    789
# i_e                    789
# i_e_raw                789
# z_f                    802
# z_e                    802
# z_e_raw                798
# y_f                    821
# y_e                    821
# y_e_raw                816
# g_hsc_f               2409
# g_hsc_e               2409
# g_hsc_e_raw           2407
# r_hsc_f               2412
# r_hsc_e               2412
# r_hsc_e_raw           2397
# i_hsc_f               2487
# i_hsc_e               2487
# i_hsc_e_raw           2400
# z_hsc_f               2415
# z_hsc_e               2415
# z_hsc_e_raw           2402
# y_hsc_f               2447
# y_hsc_e               2447
# y_hsc_e_raw           2416
# nb921_hsc_f           2600
# nb921_hsc_e           2600
# nb921_hsc_e_raw       2412
# J_f                    834
# J_e                    834
# J_e_raw                826
# K_f                    788
# K_e                    788
# K_e_raw                787
# ch1_swire_f            949
# ch1_swire_e            949
# ch1_swire_e_raw        949
# ch2_swire_f            772
# ch2_swire_e            772
# ch2_swire_e_raw        771
# ch3_swire_f            966
# ch3_swire_e            966
# ch3_swire_e_raw        966
# ch4_swire_f            787
# ch4_swire_e            787
# ch4_swire_e_raw        787
# ch1_servs_f          20015
# ch1_servs_e          20015
# ch1_servs_e_raw      20002
# ch2_servs_f          19842
# ch2_servs_e          19842
# ch2_servs_e_raw      19827
# MIPS_24_f              832
# MIPS_24_e              832
# MIPS_24_e_raw          832
# PACS_100_f              18
# PACS_100_e              18
# PACS_100_e_raw          18
# PACS_160_f              18
# PACS_160_e              18
# PACS_160_e_raw          18
# SPIRE_250_f              0
# SPIRE_250_e              0
# SPIRE_250_e_raw          0
# SPIRE_350_f              0
# SPIRE_350_e              0
# SPIRE_350_e_raw          0
# SPIRE_500_f              0
# SPIRE_500_e              0
# SPIRE_500_e_raw          0

# %%
print("Lockman Hole NaN's per column:\n")

print(data[2].isna().sum().to_string())
# Out:
# Lockman Hole NaN's per column:
#
# Source_Name              0
# ID                     760
# FLAG_OVERLAP           760
# Z_BEST                 955
# z1_median              959
# XID+_rerun_mips          0
# XID+_rerun_pacs          0
# XID+_rerun_SPIRE         0
# CHANGE_FLAG_ID           0
# CHANGE_FLAG_ZBEST        0
# CHANGE_FLAG_DEEP         0
# CHANGE_FLAG_FIR          0
# FLAG_GOOD                0
# radioID                  0
# u_f                   1082
# u_e                   1082
# u_e_raw               1082
# g_f                    813
# g_e                    813
# g_e_raw                813
# r_f                    874
# r_e                    874
# r_e_raw                796
# z_f                   1743
# z_e                   1743
# z_e_raw               1700
# g_rcs_f               3817
# g_rcs_e               3817
# g_rcs_e_raw           3317
# r_rcs_f               3892
# r_rcs_e               3892
# r_rcs_e_raw           3322
# i_rcs_f               3647
# i_rcs_e               3647
# i_rcs_e_raw           3338
# z_rcs_f               3769
# z_rcs_e               3769
# z_rcs_e_raw           3321
# J_f                  10275
# J_e                  10275
# J_e_raw               9611
# K_f                   7323
# K_e                   7323
# K_e_raw               7317
# ch1_swire_f           1292
# ch1_swire_e           1292
# ch1_swire_e_raw       1289
# ch2_swire_f            772
# ch2_swire_e            772
# ch2_swire_e_raw        764
# ch3_swire_f           1297
# ch3_swire_e           1297
# ch3_swire_e_raw       1297
# ch4_swire_f            774
# ch4_swire_e            774
# ch4_swire_e_raw        774
# ch1_servs_f          12988
# ch1_servs_e          12988
# ch1_servs_e_raw      12980
# ch2_servs_f          13616
# ch2_servs_e          13616
# ch2_servs_e_raw      13592
# MIPS_24_f              845
# MIPS_24_e              845
# MIPS_24_e_raw          845
# PACS_100_f               0
# PACS_100_e               0
# PACS_100_e_raw           0
# PACS_160_f               0
# PACS_160_e               0
# PACS_160_e_raw           0
# SPIRE_250_f           3849
# SPIRE_250_e           3849
# SPIRE_250_e_raw       3849
# SPIRE_350_f           3849
# SPIRE_350_e           3849
# SPIRE_350_e_raw       3849
# SPIRE_500_f           3849
# SPIRE_500_e           3849
# SPIRE_500_e_raw       3849

# %%
sns.pairplot(data[0].iloc[:, 15:25])
plt.show()
#fig = swarm_plot.get_figure()
#fig.savefig("./Output/Bootes_pairplot.pdf")

# %%
data[0].hist(figsize = (20,20), bins=50)
plt.tight_layout()
plt.savefig("./Output/histograms_Bootes.pdf")

# %%
data[0].iloc[:, 15:]
