# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder, MinMaxScaler, RobustScaler, MaxAbsScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

from xgboost import XGBClassifier, XGBRegressor
import xgboost as xgb

# %% [markdown]
# # Loading data

# %%
features_num = [
    'Total_flux', 'Peak_flux', 
       'NUV_flux_corr', 'u_flux_corr', 'Bw_flux_corr', 'R_flux_corr',
       'I_flux_corr', 'z_flux_corr', 'y_flux_corr',
       'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr',
       'ch1_flux_corr', 'ch2_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr',
       'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350',
       'F_SPIRE_500', 'Z_BEST', 'r_rcs_flux_corr',
       'g_flux_corr', 'nb921_hsc_flux_corr'
    ]
y_column = "Classification"

classes = ['jet-mode radio AGN/low-excitation radio galaxy', 'quasar-like radio AGN / high-excitation radio galaxy', 
           'radio-quiet AGN', 'star-forming galaxy']

# %%
data = pd.read_csv("../../Data/Fangyou_data/Cleaned/combined_using_similar_columns.csv")

# %%
X = data[features_num]
y = data[np.append(y_column, ['Xray', 'Opt_spec', 'Extended_radio', 'IRAGN'])]

# %%
le = LabelEncoder()
labels = np.unique(y[y_column].astype(str))
y[y_column] = le.fit_transform(y[y_column])
# Out:
# /var/lib/condor/execute/dir_1924914/ipykernel_1979540/2925652128.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y[y_column] = le.fit_transform(y[y_column])

# %%
# Creating training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.75, stratify=y['Classification'], random_state=42)

y_train_flags = y_train[['Xray', 'Opt_spec', 'Extended_radio', 'IRAGN']]
y_test_flags = y_test[['Xray', 'Opt_spec', 'Extended_radio', 'IRAGN']]

y_train = y_train.drop(columns=['Xray', 'Opt_spec', 'Extended_radio', 'IRAGN'])
y_test = y_test.drop(columns=['Xray', 'Opt_spec', 'Extended_radio', 'IRAGN'])

# %% [markdown]
# # SHAP

# %%
model = XGBClassifier(#use_label_encoder=False, 
                      max_depth=10, 
                      #reg_alpha=5,   
                      #min_child_weight=0.5, 
                      reg_lambda=10,
                      #subsample=0.5,
                      eta=0.05, # Remember to reduce to 0.1 or 0.05 for better results
                      tree_method='hist', # exact is more precies, but this is much faster
                      objective='multi:softprob',
                      eval_metric =['merror', 'mlogloss'],
                      nthread=64,
                      n_estimators=700,
                      )

# %%
bst = model.fit(X_train, y_train, 
                eval_set=[
                    (X_train, y_train), 
                    #(X_test, y_test )
                ], 
                #early_stopping_rounds=50,
                verbose=True, 
                #sample_weight=classes_weights,
               ) #
# Out:
# /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/sklearn.py:888: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# /Users/users/karsten/.local/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:98: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# /Users/users/karsten/.local/lib/python3.9/site-packages/sklearn/preprocessing/_label.py:133: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# [0]	validation_0-merror:0.11425	validation_0-mlogloss:1.31451
# [1]	validation_0-merror:0.11061	validation_0-mlogloss:1.24944
# [2]	validation_0-merror:0.10882	validation_0-mlogloss:1.18992
# [3]	validation_0-merror:0.10745	validation_0-mlogloss:1.13511
# [4]	validation_0-merror:0.10521	validation_0-mlogloss:1.08425
# [5]	validation_0-merror:0.10463	validation_0-mlogloss:1.03742
# [6]	validation_0-merror:0.10277	validation_0-mlogloss:0.99386
# [7]	validation_0-merror:0.10198	validation_0-mlogloss:0.95332
# [8]	validation_0-merror:0.10059	validation_0-mlogloss:0.91529
# [9]	validation_0-merror:0.09934	validation_0-mlogloss:0.87967
# [10]	validation_0-merror:0.09813	validation_0-mlogloss:0.84627
# [11]	validation_0-merror:0.09705	validation_0-mlogloss:0.81508
# [12]	validation_0-merror:0.09578	validation_0-mlogloss:0.78553
# [13]	validation_0-merror:0.09463	validation_0-mlogloss:0.75768
# [14]	validation_0-merror:0.09360	validation_0-mlogloss:0.73143
# [15]	validation_0-merror:0.09288	validation_0-mlogloss:0.70669
# [16]	validation_0-merror:0.09234	validation_0-mlogloss:0.68325
# [17]	validation_0-merror:0.09154	validation_0-mlogloss:0.66120
# [18]	validation_0-merror:0.09061	validation_0-mlogloss:0.64018
# [19]	validation_0-merror:0.08980	validation_0-mlogloss:0.62042
# [20]	validation_0-merror:0.08868	validation_0-mlogloss:0.60147
# [21]	validation_0-merror:0.08793	validation_0-mlogloss:0.58351
# [22]	validation_0-merror:0.08705	validation_0-mlogloss:0.56640
# [23]	validation_0-merror:0.08630	validation_0-mlogloss:0.55000
# [24]	validation_0-merror:0.08549	validation_0-mlogloss:0.53447
# [25]	validation_0-merror:0.08485	validation_0-mlogloss:0.51977
# [26]	validation_0-merror:0.08388	validation_0-mlogloss:0.50567
# [27]	validation_0-merror:0.08308	validation_0-mlogloss:0.49217
# [28]	validation_0-merror:0.08259	validation_0-mlogloss:0.47932
# [29]	validation_0-merror:0.08195	validation_0-mlogloss:0.46711
# [30]	validation_0-merror:0.08131	validation_0-mlogloss:0.45539
# [31]	validation_0-merror:0.08039	validation_0-mlogloss:0.44419
# [32]	validation_0-merror:0.07975	validation_0-mlogloss:0.43353
# [33]	validation_0-merror:0.07889	validation_0-mlogloss:0.42333
# [34]	validation_0-merror:0.07848	validation_0-mlogloss:0.41357
# [35]	validation_0-merror:0.07752	validation_0-mlogloss:0.40419
# [36]	validation_0-merror:0.07680	validation_0-mlogloss:0.39517
# [37]	validation_0-merror:0.07613	validation_0-mlogloss:0.38659
# [38]	validation_0-merror:0.07520	validation_0-mlogloss:0.37821
# [39]	validation_0-merror:0.07451	validation_0-mlogloss:0.37021
# [40]	validation_0-merror:0.07369	validation_0-mlogloss:0.36258
# [41]	validation_0-merror:0.07315	validation_0-mlogloss:0.35527
# [42]	validation_0-merror:0.07252	validation_0-mlogloss:0.34824
# [43]	validation_0-merror:0.07197	validation_0-mlogloss:0.34135
# [44]	validation_0-merror:0.07130	validation_0-mlogloss:0.33479
# [45]	validation_0-merror:0.07065	validation_0-mlogloss:0.32843
# [46]	validation_0-merror:0.06992	validation_0-mlogloss:0.32228
# [47]	validation_0-merror:0.06917	validation_0-mlogloss:0.31635
# [48]	validation_0-merror:0.06857	validation_0-mlogloss:0.31058
# [49]	validation_0-merror:0.06800	validation_0-mlogloss:0.30512
# [50]	validation_0-merror:0.06721	validation_0-mlogloss:0.29980
# [51]	validation_0-merror:0.06628	validation_0-mlogloss:0.29467
# [52]	validation_0-merror:0.06561	validation_0-mlogloss:0.28973
# [53]	validation_0-merror:0.06501	validation_0-mlogloss:0.28487
# [54]	validation_0-merror:0.06432	validation_0-mlogloss:0.28022
# [55]	validation_0-merror:0.06388	validation_0-mlogloss:0.27575
# [56]	validation_0-merror:0.06309	validation_0-mlogloss:0.27132
# [57]	validation_0-merror:0.06231	validation_0-mlogloss:0.26721
# [58]	validation_0-merror:0.06166	validation_0-mlogloss:0.26312
# [59]	validation_0-merror:0.06113	validation_0-mlogloss:0.25921
# [60]	validation_0-merror:0.06054	validation_0-mlogloss:0.25537
# [61]	validation_0-merror:0.06003	validation_0-mlogloss:0.25152
# [62]	validation_0-merror:0.05939	validation_0-mlogloss:0.24793
# [63]	validation_0-merror:0.05869	validation_0-mlogloss:0.24439
# [64]	validation_0-merror:0.05824	validation_0-mlogloss:0.24102
# [65]	validation_0-merror:0.05752	validation_0-mlogloss:0.23772
# [66]	validation_0-merror:0.05687	validation_0-mlogloss:0.23446
# [67]	validation_0-merror:0.05627	validation_0-mlogloss:0.23125
# [68]	validation_0-merror:0.05570	validation_0-mlogloss:0.22817
# [69]	validation_0-merror:0.05506	validation_0-mlogloss:0.22518
# [70]	validation_0-merror:0.05446	validation_0-mlogloss:0.22218
# [71]	validation_0-merror:0.05410	validation_0-mlogloss:0.21940
# [72]	validation_0-merror:0.05352	validation_0-mlogloss:0.21662
# [73]	validation_0-merror:0.05300	validation_0-mlogloss:0.21396
# [74]	validation_0-merror:0.05249	validation_0-mlogloss:0.21140
# [75]	validation_0-merror:0.05207	validation_0-mlogloss:0.20896
# [76]	validation_0-merror:0.05149	validation_0-mlogloss:0.20644
# [77]	validation_0-merror:0.05068	validation_0-mlogloss:0.20407
# [78]	validation_0-merror:0.05011	validation_0-mlogloss:0.20171
# [79]	validation_0-merror:0.04962	validation_0-mlogloss:0.19937
# [80]	validation_0-merror:0.04902	validation_0-mlogloss:0.19722
# [81]	validation_0-merror:0.04867	validation_0-mlogloss:0.19511
# [82]	validation_0-merror:0.04811	validation_0-mlogloss:0.19300
# [83]	validation_0-merror:0.04761	validation_0-mlogloss:0.19097
# [84]	validation_0-merror:0.04707	validation_0-mlogloss:0.18903
# [85]	validation_0-merror:0.04663	validation_0-mlogloss:0.18709
# [86]	validation_0-merror:0.04625	validation_0-mlogloss:0.18526
# [87]	validation_0-merror:0.04580	validation_0-mlogloss:0.18337
# [88]	validation_0-merror:0.04525	validation_0-mlogloss:0.18155
# [89]	validation_0-merror:0.04481	validation_0-mlogloss:0.17974
# [90]	validation_0-merror:0.04438	validation_0-mlogloss:0.17794
# [91]	validation_0-merror:0.04390	validation_0-mlogloss:0.17621
# [92]	validation_0-merror:0.04371	validation_0-mlogloss:0.17471
# [93]	validation_0-merror:0.04324	validation_0-mlogloss:0.17321
# [94]	validation_0-merror:0.04285	validation_0-mlogloss:0.17173
# [95]	validation_0-merror:0.04245	validation_0-mlogloss:0.17024
# [96]	validation_0-merror:0.04199	validation_0-mlogloss:0.16866
# [97]	validation_0-merror:0.04165	validation_0-mlogloss:0.16717
# [98]	validation_0-merror:0.04132	validation_0-mlogloss:0.16571
# [99]	validation_0-merror:0.04084	validation_0-mlogloss:0.16426
# [100]	validation_0-merror:0.04039	validation_0-mlogloss:0.16279
# [101]	validation_0-merror:0.03989	validation_0-mlogloss:0.16136
# [102]	validation_0-merror:0.03950	validation_0-mlogloss:0.16013
# [103]	validation_0-merror:0.03929	validation_0-mlogloss:0.15896
# [104]	validation_0-merror:0.03895	validation_0-mlogloss:0.15780
# [105]	validation_0-merror:0.03843	validation_0-mlogloss:0.15658
# [106]	validation_0-merror:0.03793	validation_0-mlogloss:0.15534
# [107]	validation_0-merror:0.03759	validation_0-mlogloss:0.15410
# [108]	validation_0-merror:0.03732	validation_0-mlogloss:0.15302
# [109]	validation_0-merror:0.03690	validation_0-mlogloss:0.15175
# [110]	validation_0-merror:0.03659	validation_0-mlogloss:0.15071
# [111]	validation_0-merror:0.03644	validation_0-mlogloss:0.14963
# [112]	validation_0-merror:0.03608	validation_0-mlogloss:0.14855
# [113]	validation_0-merror:0.03574	validation_0-mlogloss:0.14749
# [114]	validation_0-merror:0.03548	validation_0-mlogloss:0.14654
# [115]	validation_0-merror:0.03512	validation_0-mlogloss:0.14547
# [116]	validation_0-merror:0.03474	validation_0-mlogloss:0.14442
# [117]	validation_0-merror:0.03455	validation_0-mlogloss:0.14343
# [118]	validation_0-merror:0.03434	validation_0-mlogloss:0.14252
# [119]	validation_0-merror:0.03407	validation_0-mlogloss:0.14154
# [120]	validation_0-merror:0.03386	validation_0-mlogloss:0.14071
# [121]	validation_0-merror:0.03374	validation_0-mlogloss:0.13977
# [122]	validation_0-merror:0.03354	validation_0-mlogloss:0.13887
# [123]	validation_0-merror:0.03343	validation_0-mlogloss:0.13803
# [124]	validation_0-merror:0.03319	validation_0-mlogloss:0.13724
# [125]	validation_0-merror:0.03288	validation_0-mlogloss:0.13638
# [126]	validation_0-merror:0.03252	validation_0-mlogloss:0.13544
# [127]	validation_0-merror:0.03225	validation_0-mlogloss:0.13468
# [128]	validation_0-merror:0.03197	validation_0-mlogloss:0.13387
# [129]	validation_0-merror:0.03168	validation_0-mlogloss:0.13312
# [130]	validation_0-merror:0.03153	validation_0-mlogloss:0.13236
# [131]	validation_0-merror:0.03130	validation_0-mlogloss:0.13168
# [132]	validation_0-merror:0.03096	validation_0-mlogloss:0.13089
# [133]	validation_0-merror:0.03074	validation_0-mlogloss:0.13020
# [134]	validation_0-merror:0.03046	validation_0-mlogloss:0.12942
# [135]	validation_0-merror:0.03036	validation_0-mlogloss:0.12882
# [136]	validation_0-merror:0.03008	validation_0-mlogloss:0.12813
# [137]	validation_0-merror:0.02986	validation_0-mlogloss:0.12742
# [138]	validation_0-merror:0.02967	validation_0-mlogloss:0.12668
# [139]	validation_0-merror:0.02926	validation_0-mlogloss:0.12603
# [140]	validation_0-merror:0.02912	validation_0-mlogloss:0.12541
# [141]	validation_0-merror:0.02881	validation_0-mlogloss:0.12458
# [142]	validation_0-merror:0.02850	validation_0-mlogloss:0.12387
# [143]	validation_0-merror:0.02824	validation_0-mlogloss:0.12331
# [144]	validation_0-merror:0.02802	validation_0-mlogloss:0.12266
# [145]	validation_0-merror:0.02768	validation_0-mlogloss:0.12198
# [146]	validation_0-merror:0.02745	validation_0-mlogloss:0.12143
# [147]	validation_0-merror:0.02725	validation_0-mlogloss:0.12065
# [148]	validation_0-merror:0.02694	validation_0-mlogloss:0.11994
# [149]	validation_0-merror:0.02658	validation_0-mlogloss:0.11928
# [150]	validation_0-merror:0.02634	validation_0-mlogloss:0.11874
# [151]	validation_0-merror:0.02620	validation_0-mlogloss:0.11814
# [152]	validation_0-merror:0.02611	validation_0-mlogloss:0.11757
# [153]	validation_0-merror:0.02586	validation_0-mlogloss:0.11705
# [154]	validation_0-merror:0.02570	validation_0-mlogloss:0.11647
# [155]	validation_0-merror:0.02546	validation_0-mlogloss:0.11584
# [156]	validation_0-merror:0.02532	validation_0-mlogloss:0.11522
# [157]	validation_0-merror:0.02512	validation_0-mlogloss:0.11468
# [158]	validation_0-merror:0.02489	validation_0-mlogloss:0.11417
# [159]	validation_0-merror:0.02471	validation_0-mlogloss:0.11364
# [160]	validation_0-merror:0.02462	validation_0-mlogloss:0.11314
# [161]	validation_0-merror:0.02447	validation_0-mlogloss:0.11267
# [162]	validation_0-merror:0.02433	validation_0-mlogloss:0.11225
# [163]	validation_0-merror:0.02416	validation_0-mlogloss:0.11171
# [164]	validation_0-merror:0.02404	validation_0-mlogloss:0.11129
# [165]	validation_0-merror:0.02386	validation_0-mlogloss:0.11082
# [166]	validation_0-merror:0.02364	validation_0-mlogloss:0.11031
# [167]	validation_0-merror:0.02352	validation_0-mlogloss:0.10978
# [168]	validation_0-merror:0.02331	validation_0-mlogloss:0.10930
# [169]	validation_0-merror:0.02311	validation_0-mlogloss:0.10880
# [170]	validation_0-merror:0.02299	validation_0-mlogloss:0.10826
# [171]	validation_0-merror:0.02285	validation_0-mlogloss:0.10782
# [172]	validation_0-merror:0.02273	validation_0-mlogloss:0.10739
# [173]	validation_0-merror:0.02264	validation_0-mlogloss:0.10695
# [174]	validation_0-merror:0.02247	validation_0-mlogloss:0.10651
# [175]	validation_0-merror:0.02221	validation_0-mlogloss:0.10603
# [176]	validation_0-merror:0.02201	validation_0-mlogloss:0.10548
# [177]	validation_0-merror:0.02191	validation_0-mlogloss:0.10509
# [178]	validation_0-merror:0.02172	validation_0-mlogloss:0.10467
# [179]	validation_0-merror:0.02166	validation_0-mlogloss:0.10429
# [180]	validation_0-merror:0.02144	validation_0-mlogloss:0.10388
# [181]	validation_0-merror:0.02132	validation_0-mlogloss:0.10347
# [182]	validation_0-merror:0.02117	validation_0-mlogloss:0.10313
# [183]	validation_0-merror:0.02093	validation_0-mlogloss:0.10272
# [184]	validation_0-merror:0.02081	validation_0-mlogloss:0.10231
# [185]	validation_0-merror:0.02065	validation_0-mlogloss:0.10190
# [186]	validation_0-merror:0.02053	validation_0-mlogloss:0.10147
# [187]	validation_0-merror:0.02048	validation_0-mlogloss:0.10108
# [188]	validation_0-merror:0.02027	validation_0-mlogloss:0.10068
# [189]	validation_0-merror:0.02014	validation_0-mlogloss:0.10030
# [190]	validation_0-merror:0.02005	validation_0-mlogloss:0.09995
# [191]	validation_0-merror:0.01984	validation_0-mlogloss:0.09950
# [192]	validation_0-merror:0.01971	validation_0-mlogloss:0.09914
# [193]	validation_0-merror:0.01955	validation_0-mlogloss:0.09873
# [194]	validation_0-merror:0.01945	validation_0-mlogloss:0.09839
# [195]	validation_0-merror:0.01933	validation_0-mlogloss:0.09796
# [196]	validation_0-merror:0.01912	validation_0-mlogloss:0.09754
# [197]	validation_0-merror:0.01905	validation_0-mlogloss:0.09715
# [198]	validation_0-merror:0.01890	validation_0-mlogloss:0.09681
# [199]	validation_0-merror:0.01876	validation_0-mlogloss:0.09644
# [200]	validation_0-merror:0.01864	validation_0-mlogloss:0.09604
# [201]	validation_0-merror:0.01837	validation_0-mlogloss:0.09561
# [202]	validation_0-merror:0.01821	validation_0-mlogloss:0.09523
# [203]	validation_0-merror:0.01814	validation_0-mlogloss:0.09490
# [204]	validation_0-merror:0.01795	validation_0-mlogloss:0.09454
# [205]	validation_0-merror:0.01775	validation_0-mlogloss:0.09416
# [206]	validation_0-merror:0.01766	validation_0-mlogloss:0.09388
# [207]	validation_0-merror:0.01751	validation_0-mlogloss:0.09356
# [208]	validation_0-merror:0.01744	validation_0-mlogloss:0.09322
# [209]	validation_0-merror:0.01732	validation_0-mlogloss:0.09289
# [210]	validation_0-merror:0.01718	validation_0-mlogloss:0.09253
# [211]	validation_0-merror:0.01699	validation_0-mlogloss:0.09227
# [212]	validation_0-merror:0.01687	validation_0-mlogloss:0.09191
# [213]	validation_0-merror:0.01668	validation_0-mlogloss:0.09147
# [214]	validation_0-merror:0.01663	validation_0-mlogloss:0.09116
# [215]	validation_0-merror:0.01651	validation_0-mlogloss:0.09070
# [216]	validation_0-merror:0.01634	validation_0-mlogloss:0.09034
# [217]	validation_0-merror:0.01620	validation_0-mlogloss:0.09003
# [218]	validation_0-merror:0.01613	validation_0-mlogloss:0.08975
# [219]	validation_0-merror:0.01593	validation_0-mlogloss:0.08946
# [220]	validation_0-merror:0.01575	validation_0-mlogloss:0.08914
# [221]	validation_0-merror:0.01567	validation_0-mlogloss:0.08879
# [222]	validation_0-merror:0.01557	validation_0-mlogloss:0.08849
# [223]	validation_0-merror:0.01538	validation_0-mlogloss:0.08816
# [224]	validation_0-merror:0.01527	validation_0-mlogloss:0.08775
# [225]	validation_0-merror:0.01520	validation_0-mlogloss:0.08746
# [226]	validation_0-merror:0.01496	validation_0-mlogloss:0.08713
# [227]	validation_0-merror:0.01486	validation_0-mlogloss:0.08686
# [228]	validation_0-merror:0.01481	validation_0-mlogloss:0.08643
# [229]	validation_0-merror:0.01465	validation_0-mlogloss:0.08611
# [230]	validation_0-merror:0.01457	validation_0-mlogloss:0.08582
# [231]	validation_0-merror:0.01448	validation_0-mlogloss:0.08555
# [232]	validation_0-merror:0.01440	validation_0-mlogloss:0.08526
# [233]	validation_0-merror:0.01422	validation_0-mlogloss:0.08494
# [234]	validation_0-merror:0.01409	validation_0-mlogloss:0.08469
# [235]	validation_0-merror:0.01392	validation_0-mlogloss:0.08446
# [236]	validation_0-merror:0.01392	validation_0-mlogloss:0.08408
# [237]	validation_0-merror:0.01385	validation_0-mlogloss:0.08378
# [238]	validation_0-merror:0.01373	validation_0-mlogloss:0.08348
# [239]	validation_0-merror:0.01366	validation_0-mlogloss:0.08306
# [240]	validation_0-merror:0.01352	validation_0-mlogloss:0.08276
# [241]	validation_0-merror:0.01337	validation_0-mlogloss:0.08244
# [242]	validation_0-merror:0.01332	validation_0-mlogloss:0.08224
# [243]	validation_0-merror:0.01321	validation_0-mlogloss:0.08196
# [244]	validation_0-merror:0.01311	validation_0-mlogloss:0.08164
# [245]	validation_0-merror:0.01307	validation_0-mlogloss:0.08132
# [246]	validation_0-merror:0.01299	validation_0-mlogloss:0.08100
# [247]	validation_0-merror:0.01283	validation_0-mlogloss:0.08067
# [248]	validation_0-merror:0.01275	validation_0-mlogloss:0.08031
# [249]	validation_0-merror:0.01270	validation_0-mlogloss:0.08005
# [250]	validation_0-merror:0.01256	validation_0-mlogloss:0.07977
# [251]	validation_0-merror:0.01247	validation_0-mlogloss:0.07953
# [252]	validation_0-merror:0.01237	validation_0-mlogloss:0.07930
# [253]	validation_0-merror:0.01225	validation_0-mlogloss:0.07905
# [254]	validation_0-merror:0.01215	validation_0-mlogloss:0.07877
# [255]	validation_0-merror:0.01209	validation_0-mlogloss:0.07844
# [256]	validation_0-merror:0.01203	validation_0-mlogloss:0.07816
# [257]	validation_0-merror:0.01196	validation_0-mlogloss:0.07790
# [258]	validation_0-merror:0.01182	validation_0-mlogloss:0.07763
# [259]	validation_0-merror:0.01180	validation_0-mlogloss:0.07727
# [260]	validation_0-merror:0.01161	validation_0-mlogloss:0.07700
# [261]	validation_0-merror:0.01154	validation_0-mlogloss:0.07667
# [262]	validation_0-merror:0.01142	validation_0-mlogloss:0.07638
# [263]	validation_0-merror:0.01139	validation_0-mlogloss:0.07617
# [264]	validation_0-merror:0.01129	validation_0-mlogloss:0.07586
# [265]	validation_0-merror:0.01124	validation_0-mlogloss:0.07564
# [266]	validation_0-merror:0.01112	validation_0-mlogloss:0.07531
# [267]	validation_0-merror:0.01106	validation_0-mlogloss:0.07508
# [268]	validation_0-merror:0.01098	validation_0-mlogloss:0.07482
# [269]	validation_0-merror:0.01094	validation_0-mlogloss:0.07457
# [270]	validation_0-merror:0.01084	validation_0-mlogloss:0.07428
# [271]	validation_0-merror:0.01082	validation_0-mlogloss:0.07401
# [272]	validation_0-merror:0.01072	validation_0-mlogloss:0.07376
# [273]	validation_0-merror:0.01064	validation_0-mlogloss:0.07351
# [274]	validation_0-merror:0.01064	validation_0-mlogloss:0.07326
# [275]	validation_0-merror:0.01051	validation_0-mlogloss:0.07300
# [276]	validation_0-merror:0.01041	validation_0-mlogloss:0.07274
# [277]	validation_0-merror:0.01036	validation_0-mlogloss:0.07249
# [278]	validation_0-merror:0.01034	validation_0-mlogloss:0.07228
# [279]	validation_0-merror:0.01022	validation_0-mlogloss:0.07201
# [280]	validation_0-merror:0.01005	validation_0-mlogloss:0.07176
# [281]	validation_0-merror:0.00998	validation_0-mlogloss:0.07150
# [282]	validation_0-merror:0.00993	validation_0-mlogloss:0.07126
# [283]	validation_0-merror:0.00984	validation_0-mlogloss:0.07103
# [284]	validation_0-merror:0.00978	validation_0-mlogloss:0.07082
# [285]	validation_0-merror:0.00966	validation_0-mlogloss:0.07062
# [286]	validation_0-merror:0.00955	validation_0-mlogloss:0.07040
# [287]	validation_0-merror:0.00948	validation_0-mlogloss:0.07016
# [288]	validation_0-merror:0.00928	validation_0-mlogloss:0.06992
# [289]	validation_0-merror:0.00924	validation_0-mlogloss:0.06975
# [290]	validation_0-merror:0.00919	validation_0-mlogloss:0.06951
# [291]	validation_0-merror:0.00914	validation_0-mlogloss:0.06917
# [292]	validation_0-merror:0.00902	validation_0-mlogloss:0.06892
# [293]	validation_0-merror:0.00897	validation_0-mlogloss:0.06868
# [294]	validation_0-merror:0.00888	validation_0-mlogloss:0.06848
# [295]	validation_0-merror:0.00883	validation_0-mlogloss:0.06826
# [296]	validation_0-merror:0.00878	validation_0-mlogloss:0.06809
# [297]	validation_0-merror:0.00876	validation_0-mlogloss:0.06785
# [298]	validation_0-merror:0.00868	validation_0-mlogloss:0.06763
# [299]	validation_0-merror:0.00859	validation_0-mlogloss:0.06742
# [300]	validation_0-merror:0.00849	validation_0-mlogloss:0.06721
# [301]	validation_0-merror:0.00842	validation_0-mlogloss:0.06694
# [302]	validation_0-merror:0.00837	validation_0-mlogloss:0.06674
# [303]	validation_0-merror:0.00826	validation_0-mlogloss:0.06652
# [304]	validation_0-merror:0.00818	validation_0-mlogloss:0.06630
# [305]	validation_0-merror:0.00808	validation_0-mlogloss:0.06603
# [306]	validation_0-merror:0.00790	validation_0-mlogloss:0.06579
# [307]	validation_0-merror:0.00782	validation_0-mlogloss:0.06555
# [308]	validation_0-merror:0.00780	validation_0-mlogloss:0.06535
# [309]	validation_0-merror:0.00778	validation_0-mlogloss:0.06513
# [310]	validation_0-merror:0.00768	validation_0-mlogloss:0.06487
# [311]	validation_0-merror:0.00764	validation_0-mlogloss:0.06468
# [312]	validation_0-merror:0.00756	validation_0-mlogloss:0.06448
# [313]	validation_0-merror:0.00749	validation_0-mlogloss:0.06426
# [314]	validation_0-merror:0.00739	validation_0-mlogloss:0.06399
# [315]	validation_0-merror:0.00734	validation_0-mlogloss:0.06382
# [316]	validation_0-merror:0.00732	validation_0-mlogloss:0.06360
# [317]	validation_0-merror:0.00722	validation_0-mlogloss:0.06342
# [318]	validation_0-merror:0.00718	validation_0-mlogloss:0.06319
# [319]	validation_0-merror:0.00713	validation_0-mlogloss:0.06299
# [320]	validation_0-merror:0.00704	validation_0-mlogloss:0.06276
# [321]	validation_0-merror:0.00704	validation_0-mlogloss:0.06256
# [322]	validation_0-merror:0.00696	validation_0-mlogloss:0.06239
# [323]	validation_0-merror:0.00689	validation_0-mlogloss:0.06218
# [324]	validation_0-merror:0.00685	validation_0-mlogloss:0.06198
# [325]	validation_0-merror:0.00668	validation_0-mlogloss:0.06182
# [326]	validation_0-merror:0.00665	validation_0-mlogloss:0.06167
# [327]	validation_0-merror:0.00665	validation_0-mlogloss:0.06149
# [328]	validation_0-merror:0.00663	validation_0-mlogloss:0.06130
# [329]	validation_0-merror:0.00660	validation_0-mlogloss:0.06108
# [330]	validation_0-merror:0.00653	validation_0-mlogloss:0.06093
# [331]	validation_0-merror:0.00641	validation_0-mlogloss:0.06074
# [332]	validation_0-merror:0.00641	validation_0-mlogloss:0.06055
# [333]	validation_0-merror:0.00634	validation_0-mlogloss:0.06039
# [334]	validation_0-merror:0.00629	validation_0-mlogloss:0.06021
# [335]	validation_0-merror:0.00622	validation_0-mlogloss:0.06004
# [336]	validation_0-merror:0.00620	validation_0-mlogloss:0.05985
# [337]	validation_0-merror:0.00617	validation_0-mlogloss:0.05966
# [338]	validation_0-merror:0.00613	validation_0-mlogloss:0.05951
# [339]	validation_0-merror:0.00608	validation_0-mlogloss:0.05933
# [340]	validation_0-merror:0.00601	validation_0-mlogloss:0.05917
# [341]	validation_0-merror:0.00601	validation_0-mlogloss:0.05901
# [342]	validation_0-merror:0.00586	validation_0-mlogloss:0.05879
# [343]	validation_0-merror:0.00586	validation_0-mlogloss:0.05863
# [344]	validation_0-merror:0.00577	validation_0-mlogloss:0.05844
# [345]	validation_0-merror:0.00570	validation_0-mlogloss:0.05824
# [346]	validation_0-merror:0.00562	validation_0-mlogloss:0.05807
# [347]	validation_0-merror:0.00560	validation_0-mlogloss:0.05791
# [348]	validation_0-merror:0.00555	validation_0-mlogloss:0.05770
# [349]	validation_0-merror:0.00557	validation_0-mlogloss:0.05755
# [350]	validation_0-merror:0.00553	validation_0-mlogloss:0.05738
# [351]	validation_0-merror:0.00545	validation_0-mlogloss:0.05720
# [352]	validation_0-merror:0.00536	validation_0-mlogloss:0.05697
# [353]	validation_0-merror:0.00536	validation_0-mlogloss:0.05683
# [354]	validation_0-merror:0.00533	validation_0-mlogloss:0.05665
# [355]	validation_0-merror:0.00531	validation_0-mlogloss:0.05641
# [356]	validation_0-merror:0.00526	validation_0-mlogloss:0.05618
# [357]	validation_0-merror:0.00524	validation_0-mlogloss:0.05597
# [358]	validation_0-merror:0.00519	validation_0-mlogloss:0.05583
# [359]	validation_0-merror:0.00512	validation_0-mlogloss:0.05566
# [360]	validation_0-merror:0.00505	validation_0-mlogloss:0.05549
# [361]	validation_0-merror:0.00498	validation_0-mlogloss:0.05529
# [362]	validation_0-merror:0.00485	validation_0-mlogloss:0.05511
# [363]	validation_0-merror:0.00476	validation_0-mlogloss:0.05489
# [364]	validation_0-merror:0.00471	validation_0-mlogloss:0.05471
# [365]	validation_0-merror:0.00471	validation_0-mlogloss:0.05453
# [366]	validation_0-merror:0.00466	validation_0-mlogloss:0.05435
# [367]	validation_0-merror:0.00469	validation_0-mlogloss:0.05422
# [368]	validation_0-merror:0.00466	validation_0-mlogloss:0.05402
# [369]	validation_0-merror:0.00464	validation_0-mlogloss:0.05387
# [370]	validation_0-merror:0.00459	validation_0-mlogloss:0.05369
# [371]	validation_0-merror:0.00455	validation_0-mlogloss:0.05353
# [372]	validation_0-merror:0.00455	validation_0-mlogloss:0.05333
# [373]	validation_0-merror:0.00452	validation_0-mlogloss:0.05316
# [374]	validation_0-merror:0.00450	validation_0-mlogloss:0.05301
# [375]	validation_0-merror:0.00450	validation_0-mlogloss:0.05288
# [376]	validation_0-merror:0.00448	validation_0-mlogloss:0.05273
# [377]	validation_0-merror:0.00441	validation_0-mlogloss:0.05259
# [378]	validation_0-merror:0.00433	validation_0-mlogloss:0.05239
# [379]	validation_0-merror:0.00435	validation_0-mlogloss:0.05223
# [380]	validation_0-merror:0.00431	validation_0-mlogloss:0.05211
# [381]	validation_0-merror:0.00426	validation_0-mlogloss:0.05192
# [382]	validation_0-merror:0.00421	validation_0-mlogloss:0.05176
# [383]	validation_0-merror:0.00417	validation_0-mlogloss:0.05162
# [384]	validation_0-merror:0.00414	validation_0-mlogloss:0.05151
# [385]	validation_0-merror:0.00407	validation_0-mlogloss:0.05140
# [386]	validation_0-merror:0.00404	validation_0-mlogloss:0.05125
# [387]	validation_0-merror:0.00397	validation_0-mlogloss:0.05113
# [388]	validation_0-merror:0.00399	validation_0-mlogloss:0.05100
# [389]	validation_0-merror:0.00397	validation_0-mlogloss:0.05087
# [390]	validation_0-merror:0.00395	validation_0-mlogloss:0.05074
# [391]	validation_0-merror:0.00393	validation_0-mlogloss:0.05061
# [392]	validation_0-merror:0.00388	validation_0-mlogloss:0.05047
# [393]	validation_0-merror:0.00387	validation_0-mlogloss:0.05037
# [394]	validation_0-merror:0.00381	validation_0-mlogloss:0.05021
# [395]	validation_0-merror:0.00381	validation_0-mlogloss:0.05007
# [396]	validation_0-merror:0.00380	validation_0-mlogloss:0.04992
# [397]	validation_0-merror:0.00378	validation_0-mlogloss:0.04971
# [398]	validation_0-merror:0.00375	validation_0-mlogloss:0.04954
# [399]	validation_0-merror:0.00369	validation_0-mlogloss:0.04938
# [400]	validation_0-merror:0.00364	validation_0-mlogloss:0.04923
# [401]	validation_0-merror:0.00364	validation_0-mlogloss:0.04909
# [402]	validation_0-merror:0.00363	validation_0-mlogloss:0.04894
# [403]	validation_0-merror:0.00356	validation_0-mlogloss:0.04880
# [404]	validation_0-merror:0.00352	validation_0-mlogloss:0.04866
# [405]	validation_0-merror:0.00349	validation_0-mlogloss:0.04848
# [406]	validation_0-merror:0.00345	validation_0-mlogloss:0.04835
# [407]	validation_0-merror:0.00342	validation_0-mlogloss:0.04820
# [408]	validation_0-merror:0.00340	validation_0-mlogloss:0.04810
# [409]	validation_0-merror:0.00340	validation_0-mlogloss:0.04799
# [410]	validation_0-merror:0.00337	validation_0-mlogloss:0.04787
# [411]	validation_0-merror:0.00333	validation_0-mlogloss:0.04772
# [412]	validation_0-merror:0.00333	validation_0-mlogloss:0.04758
# [413]	validation_0-merror:0.00330	validation_0-mlogloss:0.04743
# [414]	validation_0-merror:0.00323	validation_0-mlogloss:0.04729
# [415]	validation_0-merror:0.00321	validation_0-mlogloss:0.04715
# [416]	validation_0-merror:0.00318	validation_0-mlogloss:0.04699
# [417]	validation_0-merror:0.00314	validation_0-mlogloss:0.04679
# [418]	validation_0-merror:0.00314	validation_0-mlogloss:0.04660
# [419]	validation_0-merror:0.00311	validation_0-mlogloss:0.04644
# [420]	validation_0-merror:0.00311	validation_0-mlogloss:0.04628
# [421]	validation_0-merror:0.00306	validation_0-mlogloss:0.04615
# [422]	validation_0-merror:0.00297	validation_0-mlogloss:0.04600
# [423]	validation_0-merror:0.00296	validation_0-mlogloss:0.04587
# [424]	validation_0-merror:0.00290	validation_0-mlogloss:0.04573
# [425]	validation_0-merror:0.00287	validation_0-mlogloss:0.04559
# [426]	validation_0-merror:0.00283	validation_0-mlogloss:0.04541
# [427]	validation_0-merror:0.00283	validation_0-mlogloss:0.04530
# [428]	validation_0-merror:0.00280	validation_0-mlogloss:0.04519
# [429]	validation_0-merror:0.00280	validation_0-mlogloss:0.04506
# [430]	validation_0-merror:0.00280	validation_0-mlogloss:0.04492
# [431]	validation_0-merror:0.00280	validation_0-mlogloss:0.04479
# [432]	validation_0-merror:0.00275	validation_0-mlogloss:0.04465
# [433]	validation_0-merror:0.00275	validation_0-mlogloss:0.04445
# [434]	validation_0-merror:0.00271	validation_0-mlogloss:0.04431
# [435]	validation_0-merror:0.00271	validation_0-mlogloss:0.04416
# [436]	validation_0-merror:0.00271	validation_0-mlogloss:0.04405
# [437]	validation_0-merror:0.00271	validation_0-mlogloss:0.04392
# [438]	validation_0-merror:0.00270	validation_0-mlogloss:0.04378
# [439]	validation_0-merror:0.00268	validation_0-mlogloss:0.04363
# [440]	validation_0-merror:0.00259	validation_0-mlogloss:0.04348
# [441]	validation_0-merror:0.00258	validation_0-mlogloss:0.04334
# [442]	validation_0-merror:0.00249	validation_0-mlogloss:0.04314
# [443]	validation_0-merror:0.00251	validation_0-mlogloss:0.04303
# [444]	validation_0-merror:0.00251	validation_0-mlogloss:0.04292
# [445]	validation_0-merror:0.00249	validation_0-mlogloss:0.04279
# [446]	validation_0-merror:0.00247	validation_0-mlogloss:0.04265
# [447]	validation_0-merror:0.00249	validation_0-mlogloss:0.04251
# [448]	validation_0-merror:0.00247	validation_0-mlogloss:0.04236
# [449]	validation_0-merror:0.00242	validation_0-mlogloss:0.04222
# [450]	validation_0-merror:0.00242	validation_0-mlogloss:0.04211
# [451]	validation_0-merror:0.00242	validation_0-mlogloss:0.04202
# [452]	validation_0-merror:0.00237	validation_0-mlogloss:0.04192
# [453]	validation_0-merror:0.00237	validation_0-mlogloss:0.04178
# [454]	validation_0-merror:0.00237	validation_0-mlogloss:0.04165
# [455]	validation_0-merror:0.00237	validation_0-mlogloss:0.04151
# [456]	validation_0-merror:0.00237	validation_0-mlogloss:0.04137
# [457]	validation_0-merror:0.00237	validation_0-mlogloss:0.04125
# [458]	validation_0-merror:0.00234	validation_0-mlogloss:0.04112
# [459]	validation_0-merror:0.00229	validation_0-mlogloss:0.04094
# [460]	validation_0-merror:0.00222	validation_0-mlogloss:0.04078
# [461]	validation_0-merror:0.00222	validation_0-mlogloss:0.04067
# [462]	validation_0-merror:0.00220	validation_0-mlogloss:0.04055
# [463]	validation_0-merror:0.00215	validation_0-mlogloss:0.04042
# [464]	validation_0-merror:0.00213	validation_0-mlogloss:0.04025
# [465]	validation_0-merror:0.00211	validation_0-mlogloss:0.04015
# [466]	validation_0-merror:0.00211	validation_0-mlogloss:0.04000
# [467]	validation_0-merror:0.00210	validation_0-mlogloss:0.03990
# [468]	validation_0-merror:0.00210	validation_0-mlogloss:0.03978
# [469]	validation_0-merror:0.00206	validation_0-mlogloss:0.03965
# [470]	validation_0-merror:0.00206	validation_0-mlogloss:0.03955
# [471]	validation_0-merror:0.00203	validation_0-mlogloss:0.03944
# [472]	validation_0-merror:0.00198	validation_0-mlogloss:0.03929
# [473]	validation_0-merror:0.00194	validation_0-mlogloss:0.03914
# [474]	validation_0-merror:0.00192	validation_0-mlogloss:0.03897
# [475]	validation_0-merror:0.00192	validation_0-mlogloss:0.03888
# [476]	validation_0-merror:0.00189	validation_0-mlogloss:0.03875
# [477]	validation_0-merror:0.00189	validation_0-mlogloss:0.03863
# [478]	validation_0-merror:0.00187	validation_0-mlogloss:0.03850
# [479]	validation_0-merror:0.00186	validation_0-mlogloss:0.03836
# [480]	validation_0-merror:0.00186	validation_0-mlogloss:0.03825
# [481]	validation_0-merror:0.00184	validation_0-mlogloss:0.03808
# [482]	validation_0-merror:0.00184	validation_0-mlogloss:0.03796
# [483]	validation_0-merror:0.00182	validation_0-mlogloss:0.03782
# [484]	validation_0-merror:0.00179	validation_0-mlogloss:0.03771
# [485]	validation_0-merror:0.00175	validation_0-mlogloss:0.03759
# [486]	validation_0-merror:0.00175	validation_0-mlogloss:0.03745
# [487]	validation_0-merror:0.00173	validation_0-mlogloss:0.03736
# [488]	validation_0-merror:0.00173	validation_0-mlogloss:0.03727
# [489]	validation_0-merror:0.00173	validation_0-mlogloss:0.03716
# [490]	validation_0-merror:0.00172	validation_0-mlogloss:0.03707
# [491]	validation_0-merror:0.00168	validation_0-mlogloss:0.03698
# [492]	validation_0-merror:0.00167	validation_0-mlogloss:0.03684
# [493]	validation_0-merror:0.00167	validation_0-mlogloss:0.03675
# [494]	validation_0-merror:0.00160	validation_0-mlogloss:0.03661
# [495]	validation_0-merror:0.00158	validation_0-mlogloss:0.03649
# [496]	validation_0-merror:0.00158	validation_0-mlogloss:0.03641
# [497]	validation_0-merror:0.00158	validation_0-mlogloss:0.03627
# [498]	validation_0-merror:0.00156	validation_0-mlogloss:0.03614
# [499]	validation_0-merror:0.00153	validation_0-mlogloss:0.03601
# [500]	validation_0-merror:0.00153	validation_0-mlogloss:0.03590
# [501]	validation_0-merror:0.00150	validation_0-mlogloss:0.03578
# [502]	validation_0-merror:0.00150	validation_0-mlogloss:0.03570
# [503]	validation_0-merror:0.00150	validation_0-mlogloss:0.03559
# [504]	validation_0-merror:0.00150	validation_0-mlogloss:0.03549
# [505]	validation_0-merror:0.00148	validation_0-mlogloss:0.03540
# [506]	validation_0-merror:0.00148	validation_0-mlogloss:0.03531
# [507]	validation_0-merror:0.00146	validation_0-mlogloss:0.03522
# [508]	validation_0-merror:0.00146	validation_0-mlogloss:0.03510
# [509]	validation_0-merror:0.00146	validation_0-mlogloss:0.03499
# [510]	validation_0-merror:0.00144	validation_0-mlogloss:0.03491
# [511]	validation_0-merror:0.00143	validation_0-mlogloss:0.03482
# [512]	validation_0-merror:0.00143	validation_0-mlogloss:0.03471
# [513]	validation_0-merror:0.00143	validation_0-mlogloss:0.03460
# [514]	validation_0-merror:0.00143	validation_0-mlogloss:0.03449
# [515]	validation_0-merror:0.00143	validation_0-mlogloss:0.03440
# [516]	validation_0-merror:0.00143	validation_0-mlogloss:0.03431
# [517]	validation_0-merror:0.00143	validation_0-mlogloss:0.03423
# [518]	validation_0-merror:0.00143	validation_0-mlogloss:0.03413
# [519]	validation_0-merror:0.00136	validation_0-mlogloss:0.03404
# [520]	validation_0-merror:0.00136	validation_0-mlogloss:0.03397
# [521]	validation_0-merror:0.00136	validation_0-mlogloss:0.03389
# [522]	validation_0-merror:0.00134	validation_0-mlogloss:0.03378
# [523]	validation_0-merror:0.00131	validation_0-mlogloss:0.03367
# [524]	validation_0-merror:0.00125	validation_0-mlogloss:0.03357
# [525]	validation_0-merror:0.00124	validation_0-mlogloss:0.03347
# [526]	validation_0-merror:0.00124	validation_0-mlogloss:0.03340
# [527]	validation_0-merror:0.00120	validation_0-mlogloss:0.03331
# [528]	validation_0-merror:0.00119	validation_0-mlogloss:0.03321
# [529]	validation_0-merror:0.00117	validation_0-mlogloss:0.03313
# [530]	validation_0-merror:0.00119	validation_0-mlogloss:0.03304
# [531]	validation_0-merror:0.00115	validation_0-mlogloss:0.03296
# [532]	validation_0-merror:0.00112	validation_0-mlogloss:0.03288
# [533]	validation_0-merror:0.00112	validation_0-mlogloss:0.03279
# [534]	validation_0-merror:0.00110	validation_0-mlogloss:0.03269
# [535]	validation_0-merror:0.00110	validation_0-mlogloss:0.03260
# [536]	validation_0-merror:0.00108	validation_0-mlogloss:0.03250
# [537]	validation_0-merror:0.00108	validation_0-mlogloss:0.03241
# [538]	validation_0-merror:0.00106	validation_0-mlogloss:0.03229
# [539]	validation_0-merror:0.00106	validation_0-mlogloss:0.03221
# [540]	validation_0-merror:0.00106	validation_0-mlogloss:0.03211
# [541]	validation_0-merror:0.00106	validation_0-mlogloss:0.03204
# [542]	validation_0-merror:0.00106	validation_0-mlogloss:0.03192
# [543]	validation_0-merror:0.00105	validation_0-mlogloss:0.03180
# [544]	validation_0-merror:0.00105	validation_0-mlogloss:0.03172
# [545]	validation_0-merror:0.00105	validation_0-mlogloss:0.03160
# [546]	validation_0-merror:0.00101	validation_0-mlogloss:0.03150
# [547]	validation_0-merror:0.00101	validation_0-mlogloss:0.03141
# [548]	validation_0-merror:0.00100	validation_0-mlogloss:0.03133
# [549]	validation_0-merror:0.00094	validation_0-mlogloss:0.03122
# [550]	validation_0-merror:0.00094	validation_0-mlogloss:0.03113
# [551]	validation_0-merror:0.00093	validation_0-mlogloss:0.03106
# [552]	validation_0-merror:0.00088	validation_0-mlogloss:0.03095
# [553]	validation_0-merror:0.00088	validation_0-mlogloss:0.03085
# [554]	validation_0-merror:0.00088	validation_0-mlogloss:0.03075
# [555]	validation_0-merror:0.00086	validation_0-mlogloss:0.03067
# [556]	validation_0-merror:0.00084	validation_0-mlogloss:0.03059
# [557]	validation_0-merror:0.00082	validation_0-mlogloss:0.03052
# [558]	validation_0-merror:0.00082	validation_0-mlogloss:0.03045
# [559]	validation_0-merror:0.00081	validation_0-mlogloss:0.03038
# [560]	validation_0-merror:0.00079	validation_0-mlogloss:0.03030
# [561]	validation_0-merror:0.00077	validation_0-mlogloss:0.03023
# [562]	validation_0-merror:0.00076	validation_0-mlogloss:0.03016
# [563]	validation_0-merror:0.00074	validation_0-mlogloss:0.03009
# [564]	validation_0-merror:0.00074	validation_0-mlogloss:0.03001
# [565]	validation_0-merror:0.00074	validation_0-mlogloss:0.02994
# [566]	validation_0-merror:0.00074	validation_0-mlogloss:0.02985
# [567]	validation_0-merror:0.00072	validation_0-mlogloss:0.02976
# [568]	validation_0-merror:0.00072	validation_0-mlogloss:0.02968
# [569]	validation_0-merror:0.00070	validation_0-mlogloss:0.02959
# [570]	validation_0-merror:0.00070	validation_0-mlogloss:0.02951
# [571]	validation_0-merror:0.00067	validation_0-mlogloss:0.02941
# [572]	validation_0-merror:0.00062	validation_0-mlogloss:0.02934
# [573]	validation_0-merror:0.00060	validation_0-mlogloss:0.02926
# [574]	validation_0-merror:0.00060	validation_0-mlogloss:0.02918
# [575]	validation_0-merror:0.00060	validation_0-mlogloss:0.02912
# [576]	validation_0-merror:0.00058	validation_0-mlogloss:0.02905
# [577]	validation_0-merror:0.00058	validation_0-mlogloss:0.02896
# [578]	validation_0-merror:0.00058	validation_0-mlogloss:0.02889
# [579]	validation_0-merror:0.00058	validation_0-mlogloss:0.02882
# [580]	validation_0-merror:0.00058	validation_0-mlogloss:0.02874
# [581]	validation_0-merror:0.00058	validation_0-mlogloss:0.02867
# [582]	validation_0-merror:0.00058	validation_0-mlogloss:0.02861
# [583]	validation_0-merror:0.00057	validation_0-mlogloss:0.02853
# [584]	validation_0-merror:0.00057	validation_0-mlogloss:0.02845
# [585]	validation_0-merror:0.00057	validation_0-mlogloss:0.02836
# [586]	validation_0-merror:0.00057	validation_0-mlogloss:0.02831
# [587]	validation_0-merror:0.00057	validation_0-mlogloss:0.02824
# [588]	validation_0-merror:0.00057	validation_0-mlogloss:0.02817
# [589]	validation_0-merror:0.00057	validation_0-mlogloss:0.02810
# [590]	validation_0-merror:0.00057	validation_0-mlogloss:0.02803
# [591]	validation_0-merror:0.00057	validation_0-mlogloss:0.02796
# [592]	validation_0-merror:0.00057	validation_0-mlogloss:0.02788
# [593]	validation_0-merror:0.00057	validation_0-mlogloss:0.02778
# [594]	validation_0-merror:0.00057	validation_0-mlogloss:0.02771
# [595]	validation_0-merror:0.00057	validation_0-mlogloss:0.02764
# [596]	validation_0-merror:0.00057	validation_0-mlogloss:0.02756
# [597]	validation_0-merror:0.00055	validation_0-mlogloss:0.02751
# [598]	validation_0-merror:0.00055	validation_0-mlogloss:0.02745
# [599]	validation_0-merror:0.00055	validation_0-mlogloss:0.02736
# [600]	validation_0-merror:0.00055	validation_0-mlogloss:0.02728
# [601]	validation_0-merror:0.00053	validation_0-mlogloss:0.02721
# [602]	validation_0-merror:0.00052	validation_0-mlogloss:0.02714
# [603]	validation_0-merror:0.00052	validation_0-mlogloss:0.02704
# [604]	validation_0-merror:0.00050	validation_0-mlogloss:0.02698
# [605]	validation_0-merror:0.00050	validation_0-mlogloss:0.02691
# [606]	validation_0-merror:0.00050	validation_0-mlogloss:0.02685
# [607]	validation_0-merror:0.00050	validation_0-mlogloss:0.02678
# [608]	validation_0-merror:0.00050	validation_0-mlogloss:0.02671
# [609]	validation_0-merror:0.00050	validation_0-mlogloss:0.02664
# [610]	validation_0-merror:0.00048	validation_0-mlogloss:0.02655
# [611]	validation_0-merror:0.00050	validation_0-mlogloss:0.02649
# [612]	validation_0-merror:0.00048	validation_0-mlogloss:0.02644
# [613]	validation_0-merror:0.00045	validation_0-mlogloss:0.02637
# [614]	validation_0-merror:0.00045	validation_0-mlogloss:0.02629
# [615]	validation_0-merror:0.00045	validation_0-mlogloss:0.02622
# [616]	validation_0-merror:0.00045	validation_0-mlogloss:0.02615
# [617]	validation_0-merror:0.00045	validation_0-mlogloss:0.02607
# [618]	validation_0-merror:0.00045	validation_0-mlogloss:0.02600
# [619]	validation_0-merror:0.00043	validation_0-mlogloss:0.02592
# [620]	validation_0-merror:0.00040	validation_0-mlogloss:0.02585
# [621]	validation_0-merror:0.00040	validation_0-mlogloss:0.02578
# [622]	validation_0-merror:0.00038	validation_0-mlogloss:0.02572
# [623]	validation_0-merror:0.00038	validation_0-mlogloss:0.02566
# [624]	validation_0-merror:0.00038	validation_0-mlogloss:0.02559
# [625]	validation_0-merror:0.00038	validation_0-mlogloss:0.02553
# [626]	validation_0-merror:0.00038	validation_0-mlogloss:0.02546
# [627]	validation_0-merror:0.00038	validation_0-mlogloss:0.02539
# [628]	validation_0-merror:0.00036	validation_0-mlogloss:0.02533
# [629]	validation_0-merror:0.00034	validation_0-mlogloss:0.02525
# [630]	validation_0-merror:0.00034	validation_0-mlogloss:0.02518
# [631]	validation_0-merror:0.00034	validation_0-mlogloss:0.02510
# [632]	validation_0-merror:0.00034	validation_0-mlogloss:0.02503
# [633]	validation_0-merror:0.00034	validation_0-mlogloss:0.02496
# [634]	validation_0-merror:0.00034	validation_0-mlogloss:0.02490
# [635]	validation_0-merror:0.00033	validation_0-mlogloss:0.02482
# [636]	validation_0-merror:0.00033	validation_0-mlogloss:0.02473
# [637]	validation_0-merror:0.00033	validation_0-mlogloss:0.02467
# [638]	validation_0-merror:0.00033	validation_0-mlogloss:0.02461
# [639]	validation_0-merror:0.00033	validation_0-mlogloss:0.02455
# [640]	validation_0-merror:0.00031	validation_0-mlogloss:0.02448
# [641]	validation_0-merror:0.00031	validation_0-mlogloss:0.02442
# [642]	validation_0-merror:0.00031	validation_0-mlogloss:0.02436
# [643]	validation_0-merror:0.00031	validation_0-mlogloss:0.02430
# [644]	validation_0-merror:0.00031	validation_0-mlogloss:0.02423
# [645]	validation_0-merror:0.00031	validation_0-mlogloss:0.02416
# [646]	validation_0-merror:0.00031	validation_0-mlogloss:0.02410
# [647]	validation_0-merror:0.00029	validation_0-mlogloss:0.02402
# [648]	validation_0-merror:0.00028	validation_0-mlogloss:0.02395
# [649]	validation_0-merror:0.00028	validation_0-mlogloss:0.02388
# [650]	validation_0-merror:0.00028	validation_0-mlogloss:0.02383
# [651]	validation_0-merror:0.00024	validation_0-mlogloss:0.02377
# [652]	validation_0-merror:0.00024	validation_0-mlogloss:0.02371
# [653]	validation_0-merror:0.00024	validation_0-mlogloss:0.02364
# [654]	validation_0-merror:0.00024	validation_0-mlogloss:0.02358
# [655]	validation_0-merror:0.00024	validation_0-mlogloss:0.02351
# [656]	validation_0-merror:0.00024	validation_0-mlogloss:0.02345
# [657]	validation_0-merror:0.00024	validation_0-mlogloss:0.02339
# [658]	validation_0-merror:0.00024	validation_0-mlogloss:0.02334
# [659]	validation_0-merror:0.00024	validation_0-mlogloss:0.02328
# [660]	validation_0-merror:0.00024	validation_0-mlogloss:0.02322
# [661]	validation_0-merror:0.00024	validation_0-mlogloss:0.02316
# [662]	validation_0-merror:0.00024	validation_0-mlogloss:0.02311
# [663]	validation_0-merror:0.00024	validation_0-mlogloss:0.02304
# [664]	validation_0-merror:0.00024	validation_0-mlogloss:0.02298
# [665]	validation_0-merror:0.00024	validation_0-mlogloss:0.02291
# [666]	validation_0-merror:0.00022	validation_0-mlogloss:0.02284
# [667]	validation_0-merror:0.00021	validation_0-mlogloss:0.02278
# [668]	validation_0-merror:0.00021	validation_0-mlogloss:0.02271
# [669]	validation_0-merror:0.00021	validation_0-mlogloss:0.02266
# [670]	validation_0-merror:0.00019	validation_0-mlogloss:0.02260
# [671]	validation_0-merror:0.00019	validation_0-mlogloss:0.02252
# [672]	validation_0-merror:0.00019	validation_0-mlogloss:0.02247
# [673]	validation_0-merror:0.00019	validation_0-mlogloss:0.02242
# [674]	validation_0-merror:0.00019	validation_0-mlogloss:0.02237
# [675]	validation_0-merror:0.00019	validation_0-mlogloss:0.02231
# [676]	validation_0-merror:0.00019	validation_0-mlogloss:0.02225
# [677]	validation_0-merror:0.00019	validation_0-mlogloss:0.02220
# [678]	validation_0-merror:0.00019	validation_0-mlogloss:0.02215
# [679]	validation_0-merror:0.00019	validation_0-mlogloss:0.02209
# [680]	validation_0-merror:0.00019	validation_0-mlogloss:0.02205
# [681]	validation_0-merror:0.00019	validation_0-mlogloss:0.02199
# [682]	validation_0-merror:0.00019	validation_0-mlogloss:0.02193
# [683]	validation_0-merror:0.00019	validation_0-mlogloss:0.02188
# [684]	validation_0-merror:0.00017	validation_0-mlogloss:0.02183
# [685]	validation_0-merror:0.00017	validation_0-mlogloss:0.02178
# [686]	validation_0-merror:0.00017	validation_0-mlogloss:0.02173
# [687]	validation_0-merror:0.00017	validation_0-mlogloss:0.02166
# [688]	validation_0-merror:0.00017	validation_0-mlogloss:0.02161
# [689]	validation_0-merror:0.00017	validation_0-mlogloss:0.02156
# [690]	validation_0-merror:0.00017	validation_0-mlogloss:0.02152
# [691]	validation_0-merror:0.00017	validation_0-mlogloss:0.02147
# [692]	validation_0-merror:0.00017	validation_0-mlogloss:0.02142
# [693]	validation_0-merror:0.00017	validation_0-mlogloss:0.02138
# [694]	validation_0-merror:0.00017	validation_0-mlogloss:0.02132
# [695]	validation_0-merror:0.00017	validation_0-mlogloss:0.02126
# [696]	validation_0-merror:0.00015	validation_0-mlogloss:0.02119
# [697]	validation_0-merror:0.00015	validation_0-mlogloss:0.02116
# [698]	validation_0-merror:0.00014	validation_0-mlogloss:0.02109
# [699]	validation_0-merror:0.00014	validation_0-mlogloss:0.02104

# %%
model = XGBClassifier()
model.load_model("../../Supervised/Fangyou/Preprocessed_data/combined_xgboost.json")
# Out:
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# /var/lib/condor/execute/dir_1924914/ipykernel_1979540/265822041.py in <module>
#       1 model = XGBClassifier()
# ----> 2 model.load_model("../../Supervised/Fangyou/Preprocessed_data/combined_xgboost.json")
#
# ~/.local/lib/python3.9/site-packages/xgboost/sklearn.py in load_model(self, fname)
#     466         if not hasattr(self, '_Booster'):
#     467             self._Booster = Booster({'n_jobs': self.n_jobs})
# --> 468         self._Booster.load_model(fname)
#     469         meta = self._Booster.attr('scikit_learn')
#     470         if meta is None:
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in load_model(self, fname)
#    1726             # assume file name, cannot use os.path.exist to check, file can be
#    1727             # from URL.
# -> 1728             _check_call(_LIB.XGBoosterLoadModel(
#    1729                 self.handle, c_str(os.fspath(fname))))
#    1730         elif isinstance(fname, bytearray):
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in _check_call(ret)
#     187     """
#     188     if ret != 0:
# --> 189         raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#     190
#     191
#
# XGBoostError: [21:50:36] ../include/xgboost/json.h:73: Invalid cast, from Integer to Boolean
# Stack trace:
#   [bt] (0) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0x8d264) [0x2b72d3ebb264]
#   [bt] (1) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0xbf379) [0x2b72d3eed379]
#   [bt] (2) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0x22fed8) [0x2b72d405ded8]
#   [bt] (3) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0x1960e5) [0x2b72d3fc40e5]
#   [bt] (4) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0x175c46) [0x2b72d3fa3c46]
#   [bt] (5) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(+0x1b407d) [0x2b72d3fe207d]
#   [bt] (6) /Users/users/karsten/.local/lib/python3.9/site-packages/xgboost/lib/libxgboost.so(XGBoosterLoadModel+0x5bf) [0x2b72d3ead85f]
#   [bt] (7) /Software/users/modules/7/software/anaconda3/2021.11/lib/python3.9/lib-dynload/../../libffi.so.7(+0x69dd) [0x2b7290fd19dd]
#   [bt] (8) /Software/users/modules/7/software/anaconda3/2021.11/lib/python3.9/lib-dynload/../../libffi.so.7(+0x6067) [0x2b7290fd1067]

# %%
import shap

shap.initjs()
explainer = shap.TreeExplainer(model)
shap_values = explainer.shap_values(X_train)

# %%
shap.plots.waterfall(exp[0])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# /var/lib/condor/execute/dir_1924914/ipykernel_1979540/2844207213.py in <module>
# ----> 1 shap.plots.waterfall(exp[0][0])
#
# ~/.local/lib/python3.9/site-packages/shap/plots/_waterfall.py in waterfall(shap_values, max_display, show)
#     124             yticklabels[rng[i]] = feature_names[order[i]]
#     125         else:
# --> 126             if np.issubdtype(type(features[order[i]]), np.number):
#     127                 yticklabels[rng[i]] = format_value(float(features[order[i]]), "%0.03f") + " = " + feature_names[order[i]]
#     128             else:
#
# IndexError: invalid index to scalar variable.

# %%
shap.plots.waterfall(shap_values[0], shap_values.values[0], shap_values.data)
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/lib/condor/execute/dir_1924914/ipykernel_1979540/213035757.py in <module>
# ----> 1 shap.plots.waterfall(shap_values[0], shap_values.values[0], shap_values.data)
#
# ~/.local/lib/python3.9/site-packages/shap/plots/_waterfall.py in waterfall(shap_values, max_display, show)
#      52     # make sure we only have a single output to explain
#      53     if (type(base_values) == np.ndarray and len(base_values) > 0) or type(base_values) == list:
# ---> 54         raise Exception("waterfall_plot requires a scalar base_values of the model output as the first "
#      55                         "parameter, but you have passed an array as the first parameter! "
#      56                         "Try shap.waterfall_plot(explainer.base_values[0], values[0], X[0]) or "
#
# Exception: waterfall_plot requires a scalar base_values of the model output as the first parameter, but you have passed an array as the first parameter! Try shap.waterfall_plot(explainer.base_values[0], values[0], X[0]) or for multi-output models try shap.waterfall_plot(explainer.base_values[0], values[0][0], X[0]).

# %%
shap.plots.force(shap_values[0])
# Out:
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# /var/lib/condor/execute/dir_1924914/ipykernel_1979540/3668929140.py in <module>
# ----> 1 shap.plots.force(shap_values[0])
#
# ~/.local/lib/python3.9/site-packages/shap/plots/_force.py in force(base_value, shap_values, features, feature_names, out_names, link, plot_cmap, matplotlib, show, figsize, ordering_keys, ordering_keys_time_format, text_rotation, contribution_threshold)
#      96     if (isinstance(base_value, np.ndarray) or type(base_value) == list):
#      97         if not isinstance(shap_values, list) or len(shap_values) != len(base_value):
# ---> 98             raise Exception("In v0.20 force_plot now requires the base value as the first parameter! " \
#      99                             "Try shap.force_plot(explainer.expected_value, shap_values) or " \
#     100                             "for multi-output models try " \
#
# Exception: In v0.20 force_plot now requires the base value as the first parameter! Try shap.force_plot(explainer.expected_value, shap_values) or for multi-output models try shap.force_plot(explainer.expected_value[0], shap_values[0]).

# %%
from platform import python_version

print(python_version())
# Out:
# 3.9.7
