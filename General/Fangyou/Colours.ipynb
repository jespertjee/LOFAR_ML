# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("../../Data/Fangyou_data/Cleaned/Bootes_preprocessed.csv")

# %%
fluxes = data.iloc[:,1:-11].drop(columns=["S_Code", "EBV"])

# %%
fluxes
# Out:
#        FUV_flux_corr  NUV_flux_corr  u_flux_corr  Bw_flux_corr  R_flux_corr  \
# 0           0.000517       0.121041     0.000024      0.000003     1.382728
# 1           0.000517       0.000002    13.038874      0.000003     0.000854
# 2           0.000517       0.313706     1.890881      0.000003     6.857692
# 3           0.000517       7.500074     0.000024      0.000003    63.557111
# 4           0.000517       0.000002     0.011021      0.000003     0.000854
# ...              ...            ...          ...           ...          ...
# 77604       0.341273       0.225079     0.431178           NaN          NaN
# 77605       0.262419       0.172858     0.609065           NaN          NaN
# 77606       0.329990       0.217307     0.979376           NaN          NaN
# 77607       0.561018       0.366819     0.469435           NaN          NaN
# 77608       0.252158       0.165640     0.608928           NaN          NaN
#
# ...

# %%
number_of_columns = len(fluxes.columns)


for i in range(number_of_columns):
    for j in range(i+1, number_of_columns):
        name = fluxes.columns[i] + " - " + fluxes.columns[j]
        data[name] = fluxes.iloc[:,i] - fluxes.iloc[:,j]
# Out:
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10884\3724251815.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[name] = fluxes.iloc[:,i] - fluxes.iloc[:,j]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10884\3724251815.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   data[name] = fluxes.iloc[:,i] - fluxes.iloc[:,j]
# ...

# %%
data.to_csv("../../Data/Fangyou_data/Cleaned/Bootes_preprocessed_colours.csv", index=False)

# %%
data

# %%
for t in range(3,10):
    k=0
    for i in range(t+1):
        for j in range(i+1, t+1):
            k+=1
    print(t, k, (t*(t+1))/2)

# %%
for i in range(6):
    for j in range(i+1, 6):
        print(i,j)
# Out:
# FUV_flux_corr                                0.693582
# NUV_flux_corr                                0.621341
# u_flux_corr                                  2.793264
# Bw_flux_corr                                 4.679764
# FUV_flux_corr - NUV_flux_corr                0.072241
# FUV_flux_corr - u_flux_corr                 -2.099682
# FUV_flux_corr - Bw_flux_corr                -4.674672
# NUV_flux_corr - u_flux_corr                 -2.171923
# NUV_flux_corr - Bw_flux_corr                -3.886621
# u_flux_corr - Bw_flux_corr                  -1.643831
# u_flux_corr - g_flux_corr                   -4.355937
# u_flux_corr - g_hsc_flux_corr               -3.727551
# u_flux_corr - g_rcs_flux_corr               -4.560062
# I_flux_corr - z_flux_corr                   -1.425761
# I_flux_corr - z_Subaru_flux_corr            -1.824575
# z_flux_corr - z_Subaru_flux_corr            -0.398814
# z_flux_corr - z_hsc_flux_corr               -1.490898
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 2>()
#       1 index = means[(means<5) & (means>-5)]["mean"].dropna().index
# ----> 2 means.loc(index)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\indexing.py:634, in _LocationIndexer.__call__(self, axis)
#     631 new_self = type(self)(self.name, self.obj)
#     633 if axis is not None:
# --> 634     axis = self.obj._get_axis_number(axis)
#     635 new_self.axis = axis
#     636 return new_self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\pandas\core\generic.py:550, in NDFrame._get_axis_number(cls, axis)
#     546 @final
#     547 @classmethod
#     548 def _get_axis_number(cls, axis: Axis) -> int:
# ...
