# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, balanced_accuracy_score
from sklearn.utils.class_weight import compute_class_weight


from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

from xgboost import XGBClassifier, XGBRegressor
from bayes_opt import BayesianOptimization

# %%
features_num = [
    'Total_flux', 'Peak_flux', 
       'NUV_flux_corr', 'u_flux_corr', 'Bw_flux_corr', 'R_flux_corr',
       'I_flux_corr', 'z_flux_corr', 'y_flux_corr',
       'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr',
       'ch1_flux_corr', 'ch2_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr',
       'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350',
       'F_SPIRE_500', 'Z_BEST',
       'g_flux_corr', 'nb921_hsc_flux_corr'
    ]
y_column = "Classification"

classes = ['jet-mode radio AGN/low-excitation radio galaxy', 'quasar-like radio AGN / high-excitation radio galaxy', 
           'radio-quiet AGN', 'star-forming galaxy']

# %%
data = pd.read_csv("../../../Data/Fangyou_data/Cleaned/combined_using_similar_columns.csv")

X = data[features_num]
y = data[[y_column, 'Source']]

# %% [markdown]
# # 2 class

# %%
def AGN(row):
    
    if row['Classification'] == 'jet-mode radio AGN/low-excitation radio galaxy':
        return 1
    elif row['Classification'] == 'quasar-like radio AGN / high-excitation radio galaxy':
        return 1
    elif row['Classification'] == 'radio-quiet AGN':
        return 1
    elif row['Classification'] == 'star-forming galaxy':
        return 0

# %%
y['AGN'] =  y.apply(AGN, axis=1, result_type='expand')
# Out:
# /var/lib/condor/execute/dir_830810/ipykernel_873943/3505554675.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   y['AGN'] =  y.apply(AGN, axis=1, result_type='expand')

# %% [markdown]
# # Training model

# %%
X
# Out:
#         Total_flux   Peak_flux  NUV_flux_corr  u_flux_corr  Bw_flux_corr  \
# 0       841.504227  504.067340       0.121041          NaN           NaN
# 1      1497.581978  934.846936            NaN    13.038874           NaN
# 2       502.877076  322.345615       0.313706     1.890881           NaN
# 3       300.955344  329.597236       7.500074          NaN           NaN
# 4       285.588580  318.506481            NaN     0.011021           NaN
# ...            ...         ...            ...          ...           ...
# 77604   404.272879  344.389065       0.225079     0.431178           NaN
# 77605  1480.551760  936.415793       0.172858     0.609065           NaN
# 77606   709.620314  374.982368       0.217307     0.979376           NaN
# 77607   591.226106  497.437861       0.366819     0.469435           NaN
# 77608   969.100623  883.821355       0.165640     0.608928           NaN
#
#        R_flux_corr  I_flux_corr  z_flux_corr  y_flux_corr  J_flux_corr  ...  \
# 0         1.382728          NaN     2.296511          NaN     5.001355  ...
# 1              NaN     0.011940   126.802889   126.964987   186.723870  ...
# 2         6.857692    18.628942    15.904630    19.680046    27.588542  ...
# 3        63.557111    96.889359    81.025505          NaN   100.024530  ...
# 4              NaN          NaN     0.743611     0.080719     0.027066  ...
# ...            ...          ...          ...          ...          ...  ...
# 77604     1.626601          NaN     7.158808          NaN          NaN  ...
# 77605     2.296721          NaN     9.497899          NaN          NaN  ...
# 77606     2.811726          NaN     9.116296          NaN          NaN  ...
# 77607     5.373043          NaN    15.577719          NaN          NaN  ...
# 77608     2.016850          NaN     9.083191          NaN          NaN  ...
#
#        ch4_flux_corr   F_MIPS_24  F_PACS_100  F_PACS_160   F_SPIRE_250  \
# 0          64.083221         NaN         NaN         NaN           NaN
# 1        1071.471101         NaN         NaN         NaN           NaN
# 2          77.374759  292.823334  7114.09200   8275.3570   5009.754395
# 3         495.052235         NaN         NaN         NaN           NaN
# 4          26.426610  303.623596  5778.15500  58864.6880  20822.921875
# ...              ...         ...         ...         ...           ...
# 77604      51.112049  323.144684   565.49347   1275.3830           NaN
# 77605      51.009281  306.243469   563.41090   1235.7626           NaN
# 77606      65.887466  305.930634   545.68060   1352.5192           NaN
# 77607      31.999180  311.362915   536.16010   1616.1852           NaN
# 77608      78.511047         NaN   540.41846   1488.7367           NaN
#
#         F_SPIRE_350  F_SPIRE_500  Z_BEST  g_flux_corr  nb921_hsc_flux_corr
# 0               NaN          NaN  2.4986          NaN                  NaN
# 1               NaN          NaN  4.5887          NaN                  NaN
# 2       2178.669678   990.541626  2.7221          NaN                  NaN
# 3               NaN          NaN  0.1513          NaN                  NaN
# 4      25510.591797  9542.652344  4.4603          NaN                  NaN
# ...             ...          ...     ...          ...                  ...
# 77604           NaN          NaN  0.9986     0.609437                  NaN
# 77605           NaN          NaN  1.0274     0.949995                  NaN
# 77606           NaN          NaN  1.0350     1.320066                  NaN
# 77607           NaN          NaN  0.4429     1.528544                  NaN
# 77608           NaN          NaN  1.2068     0.847047                  NaN
#
# [77609 rows x 26 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(X_temp, y[['AGN', 'Source']], train_size=0.8, stratify=y[['AGN', 'Source']])
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, train_size=0.8, stratify=y_test)

# %%
model = XGBClassifier(use_label_encoder=False, 
                      max_depth=7,
                     min_child_weight=5,
                     learning_rate=0.2,
                     reg_alpha=5.7,
                     reg_lambda=3.6,
                     tree_method='hist',
                     objective='binary:logistic',
                     #eval_metric=['error'],
                     #scale_pos_weight=frac,
                      nthread=8,
                      n_estimators=10**5,
                      random_state=42
                      )

# %%
eval_set = [(X_train, y_train['AGN']), (X_val, y_val['AGN'])]

# %%
model.fit(X_train, y_train['AGN'], verbose=True, eval_set=eval_set, early_stopping_rounds=5)
# Out:
# [16:44:49] WARNING: ../src/learner.cc:1061: Starting in XGBoost 1.3.0, the default evaluation metric used with the objective 'binary:logistic' was changed from 'error' to 'logloss'. Explicitly set eval_metric if you'd like to restore the old behavior.
# [0]	validation_0-logloss:0.62457	validation_1-logloss:0.62432
# [1]	validation_0-logloss:0.58072	validation_1-logloss:0.58213
# [2]	validation_0-logloss:0.54659	validation_1-logloss:0.54880
# [3]	validation_0-logloss:0.52192	validation_1-logloss:0.52532
# [4]	validation_0-logloss:0.50269	validation_1-logloss:0.50681
# [5]	validation_0-logloss:0.48804	validation_1-logloss:0.49286
# [6]	validation_0-logloss:0.47623	validation_1-logloss:0.48150
# [7]	validation_0-logloss:0.46725	validation_1-logloss:0.47345
# [8]	validation_0-logloss:0.45875	validation_1-logloss:0.46692
# [9]	validation_0-logloss:0.45105	validation_1-logloss:0.46119
# [10]	validation_0-logloss:0.44536	validation_1-logloss:0.45660
# [11]	validation_0-logloss:0.44028	validation_1-logloss:0.45234
# [12]	validation_0-logloss:0.43597	validation_1-logloss:0.44863
# [13]	validation_0-logloss:0.43124	validation_1-logloss:0.44572
# [14]	validation_0-logloss:0.42805	validation_1-logloss:0.44364
# [15]	validation_0-logloss:0.42518	validation_1-logloss:0.44154
# [16]	validation_0-logloss:0.42319	validation_1-logloss:0.44020
# [17]	validation_0-logloss:0.42189	validation_1-logloss:0.43863
# [18]	validation_0-logloss:0.42054	validation_1-logloss:0.43774
# [19]	validation_0-logloss:0.41869	validation_1-logloss:0.43674
# [20]	validation_0-logloss:0.41614	validation_1-logloss:0.43481
# [21]	validation_0-logloss:0.41384	validation_1-logloss:0.43271
# [22]	validation_0-logloss:0.41274	validation_1-logloss:0.43168
# [23]	validation_0-logloss:0.41210	validation_1-logloss:0.43117
# [24]	validation_0-logloss:0.41148	validation_1-logloss:0.43060
# [25]	validation_0-logloss:0.40916	validation_1-logloss:0.42933
# [26]	validation_0-logloss:0.40745	validation_1-logloss:0.42828
# [27]	validation_0-logloss:0.40598	validation_1-logloss:0.42723
# [28]	validation_0-logloss:0.40519	validation_1-logloss:0.42697
# [29]	validation_0-logloss:0.40473	validation_1-logloss:0.42656
# [30]	validation_0-logloss:0.40334	validation_1-logloss:0.42554
# [31]	validation_0-logloss:0.40308	validation_1-logloss:0.42556
# [32]	validation_0-logloss:0.40158	validation_1-logloss:0.42492
# [33]	validation_0-logloss:0.39994	validation_1-logloss:0.42387
# [34]	validation_0-logloss:0.39841	validation_1-logloss:0.42316
# [35]	validation_0-logloss:0.39720	validation_1-logloss:0.42267
# [36]	validation_0-logloss:0.39553	validation_1-logloss:0.42171
# [37]	validation_0-logloss:0.39459	validation_1-logloss:0.42104
# [38]	validation_0-logloss:0.39358	validation_1-logloss:0.42042
# [39]	validation_0-logloss:0.39239	validation_1-logloss:0.41983
# [40]	validation_0-logloss:0.39114	validation_1-logloss:0.41909
# [41]	validation_0-logloss:0.38974	validation_1-logloss:0.41852
# [42]	validation_0-logloss:0.38826	validation_1-logloss:0.41768
# [43]	validation_0-logloss:0.38721	validation_1-logloss:0.41739
# [44]	validation_0-logloss:0.38576	validation_1-logloss:0.41660
# [45]	validation_0-logloss:0.38504	validation_1-logloss:0.41600
# [46]	validation_0-logloss:0.38359	validation_1-logloss:0.41503
# [47]	validation_0-logloss:0.38260	validation_1-logloss:0.41466
# [48]	validation_0-logloss:0.38216	validation_1-logloss:0.41465
# [49]	validation_0-logloss:0.38096	validation_1-logloss:0.41395
# [50]	validation_0-logloss:0.38027	validation_1-logloss:0.41339
# [51]	validation_0-logloss:0.37974	validation_1-logloss:0.41342
# [52]	validation_0-logloss:0.37926	validation_1-logloss:0.41325
# [53]	validation_0-logloss:0.37866	validation_1-logloss:0.41284
# [54]	validation_0-logloss:0.37786	validation_1-logloss:0.41216
# [55]	validation_0-logloss:0.37656	validation_1-logloss:0.41148
# [56]	validation_0-logloss:0.37565	validation_1-logloss:0.41094
# [57]	validation_0-logloss:0.37469	validation_1-logloss:0.41066
# [58]	validation_0-logloss:0.37373	validation_1-logloss:0.41039
# [59]	validation_0-logloss:0.37283	validation_1-logloss:0.40951
# [60]	validation_0-logloss:0.37200	validation_1-logloss:0.40894
# [61]	validation_0-logloss:0.37146	validation_1-logloss:0.40870
# [62]	validation_0-logloss:0.37079	validation_1-logloss:0.40822
# [63]	validation_0-logloss:0.37002	validation_1-logloss:0.40798
# [64]	validation_0-logloss:0.36901	validation_1-logloss:0.40744
# [65]	validation_0-logloss:0.36825	validation_1-logloss:0.40721
# [66]	validation_0-logloss:0.36784	validation_1-logloss:0.40702
# [67]	validation_0-logloss:0.36694	validation_1-logloss:0.40685
# [68]	validation_0-logloss:0.36629	validation_1-logloss:0.40666
# [69]	validation_0-logloss:0.36554	validation_1-logloss:0.40656
# [70]	validation_0-logloss:0.36491	validation_1-logloss:0.40646
# [71]	validation_0-logloss:0.36442	validation_1-logloss:0.40619
# [72]	validation_0-logloss:0.36403	validation_1-logloss:0.40594
# [73]	validation_0-logloss:0.36323	validation_1-logloss:0.40571
# [74]	validation_0-logloss:0.36265	validation_1-logloss:0.40537
# [75]	validation_0-logloss:0.36191	validation_1-logloss:0.40514
# [76]	validation_0-logloss:0.36157	validation_1-logloss:0.40489
# [77]	validation_0-logloss:0.36128	validation_1-logloss:0.40493
# [78]	validation_0-logloss:0.36074	validation_1-logloss:0.40474
# [79]	validation_0-logloss:0.36020	validation_1-logloss:0.40442
# [80]	validation_0-logloss:0.35934	validation_1-logloss:0.40413
# [81]	validation_0-logloss:0.35860	validation_1-logloss:0.40363
# [82]	validation_0-logloss:0.35796	validation_1-logloss:0.40330
# [83]	validation_0-logloss:0.35733	validation_1-logloss:0.40291
# [84]	validation_0-logloss:0.35656	validation_1-logloss:0.40250
# [85]	validation_0-logloss:0.35601	validation_1-logloss:0.40249
# [86]	validation_0-logloss:0.35549	validation_1-logloss:0.40216
# [87]	validation_0-logloss:0.35472	validation_1-logloss:0.40223
# [88]	validation_0-logloss:0.35423	validation_1-logloss:0.40211
# [89]	validation_0-logloss:0.35361	validation_1-logloss:0.40190
# [90]	validation_0-logloss:0.35308	validation_1-logloss:0.40196
# [91]	validation_0-logloss:0.35259	validation_1-logloss:0.40200
# [92]	validation_0-logloss:0.35211	validation_1-logloss:0.40198
# [93]	validation_0-logloss:0.35161	validation_1-logloss:0.40162
# [94]	validation_0-logloss:0.35089	validation_1-logloss:0.40141
# [95]	validation_0-logloss:0.35066	validation_1-logloss:0.40138
# [96]	validation_0-logloss:0.34986	validation_1-logloss:0.40117
# [97]	validation_0-logloss:0.34921	validation_1-logloss:0.40076
# [98]	validation_0-logloss:0.34865	validation_1-logloss:0.40072
# [99]	validation_0-logloss:0.34824	validation_1-logloss:0.40052
# [100]	validation_0-logloss:0.34783	validation_1-logloss:0.40052
# [101]	validation_0-logloss:0.34743	validation_1-logloss:0.40034
# [102]	validation_0-logloss:0.34704	validation_1-logloss:0.40042
# [103]	validation_0-logloss:0.34669	validation_1-logloss:0.40041
# [104]	validation_0-logloss:0.34613	validation_1-logloss:0.40021
# [105]	validation_0-logloss:0.34545	validation_1-logloss:0.40024
# [106]	validation_0-logloss:0.34484	validation_1-logloss:0.39995
# [107]	validation_0-logloss:0.34426	validation_1-logloss:0.39985
# [108]	validation_0-logloss:0.34397	validation_1-logloss:0.39998
# [109]	validation_0-logloss:0.34357	validation_1-logloss:0.39985
# [110]	validation_0-logloss:0.34321	validation_1-logloss:0.39994
# [111]	validation_0-logloss:0.34286	validation_1-logloss:0.39983
# [112]	validation_0-logloss:0.34227	validation_1-logloss:0.39980
# [113]	validation_0-logloss:0.34199	validation_1-logloss:0.39967
# [114]	validation_0-logloss:0.34153	validation_1-logloss:0.39937
# [115]	validation_0-logloss:0.34106	validation_1-logloss:0.39943
# [116]	validation_0-logloss:0.34054	validation_1-logloss:0.39904
# [117]	validation_0-logloss:0.34023	validation_1-logloss:0.39891
# [118]	validation_0-logloss:0.33984	validation_1-logloss:0.39873
# [119]	validation_0-logloss:0.33956	validation_1-logloss:0.39856
# [120]	validation_0-logloss:0.33926	validation_1-logloss:0.39854
# [121]	validation_0-logloss:0.33866	validation_1-logloss:0.39868
# [122]	validation_0-logloss:0.33818	validation_1-logloss:0.39841
# [123]	validation_0-logloss:0.33766	validation_1-logloss:0.39821
# [124]	validation_0-logloss:0.33689	validation_1-logloss:0.39850
# [125]	validation_0-logloss:0.33666	validation_1-logloss:0.39833
# [126]	validation_0-logloss:0.33614	validation_1-logloss:0.39834
# [127]	validation_0-logloss:0.33559	validation_1-logloss:0.39825
# [128]	validation_0-logloss:0.33530	validation_1-logloss:0.39830
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#               importance_type='gain', interaction_constraints='',
#               learning_rate=0.2, max_delta_step=0, max_depth=7,
#               min_child_weight=5, missing=nan, monotone_constraints='()',
#               n_estimators=100000, n_jobs=8, nthread=8, num_parallel_tree=1,
#               random_state=42, reg_alpha=5.7, reg_lambda=3.6,
#               scale_pos_weight=1, subsample=1, tree_method='hist',
#               use_label_encoder=False, validate_parameters=1, verbosity=None)

# %%
print(classification_report(model.predict(X_test), y_test['AGN'], digits=4))
print(balanced_accuracy_score(model.predict(X_test), y_test['AGN']))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9385    0.8305    0.8812     10241
#            1     0.4826    0.7440    0.5854      2176
#
#     accuracy                         0.8153     12417
#    macro avg     0.7105    0.7873    0.7333     12417
# weighted avg     0.8586    0.8153    0.8294     12417
#
# 0.7872555197318162

# %% [markdown]
# # Reducing features and seeing accuracy

# %%
# We remove features in sets, in things that are likely to be there
to_be_removed = [['Total_flux', 'Peak_flux'],
                 ['u_flux_corr'],
                 ['z_flux_corr', 'y_flux_corr', 'I_flux_corr', 'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr'],
                 ['ch1_flux_corr', 'ch2_flux_corr'], 
                 ['ch3_flux_corr', 'ch4_flux_corr'],
                 ['F_MIPS_24'],
                 ['F_PACS_100', 'F_PACS_160'],
                 ['F_SPIRE_250', 'F_SPIRE_350', 'F_SPIRE_500']
                ]

# %%
for c in to_be_removed:
    X_removed = X_test.copy()
    X_removed[c] = np.nan
    print(c, balanced_accuracy_score(model.predict(X_removed), y_test['AGN']))
# Out:
# ['Total_flux', 'Peak_flux']
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /var/lib/condor/execute/dir_830810/ipykernel_873943/2937941492.py in <module>
#       3     X_removed[c] = np.nan
#       4     print(c)
# ----> 5     print(c, balanced_accuracy_score(model.predict(X_removed), y_test['AGN']))
#
# ~/.local/lib/python3.9/site-packages/xgboost/sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features, base_margin)
#     968         if ntree_limit is None:
#     969             ntree_limit = getattr(self, "best_ntree_limit", 0)
# --> 970         class_probs = self.get_booster().predict(
#     971             test_dmatrix,
#     972             output_margin=output_margin,
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in predict(self, data, output_margin, ntree_limit, pred_leaf, pred_contribs, approx_contribs, pred_interactions, validate_features, training)
#    1483
#    1484         if validate_features:
# -> 1485             self._validate_features(data)
#    1486
#    1487         length = c_bst_ulong()
#
# ~/.local/lib/python3.9/site-packages/xgboost/core.py in _validate_features(self, data)
#    2058                             ', '.join(str(s) for s in my_missing))
#    2059
# -> 2060                 raise ValueError(msg.format(self.feature_names,
#    2061                                             data.feature_names))
#    2062
#
# ValueError: feature_names mismatch: ['NUV_flux_corr', 'u_flux_corr', 'Bw_flux_corr', 'R_flux_corr', 'I_flux_corr', 'z_flux_corr', 'y_flux_corr', 'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr', 'ch1_flux_corr', 'ch2_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr', 'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350', 'F_SPIRE_500', 'Z_BEST', 'g_flux_corr', 'nb921_hsc_flux_corr'] ['Total_flux', 'Peak_flux', 'NUV_flux_corr', 'u_flux_corr', 'Bw_flux_corr', 'R_flux_corr', 'I_flux_corr', 'z_flux_corr', 'y_flux_corr', 'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr', 'ch1_flux_corr', 'ch2_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr', 'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350', 'F_SPIRE_500', 'Z_BEST', 'g_flux_corr', 'nb921_hsc_flux_corr']
# training data did not have the following fields: Peak_flux, Total_flux

# %% [markdown]
# # BH stuff

# %%
model = XGBClassifier(use_label_encoder=False, 
                      max_depth=1,
                     #min_child_weight=5,
                     #learning_rate=0.2,
                     #reg_alpha=5.7,
                     #reg_lambda=3.6,
                     tree_method='hist',
                     objective='binary:logistic',
                     eval_metric=['error'],
                     #scale_pos_weight=frac,
                      nthread=8,
                      n_estimators=10**5,
                      random_state=42
                      )

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y[['AGN', 'Source']], train_size=0.8, stratify=y[['AGN', 'Source']])
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, train_size=0.8, stratify=y_test)

# %%
eval_set = [(X_train, y_train['AGN']), (Best_Heckman_X, Best_Heckman_y['AGN']), (X_val, y_val['AGN'])]

# %%
model.fit(X_train, y_train['AGN'], verbose=True, eval_set=eval_set, early_stopping_rounds=5)
# Out:
# [0]	validation_0-error:0.22132	validation_1-error:0.77868	validation_2-error:0.22576
# [1]	validation_0-error:0.24031	validation_1-error:0.77868	validation_2-error:0.24283
# [2]	validation_0-error:0.22132	validation_1-error:0.77868	validation_2-error:0.22576
# [3]	validation_0-error:0.20861	validation_1-error:0.42554	validation_2-error:0.21256
# [4]	validation_0-error:0.20521	validation_1-error:0.42554	validation_2-error:0.20837
# [5]	validation_0-error:0.19811	validation_1-error:0.42554	validation_2-error:0.20000
# [6]	validation_0-error:0.20983	validation_1-error:0.42554	validation_2-error:0.21385
# [7]	validation_0-error:0.19592	validation_1-error:0.42554	validation_2-error:0.19807
# [8]	validation_0-error:0.19281	validation_1-error:0.42554	validation_2-error:0.19678
# [9]	validation_0-error:0.19281	validation_1-error:0.42554	validation_2-error:0.19678
# [10]	validation_0-error:0.18877	validation_1-error:0.41985	validation_2-error:0.19549
# [11]	validation_0-error:0.19304	validation_1-error:0.42554	validation_2-error:0.20064
# [12]	validation_0-error:0.18820	validation_1-error:0.42554	validation_2-error:0.19710
# [13]	validation_0-error:0.18965	validation_1-error:0.42554	validation_2-error:0.19839
# [14]	validation_0-error:0.18872	validation_1-error:0.42554	validation_2-error:0.19485
# [15]	validation_0-error:0.19001	validation_1-error:0.41985	validation_2-error:0.20000
# [16]	validation_0-error:0.18609	validation_1-error:0.41985	validation_2-error:0.19517
# [17]	validation_0-error:0.18521	validation_1-error:0.42554	validation_2-error:0.19614
# [18]	validation_0-error:0.18257	validation_1-error:0.42554	validation_2-error:0.19292
# [19]	validation_0-error:0.18213	validation_1-error:0.42554	validation_2-error:0.19098
# [20]	validation_0-error:0.18183	validation_1-error:0.42554	validation_2-error:0.19163
# [21]	validation_0-error:0.18067	validation_1-error:0.42554	validation_2-error:0.19227
# [22]	validation_0-error:0.17968	validation_1-error:0.42554	validation_2-error:0.19259
# [23]	validation_0-error:0.17804	validation_1-error:0.42554	validation_2-error:0.18808
# [24]	validation_0-error:0.17735	validation_1-error:0.42554	validation_2-error:0.18969
# [25]	validation_0-error:0.17704	validation_1-error:0.42554	validation_2-error:0.18679
# [26]	validation_0-error:0.17627	validation_1-error:0.42554	validation_2-error:0.18679
# [27]	validation_0-error:0.17675	validation_1-error:0.42554	validation_2-error:0.18712
# [28]	validation_0-error:0.17490	validation_1-error:0.42554	validation_2-error:0.18454
# [29]	validation_0-error:0.17445	validation_1-error:0.42539	validation_2-error:0.18454
# [30]	validation_0-error:0.17380	validation_1-error:0.42554	validation_2-error:0.18454
# [31]	validation_0-error:0.17464	validation_1-error:0.42554	validation_2-error:0.18261
# [32]	validation_0-error:0.17406	validation_1-error:0.42554	validation_2-error:0.18551
# [33]	validation_0-error:0.17514	validation_1-error:0.42554	validation_2-error:0.18808
# [34]	validation_0-error:0.17310	validation_1-error:0.42554	validation_2-error:0.18196
# [35]	validation_0-error:0.17422	validation_1-error:0.42554	validation_2-error:0.18647
# [36]	validation_0-error:0.17169	validation_1-error:0.42949	validation_2-error:0.18422
# [37]	validation_0-error:0.17210	validation_1-error:0.42949	validation_2-error:0.18068
# [38]	validation_0-error:0.17139	validation_1-error:0.42949	validation_2-error:0.18261
# [39]	validation_0-error:0.17118	validation_1-error:0.42949	validation_2-error:0.18132
# [40]	validation_0-error:0.17083	validation_1-error:0.42949	validation_2-error:0.18132
# [41]	validation_0-error:0.17039	validation_1-error:0.42949	validation_2-error:0.18003
# [42]	validation_0-error:0.16986	validation_1-error:0.42949	validation_2-error:0.18003
# [43]	validation_0-error:0.16936	validation_1-error:0.42934	validation_2-error:0.18132
# [44]	validation_0-error:0.16904	validation_1-error:0.42949	validation_2-error:0.17971
# [45]	validation_0-error:0.16886	validation_1-error:0.42949	validation_2-error:0.17874
# [46]	validation_0-error:0.16884	validation_1-error:0.42949	validation_2-error:0.18068
# [47]	validation_0-error:0.16921	validation_1-error:0.42949	validation_2-error:0.18229
# [48]	validation_0-error:0.16783	validation_1-error:0.42949	validation_2-error:0.17939
# [49]	validation_0-error:0.16838	validation_1-error:0.42949	validation_2-error:0.18068
# [50]	validation_0-error:0.16735	validation_1-error:0.43299	validation_2-error:0.17681
# [51]	validation_0-error:0.16686	validation_1-error:0.43299	validation_2-error:0.17585
# [52]	validation_0-error:0.16672	validation_1-error:0.42949	validation_2-error:0.17649
# [53]	validation_0-error:0.16636	validation_1-error:0.42949	validation_2-error:0.17552
# [54]	validation_0-error:0.16585	validation_1-error:0.42942	validation_2-error:0.17520
# [55]	validation_0-error:0.16659	validation_1-error:0.42942	validation_2-error:0.17359
# [56]	validation_0-error:0.16638	validation_1-error:0.42942	validation_2-error:0.17424
# [57]	validation_0-error:0.16564	validation_1-error:0.42942	validation_2-error:0.17456
# [58]	validation_0-error:0.16548	validation_1-error:0.42942	validation_2-error:0.17424
# [59]	validation_0-error:0.16514	validation_1-error:0.42942	validation_2-error:0.17424
# [60]	validation_0-error:0.16480	validation_1-error:0.42942	validation_2-error:0.17327
# [61]	validation_0-error:0.16403	validation_1-error:0.42942	validation_2-error:0.17295
# [62]	validation_0-error:0.16408	validation_1-error:0.42949	validation_2-error:0.17327
# [63]	validation_0-error:0.16356	validation_1-error:0.42942	validation_2-error:0.17166
# [64]	validation_0-error:0.16390	validation_1-error:0.43299	validation_2-error:0.17069
# [65]	validation_0-error:0.16358	validation_1-error:0.42942	validation_2-error:0.17327
# [66]	validation_0-error:0.16324	validation_1-error:0.43246	validation_2-error:0.17327
# [67]	validation_0-error:0.16272	validation_1-error:0.43246	validation_2-error:0.17327
# [68]	validation_0-error:0.16239	validation_1-error:0.42942	validation_2-error:0.17263
# [69]	validation_0-error:0.16209	validation_1-error:0.43246	validation_2-error:0.17359
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, eval_metric=['error'],
#               gamma=0, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.300000012,
#               max_delta_step=0, max_depth=1, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100000, n_jobs=8,
#               nthread=8, num_parallel_tree=1, random_state=42, reg_alpha=0,
#               reg_lambda=1, scale_pos_weight=1, subsample=1, tree_method='hist',
#               use_label_encoder=False, validate_parameters=1, verbosity=None)

# %%
print(classification_report(model.predict(X_test), y_test['AGN'], digits=4))
print(balanced_accuracy_score(model.predict(X_test), y_test['AGN']))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.9427    0.8657    0.9026      9868
#            1     0.6051    0.7964    0.6877      2549
#
#     accuracy                         0.8515     12417
#    macro avg     0.7739    0.8311    0.7951     12417
# weighted avg     0.8734    0.8515    0.8585     12417
#
# 0.8310591729225144

# %%
import lightgbm as lgb

param = {'n_estimators': 172,
         'num_leaves': 1011,
         'min_child_samples': 16, 
         'objective': 'binary',
         'log_max_bin': 9,
         'colsample_bytree': 0.46
        }

# %%
train_data = lgb.Dataset(X_train, label=y_train['AGN'])
validation_data = lgb.Dataset(X_val, label=y_val['AGN'])
Best_heckman = lgb.Dataset(Best_Heckman_X, label=Best_Heckman_y['AGN'])

# %%
bst = lgb.train(param, train_data, 200, valid_sets=[validation_data], early_stopping_rounds=5)
# Out:
# [LightGBM] [Warning] Unknown parameter: log_max_bin
# [LightGBM] [Warning] Unknown parameter: log_max_bin
# [LightGBM] [Info] Number of positive: 16775, number of negative: 45312
# [LightGBM] [Warning] Auto-choosing row-wise multi-threading, the overhead of testing was 0.010701 seconds.
# You can set `force_row_wise=true` to remove the overhead.
# And if memory is not enough, you can set `force_col_wise=true`.
# [LightGBM] [Info] Total Bins 6630
# [LightGBM] [Info] Number of data points in the train set: 62087, number of used features: 26
# [LightGBM] [Warning] Unknown parameter: log_max_bin
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.270185 -> initscore=-0.993682
# [LightGBM] [Info] Start training from score -0.993682
# [1]	valid_0's binary_logloss: 0.540279
# Training until validation scores don't improve for 5 rounds
# [2]	valid_0's binary_logloss: 0.52001
# [3]	valid_0's binary_logloss: 0.499769
# [4]	valid_0's binary_logloss: 0.486583
# [5]	valid_0's binary_logloss: 0.461765
# [6]	valid_0's binary_logloss: 0.446977
# [7]	valid_0's binary_logloss: 0.431922
# [8]	valid_0's binary_logloss: 0.414111
# [9]	valid_0's binary_logloss: 0.397067
# [10]	valid_0's binary_logloss: 0.383478
# [11]	valid_0's binary_logloss: 0.376457
# [12]	valid_0's binary_logloss: 0.364047
# [13]	valid_0's binary_logloss: 0.353483
# [14]	valid_0's binary_logloss: 0.345396
# [15]	valid_0's binary_logloss: 0.337749
# [16]	valid_0's binary_logloss: 0.330596
# [17]	valid_0's binary_logloss: 0.324469
# [18]	valid_0's binary_logloss: 0.319877
# [19]	valid_0's binary_logloss: 0.313568
# [20]	valid_0's binary_logloss: 0.309742
# [21]	valid_0's binary_logloss: 0.306666
# [22]	valid_0's binary_logloss: 0.302963
# [23]	valid_0's binary_logloss: 0.299912
# [24]	valid_0's binary_logloss: 0.297913
# [25]	valid_0's binary_logloss: 0.292658
# [26]	valid_0's binary_logloss: 0.290347
# [27]	valid_0's binary_logloss: 0.288291
# [28]	valid_0's binary_logloss: 0.286101
# [29]	valid_0's binary_logloss: 0.285741
# [30]	valid_0's binary_logloss: 0.283675
# [31]	valid_0's binary_logloss: 0.280493
# [32]	valid_0's binary_logloss: 0.278465
# [33]	valid_0's binary_logloss: 0.275606
# [34]	valid_0's binary_logloss: 0.273706
# [35]	valid_0's binary_logloss: 0.272886
# [36]	valid_0's binary_logloss: 0.272
# [37]	valid_0's binary_logloss: 0.269342
# [38]	valid_0's binary_logloss: 0.268011
# [39]	valid_0's binary_logloss: 0.265085
# [40]	valid_0's binary_logloss: 0.264477
# [41]	valid_0's binary_logloss: 0.262518
# [42]	valid_0's binary_logloss: 0.261076
# [43]	valid_0's binary_logloss: 0.2588
# [44]	valid_0's binary_logloss: 0.257922
# [45]	valid_0's binary_logloss: 0.257874
# [46]	valid_0's binary_logloss: 0.257435
# [47]	valid_0's binary_logloss: 0.256756
# [48]	valid_0's binary_logloss: 0.256484
# [49]	valid_0's binary_logloss: 0.254427
# [50]	valid_0's binary_logloss: 0.253369
# [51]	valid_0's binary_logloss: 0.253621
# [52]	valid_0's binary_logloss: 0.253763
# [53]	valid_0's binary_logloss: 0.253219
# [54]	valid_0's binary_logloss: 0.253006
# [55]	valid_0's binary_logloss: 0.253074
# [56]	valid_0's binary_logloss: 0.252958
# [57]	valid_0's binary_logloss: 0.252306
# [58]	valid_0's binary_logloss: 0.252232
# [59]	valid_0's binary_logloss: 0.252262
# [60]	valid_0's binary_logloss: 0.252326
# [61]	valid_0's binary_logloss: 0.252538
# [62]	valid_0's binary_logloss: 0.252728
# [63]	valid_0's binary_logloss: 0.252405
# Early stopping, best iteration is:
# [58]	valid_0's binary_logloss: 0.252232

# %%
# Out:
# array([1., 0., 0., ..., 0., 0., 0.])

# %%
print(classification_report(np.rint(bst.predict(Best_Heckman_X)), Best_Heckman_y['AGN'], digits=4))
print(balanced_accuracy_score(np.rint(bst.predict(Best_Heckman_X)), Best_Heckman_y['AGN']))
# Out:
#               precision    recall  f1-score   support
#
#          0.0     0.7085    0.5656    0.6291      3649
#          1.0     0.8454    0.9108    0.8768      9513
#
#     accuracy                         0.8151     13162
#    macro avg     0.7769    0.7382    0.7530     13162
# weighted avg     0.8074    0.8151    0.8081     13162
#
# 0.73819406292242

# %%
Best_Heckman_data = pd.read_csv("../../../Data/Best&Heckman/BestHeckman+SDSS+wise+LOFAR_better_fixed_fluxes.csv")
Best_Heckman_data['Source'] = 'BH'

# %%
# Only selecting data with a classification
Best_Heckman_data = Best_Heckman_data[Best_Heckman_data['Classification'] != 'Radio-loud AGN']

# %%
Best_Heckman_X = Best_Heckman_data[[c for c in Best_Heckman_data.columns if c != 'Classification']]
Best_Heckman_y = Best_Heckman_data[['Classification', 'Source']]

# %%
Best_Heckman_X = Best_Heckman_X[['Z_BEST', 'u_flux_corr',
       'g_flux_corr', 'R_flux_corr', 'I_flux_corr', 'z_flux_corr', 'ch1_flux_corr', 'ch2_flux_corr',
       'J_flux_corr', 'H_flux_corr', 'Ks_flux_corr', 'Peak_flux', 'Total_flux']]

# Adding nans to missing columns
Best_Heckman_X[['NUV_flux_corr', 'Bw_flux_corr', 'y_flux_corr', 'K_flux_corr', 
                'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350',
                'F_SPIRE_500', 'nb921_hsc_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr', 'FUV_flux_corr']] = np.nan

# %%
Best_Heckman_y['AGN'] =  Best_Heckman_y.apply(AGN, axis=1, result_type='expand')
# Out:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
Best_Heckman_X = Best_Heckman_X[features_num]

# %%
filt = ~Best_Heckman_X['Total_flux'].isna()

# %%
print(classification_report(model.predict(Best_Heckman_X), Best_Heckman_y['AGN'], digits=4))
print(balanced_accuracy_score(model.predict(Best_Heckman_X), Best_Heckman_y['AGN']))
# Out:
#               precision    recall  f1-score   support
#
#            0     0.1593    0.2094    0.1809      2216
#            1     0.8291    0.7763    0.8018     10946
#
#     accuracy                         0.6808     13162
#    macro avg     0.4942    0.4928    0.4914     13162
# weighted avg     0.7163    0.6808    0.6973     13162
#
# 0.492825791991008
