# %%
import pandas as pd
import numpy as np

from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder
from sklearn.impute import SimpleImputer, KNNImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import make_column_transformer
from sklearn import preprocessing
from sklearn.linear_model import LinearRegression
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from sklearn import svm
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight

import matplotlib.pyplot as plt

from xgboost import XGBClassifier


# Necessary to get names out
SimpleImputer.get_feature_names_out = (lambda self, names=None:
                                       self.feature_names_in_)

# %%
features_num = ['Z_BEST', 'z1_median', 'u_f', 'u_e', 'u_e_raw', 'Bw_f', 'Bw_e', 'Bw_e_raw', 'R_f', 
                'R_e', 'R_e_raw', 'I_f', 'I_e', 'I_e_raw', 'z_f', 'z_e', 'z_e_raw', 'z_Subaru_f', 
                'z_Subaru_e', 'z_Subaru_e_raw', 'y_f', 'y_e', 'y_e_raw', 'J_f', 'J_e', 'J_e_raw', 
                'H_f', 'H_e', 'H_e_raw', 'K_f', 'K_e', 'K_e_raw', 'Ks_f', 'Ks_e', 'Ks_e_raw', 'ch1_f', 
                'ch1_e', 'ch1_e_raw', 'ch2_f', 'ch2_e', 'ch2_e_raw', 'ch3_f', 'ch3_e', 'ch3_e_raw', 'ch4_f', 
                'ch4_e', 'ch4_e_raw', 'MIPS_24_f', 'MIPS_24_e', 'MIPS_24_e_raw', 'PACS_100_f', 'PACS_100_e', 
                'PACS_100_e_raw', 'PACS_160_f', 'PACS_160_e', 'PACS_160_e_raw', 'SPIRE_250_f', 'SPIRE_250_e', 
                'SPIRE_250_e_raw', 'SPIRE_350_f', 'SPIRE_350_e', 'SPIRE_350_e_raw', 'SPIRE_500_f', 'SPIRE_500_e', 
                'SPIRE_500_e_raw', 'g_f', 'g_e', 'g_e_raw', 'r_f', 'r_e', 'r_e_raw', 'i_f', 'i_e', 'i_e_raw', 
                'g_hsc_f', 'g_hsc_e', 'g_hsc_e_raw', 'r_hsc_f', 'r_hsc_e', 'r_hsc_e_raw', 'i_hsc_f', 'i_hsc_e', 
                'i_hsc_e_raw', 'z_hsc_f', 'z_hsc_e', 'z_hsc_e_raw', 'y_hsc_f', 'y_hsc_e', 'y_hsc_e_raw', 'nb921_hsc_f', 
                'nb921_hsc_e', 'nb921_hsc_e_raw', 'ch1_swire_f', 'ch1_swire_e', 'ch1_swire_e_raw', 'ch2_swire_f', 
                'ch2_swire_e', 'ch2_swire_e_raw', 'ch3_swire_f', 'ch3_swire_e', 'ch3_swire_e_raw', 'ch4_swire_f', 
                'ch4_swire_e', 'ch4_swire_e_raw', 'ch1_servs_f', 'ch1_servs_e', 'ch1_servs_e_raw', 'ch2_servs_f', 
                'ch2_servs_e', 'ch2_servs_e_raw', 'g_rcs_f', 'g_rcs_e', 'g_rcs_e_raw', 'r_rcs_f', 'r_rcs_e', 
                'r_rcs_e_raw', 'i_rcs_f', 'i_rcs_e', 'i_rcs_e_raw', 'z_rcs_f', 'z_rcs_e', 'z_rcs_e_raw']
features_cat_binary = [
    "FLAG_OVERLAP", "XID+_rerun_mips", "XID+_rerun_pacs", "XID+_rerun_SPIRE", "CHANGE_FLAG_ID", 
    "CHANGE_FLAG_ZBEST", "CHANGE_FLAG_DEEP", "CHANGE_FLAG_FIR", "FLAG_GOOD"
]
features_cat_non_binary = [
    "FLAG_DEEP"
]
features_drop = [
    "Source_Name"
]
y_column = "Classification"

classes = ['jet-mode radio AGN/low-excitation radio galaxy', 'quasar-like radio AGN / high-excitation radio galaxy', 
           'radio-quiet AGN', 'star-forming galaxy']

# %%
# Creating the pipeline
transformer_num = make_pipeline(
    SimpleImputer(strategy="mean"),  # there are a few missing values
    StandardScaler(),
)
# Almost all cat features are already binary, so don't have to be one-hot encoded
transformer_cat_binary = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
)
transformer_cat_non_binary = make_pipeline(
    SimpleImputer(strategy="most_frequent"),
    OneHotEncoder(sparse=False)
)

preprocessor = make_column_transformer(
    (transformer_num, features_num),
    (transformer_cat_binary, features_cat_binary),
    (transformer_cat_non_binary, features_cat_non_binary),
)

# %%
data = pd.read_csv("../../Data/Fangyou_data/Cleaned/Combined.csv")

# %%
# Dropping required columns
X = data.drop(columns=features_drop)
X = X.drop(columns=y_column)
y = data[y_column]

# %%
# Transforming y to labels
le = preprocessing.LabelEncoder()
labels = np.unique(y)
y = le.fit_transform(y)

# Creating training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.7)

# %%
# Transforming the data
X_train = preprocessor.fit_transform(X_train)
X_test = preprocessor.transform(X_test)

# %%
# Class weights
class_weight = compute_class_weight(class_weight='balanced', classes=np.unique(y_train), y=y_train)

# %% [markdown]
# # PCA

# %%
pca = PCA().fit(X_train)

# %%
explained_variance = pca.explained_variance_ratio_
plt.figure(figsize=(10,10))
plt.bar(range(len(explained_variance)),explained_variance)
plt.title("Explained vaiance")
plt.show()

# %%
plt.figure(figsize=(10,10))
plt.bar(range(len(explained_variance)),explained_variance.cumsum())
plt.title("Explained cumulative variance")
plt.show()

# %% [markdown]
# # Random forest

# %%
clf = RandomForestClassifier(n_estimators=100, class_weight="balanced")
clf.fit(X_train, y_train)
# Out:
# RandomForestClassifier(class_weight='balanced')

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.8495    0.5217    0.6464      3753
# quasar-like radio AGN / high-excitation radio galaxy     0.4706    0.0198    0.0379       405
#                                      radio-quiet AGN     0.7625    0.5045    0.6073      1992
#                                  star-forming galaxy     0.8481    0.9723    0.9060     17133
#
#                                             accuracy                         0.8431     23283
#                                            macro avg     0.7327    0.5046    0.5494     23283
#                                         weighted avg     0.8344    0.8431    0.8235     23283

# %%
cm = confusion_matrix(y_test, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %%
random_forest_feature_importance = pd.DataFrame(
    np.array([preprocessor.get_feature_names_out(), clf.feature_importances_]).T,
                                               columns=['Feature', 'Importance'])
random_forest_feature_importance = random_forest_feature_importance.sort_values(by=['Importance'], ascending=False)

# %%
ax = random_forest_feature_importance.plot(kind='bar', figsize=(20,10))
ax.set_xticklabels(random_forest_feature_importance.Feature)
plt.plot()
# Out:
# []

# %% [markdown]
# ## Hyperparameter tuning

# %%
# Metrics for hyperparameter tuning
metrics = {"Accuracy": "accuracy",
          "Balanced accuracy": "balanced_accuracy",
          "F1 score": "f1_weighted"}

# %%
# Parameter space
parameters = {"n_estimators": [10,20,50,100,150,200],
             "criterion": ["gini", "entropy"],
             "max_depth": [10,30,50,70],
             "min_samples_split": [2,10,20],
             }

# %%
random_forest = RandomForestClassifier()
clf = GridSearchCV(estimator=random_forest, 
                   param_grid=parameters,
                  scoring=metrics,
                  refit="Accuracy",
                  return_train_score=True,
                  n_jobs=-1,
                  cv=2,
                  verbose=4)

clf.fit(X_train, y_train)
# Out:
# Fitting 2 folds for each of 144 candidates, totalling 288 fits
# KeyboardInterrupt

# %%
clf

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))

# %% [markdown]
# # XGboost

# %%
model = XGBClassifier(use_label_encoder=False, max_depth=7)
model.fit(X_train, y_train, early_stopping_rounds=10, eval_set=[(X_test, y_test)], verbose=True)
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\sklearn.py:793: UserWarning: `early_stopping_rounds` in `fit` method is deprecated for better compatibility with scikit-learn, use `early_stopping_rounds` in constructor or`set_params` instead.
#   warnings.warn(
# [0]	validation_0-mlogloss:1.04769
# [1]	validation_0-mlogloss:0.85802
# [2]	validation_0-mlogloss:0.73533
# [3]	validation_0-mlogloss:0.64993
# [4]	validation_0-mlogloss:0.59116
# [5]	validation_0-mlogloss:0.54775
# [6]	validation_0-mlogloss:0.51587
# [7]	validation_0-mlogloss:0.49074
# [8]	validation_0-mlogloss:0.47244
# [9]	validation_0-mlogloss:0.45838
# [10]	validation_0-mlogloss:0.44727
# [11]	validation_0-mlogloss:0.43752
# [12]	validation_0-mlogloss:0.43080
# [13]	validation_0-mlogloss:0.42496
# [14]	validation_0-mlogloss:0.41985
# [15]	validation_0-mlogloss:0.41561
# [16]	validation_0-mlogloss:0.41159
# [17]	validation_0-mlogloss:0.40874
# [18]	validation_0-mlogloss:0.40655
# [19]	validation_0-mlogloss:0.40469
# [20]	validation_0-mlogloss:0.40293
# [21]	validation_0-mlogloss:0.40172
# [22]	validation_0-mlogloss:0.40096
# [23]	validation_0-mlogloss:0.39936
# [24]	validation_0-mlogloss:0.39877
# [25]	validation_0-mlogloss:0.39822
# [26]	validation_0-mlogloss:0.39687
# [27]	validation_0-mlogloss:0.39576
# [28]	validation_0-mlogloss:0.39501
# [29]	validation_0-mlogloss:0.39444
# [30]	validation_0-mlogloss:0.39387
# [31]	validation_0-mlogloss:0.39339
# [32]	validation_0-mlogloss:0.39308
# [33]	validation_0-mlogloss:0.39302
# [34]	validation_0-mlogloss:0.39278
# [35]	validation_0-mlogloss:0.39270
# [36]	validation_0-mlogloss:0.39266
# [37]	validation_0-mlogloss:0.39212
# [38]	validation_0-mlogloss:0.39201
# [39]	validation_0-mlogloss:0.39178
# [40]	validation_0-mlogloss:0.39168
# [41]	validation_0-mlogloss:0.39168
# [42]	validation_0-mlogloss:0.39148
# [43]	validation_0-mlogloss:0.39156
# [44]	validation_0-mlogloss:0.39089
# [45]	validation_0-mlogloss:0.39038
# [46]	validation_0-mlogloss:0.39041
# [47]	validation_0-mlogloss:0.39034
# [48]	validation_0-mlogloss:0.39049
# [49]	validation_0-mlogloss:0.39017
# [50]	validation_0-mlogloss:0.39033
# [51]	validation_0-mlogloss:0.38973
# [52]	validation_0-mlogloss:0.38953
# [53]	validation_0-mlogloss:0.38943
# [54]	validation_0-mlogloss:0.38909
# [55]	validation_0-mlogloss:0.38895
# [56]	validation_0-mlogloss:0.38898
# [57]	validation_0-mlogloss:0.38881
# [58]	validation_0-mlogloss:0.38902
# [59]	validation_0-mlogloss:0.38865
# [60]	validation_0-mlogloss:0.38870
# [61]	validation_0-mlogloss:0.38889
# [62]	validation_0-mlogloss:0.38887
# [63]	validation_0-mlogloss:0.38879
# [64]	validation_0-mlogloss:0.38856
# [65]	validation_0-mlogloss:0.38849
# [66]	validation_0-mlogloss:0.38838
# [67]	validation_0-mlogloss:0.38839
# [68]	validation_0-mlogloss:0.38851
# [69]	validation_0-mlogloss:0.38863
# [70]	validation_0-mlogloss:0.38877
# [71]	validation_0-mlogloss:0.38895
# [72]	validation_0-mlogloss:0.38869
# [73]	validation_0-mlogloss:0.38884
# [74]	validation_0-mlogloss:0.38878
# [75]	validation_0-mlogloss:0.38869
# XGBClassifier(base_score=0.5, booster='gbtree', callbacks=None,
#               colsample_bylevel=1, colsample_bynode=1, colsample_bytree=1,
#               early_stopping_rounds=None, enable_categorical=False,
#               eval_metric=None, gamma=0, gpu_id=-1, grow_policy='depthwise',
#               importance_type=None, interaction_constraints='',
#               learning_rate=0.300000012, max_bin=256, max_cat_to_onehot=4,
#               max_delta_step=0, max_depth=7, max_leaves=0, min_child_weight=1,
#               missing=nan, monotone_constraints='()', n_estimators=100,
#               n_jobs=0, num_parallel_tree=1, objective='multi:softprob',
#               predictor='auto', random_state=0, reg_alpha=0, ...)

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.7952    0.6227    0.6984      3753
# quasar-like radio AGN / high-excitation radio galaxy     0.4507    0.0790    0.1345       405
#                                      radio-quiet AGN     0.7092    0.6662    0.6870      1992
#                                  star-forming galaxy     0.8848    0.9504    0.9164     17133
#
#                                             accuracy                         0.8581     23283
#                                            macro avg     0.7100    0.5796    0.6091     23283
#                                         weighted avg     0.8478    0.8581    0.8481     23283

# %%
cm = confusion_matrix(y_test, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []

# %% [markdown]
# # SVM

# %%
clf = svm.SVC()
clf.fit(X_train, y_train)
# Out:
# SVC()

# %%
y_pred = clf.predict(X_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.8363    0.3648    0.5080      3753
# quasar-like radio AGN / high-excitation radio galaxy     0.0000    0.0000    0.0000       405
#                                      radio-quiet AGN     0.7585    0.2681    0.3961      1992
#                                  star-forming galaxy     0.8053    0.9844    0.8859     17133
#
#                                             accuracy                         0.8061     23283
#                                            macro avg     0.6000    0.4043    0.4475     23283
#                                         weighted avg     0.7923    0.8061    0.7677     23283
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\sklearn\metrics\_classification.py:1318: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
cm = confusion_matrix(y_test, y_pred, normalize='true')
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=labels)
disp.plot()
plt.xticks(rotation = 90)
plt.plot()
# Out:
# []
