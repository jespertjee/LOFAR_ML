# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.preprocessing import MinMaxScaler, LabelEncoder
from sklearn.metrics import accuracy_score, classification_report
from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

from xgboost import XGBClassifier, XGBRegressor
import xgboost as xgb

# %% [markdown]
# ## Importing data

# %%
features_num = [
    'Total_flux', 'Peak_flux', 'FUV_flux_corr', 'NUV_flux_corr', 'g_flux_corr', 'r_flux_corr', 'i_flux_corr',
    'z_flux_corr', 'y_flux_corr', 'g_hsc_flux_corr', 'r_hsc_flux_corr', 'i_hsc_flux_corr', 'z_hsc_flux_corr',
    'y_hsc_flux_corr', 'nb921_hsc_flux_corr', 'J_flux_corr', 'K_flux_corr', 'ch1_swire_flux_corr', 
    'ch2_swire_flux_corr', 'ch3_swire_flux_corr', 'ch4_swire_flux_corr', 'ch1_servs_flux_corr', 'ch2_servs_flux_corr',
    'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350', 'F_SPIRE_500', 'Z_BEST', 'EBV'
    ]
statmorph_features = ['xc_centroid', 'yc_centroid', 'ellipticity_centroid',
       'elongation_centroid', 'orientation_centroid', 'xc_asymmetry',
       'yc_asymmetry', 'ellipticity_asymmetry', 'elongation_asymmetry',
       'orientation_asymmetry', 'r20', 'r50', 'r80', 'rhalf_circ',
       'rhalf_ellip', 'rmax_circ', 'rmax_ellip', 'rpetro_circ', 'rpetro_ellip',
       'C', 'A', 'S', 'M20', 'Gini', 'F(G,M20)', 'S(G,M20)', 'deviation',
       'shape_asymmetry', 'outer_asymmetry', 'multimode', 'sn_per_pixel',
       'flux_circ', 'flux_ellip', 'intensity', 'sersic_xc', 'sersic_yc',
       'sersic_amplitude', 'sersic_ellip', 'sersic_n', 'sersic_rhalf',
       'sersic_theta', 'sky_mean', 'sky_median', 'sky_sigma', 'nx_stamp',
       'ny_stamp', 'xmax_stamp', 'xmin_stamp', 'ymax_stamp', 'ymin_stamp',
       'flag', 'flag_sersic']
y_column = "Classification"

classes = ['jet-mode radio AGN/low-excitation radio galaxy', 'quasar-like radio AGN / high-excitation radio galaxy', 
           'radio-quiet AGN', 'star-forming galaxy']

# %%
# Loading data, Only selecting ELais-N1, since we do not have statmorph data on the others
data = pd.read_csv("../../../Data/Fangyou_data/Cleaned/Elais-N1.csv")

# Loading statmorph data
statmorph_data = pd.read_csv("../../../General/Fangyou/HSC_images/statmorph.dat", sep=' ')
statmorph_data.ID = statmorph_data.ID.str[0:-5]

# Only selecting ids where we have statmorph data for
data = data[data['Source_Name'].isin(statmorph_data.ID)]

# %%
# Normal data without statmorph features
X_normal = data[features_num]
y = data[y_column]

# Label encoding y
le = LabelEncoder()
labels = np.unique(y.astype(str))
y = le.fit_transform(y)

X_normal_train, X_normal_test, y_train, y_test =\
    train_test_split(X_normal, y, train_size=0.75, stratify=y, random_state=42)

# %%
combined_data = data.merge(statmorph_data, left_on='Source_Name', right_on='ID')
# Out:
#                   Source_Name          RA        DEC   Total_flux  \
# 0      ILTJ155957.58+550052.4  239.989902  55.014560   395.834521
# 1      ILTJ155958.25+550105.3  239.992724  55.018160   735.574774
# 2      ILTJ155958.68+550534.6  239.994484  55.092971   196.988095
# 3      ILTJ160000.65+550723.3  240.002697  55.123141   195.907800
# 4      ILTJ160001.30+550713.3  240.005426  55.120372   170.575808
# ...                       ...         ...        ...          ...
# 20150  ILTJ162211.32+550612.5  245.547149  55.103485   480.598455
# 20151  ILTJ162213.96+550907.3  245.558179  55.152042   582.153970
# 20152  ILTJ162214.42+550646.2  245.560101  55.112845  1603.159656
# 20153  ILTJ162218.30+545744.2  245.576261  54.962279   153.220502
# 20154  ILTJ162219.25+545913.5  245.580201  54.987082   255.904090
#
#        E_Total_flux   Peak_flux  E_Peak_flux S_Code       EBV  FUV_flux_corr  \
# 0          0.000054  324.796395     0.000027      S  0.008792            NaN
# 1          0.000059  557.217365     0.000028      S  0.008780       0.144002
# 2          0.000054  145.972469     0.000024      S  0.008420       1.259824
# 3          0.000056  140.977168     0.000025      S  0.008466       0.346457
# 4          0.000043  168.803311     0.000025      S  0.008482       0.043996
# ...             ...         ...          ...    ...       ...            ...
# 20150      0.000076  304.736496     0.000032      S  0.008023       0.699567
# 20151      0.000051  499.840837     0.000027      S  0.008016       3.220747
# 20152      0.000082  863.365329     0.000030      M  0.007905       3.183800
# 20153      0.000049  130.011489     0.000024      S  0.008061       0.603581
# 20154      0.000056  196.749375     0.000027      S  0.007824       0.393618
#
#        ...  sky_median  sky_sigma  nx_stamp  ny_stamp  xmax_stamp  xmin_stamp  \
# 0      ...    0.031428   0.414262      48.0      48.0        53.0         6.0
# 1      ...   -0.014147   0.099554      47.0      48.0        46.0         0.0
# 2      ...   -0.020424   0.087857      48.0      48.0        59.0        12.0
# 3      ...    0.001740   0.085209      48.0      48.0        53.0         6.0
# 4      ...   -0.014750   0.092218      48.0      48.0        50.0         3.0
# ...    ...         ...        ...       ...       ...         ...         ...
# 20150  ...   -0.123571   0.109558      59.0      58.0        60.0         2.0
# 20151  ...   -0.046317   0.139436      61.0      61.0        60.0         0.0
# 20152  ...   -2.782889   0.241846      61.0      60.0        60.0         0.0
# 20153  ...    0.000016   0.130863      48.0      48.0        56.0         9.0
# 20154  ...    0.015976   0.169679      48.0      48.0        53.0         6.0
#
#        ymax_stamp  ymin_stamp  flag  flag_sersic
# 0            59.0        12.0   1.0          1.0
# 1            52.0         5.0   1.0          1.0
# 2            53.0         6.0   0.0          0.0
# 3            54.0         7.0   1.0          1.0
# 4            53.0         6.0   1.0          1.0
# ...           ...         ...   ...          ...
# 20150        59.0         2.0   1.0          0.0
# 20151        60.0         0.0   0.0          0.0
# 20152        59.0         0.0   1.0          1.0
# 20153        54.0         7.0   1.0          1.0
# 20154        55.0         8.0   1.0          1.0
#
# [20155 rows x 143 columns]

# %% [markdown]
# # Rnning model

# %%
model = XGBClassifier(use_label_encoder=False, 
                      max_depth=7, 
                      #reg_alpha=1,   
                      #min_child_weight=0.5, 
                      #reg_lambda=5,
                      #subsample=0.5,
                      eta=0.1, # Remember to reduce to 0.1 or 0.05 for better results
                      tree_method='gpu_hist', # exact is more precies, but this is much faster
                      gpu_id=0,
                      objective='multi:softprob',
                      eval_metric =['merror', 'mlogloss'],
                      nthread=8,
                      n_estimators=500,
                      )

# %%
bst = model.fit(X_normal_train, y_train, 
                eval_set=[(X_normal_train, y_train)], 
                #early_stopping_rounds=50,
                verbose=True, 
                #eval_metric=xgb_recall
                #sample_weight=classes_weights,
               ) # Maybe remove weight
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [0]	validation_0-merror:0.08541	validation_0-mlogloss:1.23317
# [1]	validation_0-merror:0.07978	validation_0-mlogloss:1.10791
# [2]	validation_0-merror:0.07800	validation_0-mlogloss:1.00248
# [3]	validation_0-merror:0.07581	validation_0-mlogloss:0.91230
# [4]	validation_0-merror:0.07390	validation_0-mlogloss:0.83450
# [5]	validation_0-merror:0.07211	validation_0-mlogloss:0.76569
# [6]	validation_0-merror:0.06933	validation_0-mlogloss:0.70509
# [7]	validation_0-merror:0.06781	validation_0-mlogloss:0.65129
# [8]	validation_0-merror:0.06576	validation_0-mlogloss:0.60374
# [9]	validation_0-merror:0.06424	validation_0-mlogloss:0.56113
# [10]	validation_0-merror:0.06285	validation_0-mlogloss:0.52311
# [11]	validation_0-merror:0.06133	validation_0-mlogloss:0.48877
# [12]	validation_0-merror:0.05967	validation_0-mlogloss:0.45728
# [13]	validation_0-merror:0.05868	validation_0-mlogloss:0.42916
# [14]	validation_0-merror:0.05749	validation_0-mlogloss:0.40372
# [15]	validation_0-merror:0.05597	validation_0-mlogloss:0.38069
# [16]	validation_0-merror:0.05458	validation_0-mlogloss:0.35935
# [17]	validation_0-merror:0.05332	validation_0-mlogloss:0.33961
# [18]	validation_0-merror:0.05193	validation_0-mlogloss:0.32156
# [19]	validation_0-merror:0.05087	validation_0-mlogloss:0.30516
# [20]	validation_0-merror:0.05001	validation_0-mlogloss:0.29002
# [21]	validation_0-merror:0.04829	validation_0-mlogloss:0.27604
# [22]	validation_0-merror:0.04757	validation_0-mlogloss:0.26336
# [23]	validation_0-merror:0.04651	validation_0-mlogloss:0.25116
# [24]	validation_0-merror:0.04584	validation_0-mlogloss:0.24025
# [25]	validation_0-merror:0.04459	validation_0-mlogloss:0.22958
# [26]	validation_0-merror:0.04406	validation_0-mlogloss:0.21958
# [27]	validation_0-merror:0.04313	validation_0-mlogloss:0.21032
# [28]	validation_0-merror:0.04201	validation_0-mlogloss:0.20180
# [29]	validation_0-merror:0.04102	validation_0-mlogloss:0.19396
# [30]	validation_0-merror:0.03989	validation_0-mlogloss:0.18634
# [31]	validation_0-merror:0.03883	validation_0-mlogloss:0.17955
# [32]	validation_0-merror:0.03771	validation_0-mlogloss:0.17302
# [33]	validation_0-merror:0.03711	validation_0-mlogloss:0.16666
# [34]	validation_0-merror:0.03599	validation_0-mlogloss:0.16100
# [35]	validation_0-merror:0.03480	validation_0-mlogloss:0.15548
# [36]	validation_0-merror:0.03407	validation_0-mlogloss:0.15025
# [37]	validation_0-merror:0.03321	validation_0-mlogloss:0.14547
# [38]	validation_0-merror:0.03242	validation_0-mlogloss:0.14104
# [39]	validation_0-merror:0.03109	validation_0-mlogloss:0.13686
# [40]	validation_0-merror:0.03023	validation_0-mlogloss:0.13266
# [41]	validation_0-merror:0.02878	validation_0-mlogloss:0.12898
# [42]	validation_0-merror:0.02798	validation_0-mlogloss:0.12551
# [43]	validation_0-merror:0.02679	validation_0-mlogloss:0.12181
# [44]	validation_0-merror:0.02587	validation_0-mlogloss:0.11863
# [45]	validation_0-merror:0.02487	validation_0-mlogloss:0.11509
# [46]	validation_0-merror:0.02401	validation_0-mlogloss:0.11176
# [47]	validation_0-merror:0.02348	validation_0-mlogloss:0.10895
# [48]	validation_0-merror:0.02256	validation_0-mlogloss:0.10629
# [49]	validation_0-merror:0.02150	validation_0-mlogloss:0.10365
# [50]	validation_0-merror:0.02071	validation_0-mlogloss:0.10130
# [51]	validation_0-merror:0.01991	validation_0-mlogloss:0.09909
# [52]	validation_0-merror:0.01932	validation_0-mlogloss:0.09664
# [53]	validation_0-merror:0.01852	validation_0-mlogloss:0.09440
# [54]	validation_0-merror:0.01780	validation_0-mlogloss:0.09245
# [55]	validation_0-merror:0.01713	validation_0-mlogloss:0.09066
# [56]	validation_0-merror:0.01654	validation_0-mlogloss:0.08885
# [57]	validation_0-merror:0.01601	validation_0-mlogloss:0.08732
# [58]	validation_0-merror:0.01528	validation_0-mlogloss:0.08542
# [59]	validation_0-merror:0.01475	validation_0-mlogloss:0.08383
# [60]	validation_0-merror:0.01416	validation_0-mlogloss:0.08215
# [61]	validation_0-merror:0.01376	validation_0-mlogloss:0.08066
# [62]	validation_0-merror:0.01350	validation_0-mlogloss:0.07942
# [63]	validation_0-merror:0.01277	validation_0-mlogloss:0.07799
# [64]	validation_0-merror:0.01264	validation_0-mlogloss:0.07693
# [65]	validation_0-merror:0.01230	validation_0-mlogloss:0.07576
# [66]	validation_0-merror:0.01171	validation_0-mlogloss:0.07443
# [67]	validation_0-merror:0.01131	validation_0-mlogloss:0.07340
# [68]	validation_0-merror:0.01065	validation_0-mlogloss:0.07215
# [69]	validation_0-merror:0.01019	validation_0-mlogloss:0.07114
# [70]	validation_0-merror:0.00986	validation_0-mlogloss:0.06993
# [71]	validation_0-merror:0.00959	validation_0-mlogloss:0.06896
# [72]	validation_0-merror:0.00946	validation_0-mlogloss:0.06792
# [73]	validation_0-merror:0.00926	validation_0-mlogloss:0.06681
# [74]	validation_0-merror:0.00906	validation_0-mlogloss:0.06578
# [75]	validation_0-merror:0.00886	validation_0-mlogloss:0.06475
# [76]	validation_0-merror:0.00853	validation_0-mlogloss:0.06394
# [77]	validation_0-merror:0.00834	validation_0-mlogloss:0.06273
# [78]	validation_0-merror:0.00820	validation_0-mlogloss:0.06193
# [79]	validation_0-merror:0.00800	validation_0-mlogloss:0.06125
# [80]	validation_0-merror:0.00741	validation_0-mlogloss:0.06008
# [81]	validation_0-merror:0.00728	validation_0-mlogloss:0.05933
# [82]	validation_0-merror:0.00708	validation_0-mlogloss:0.05868
# [83]	validation_0-merror:0.00701	validation_0-mlogloss:0.05790
# [84]	validation_0-merror:0.00675	validation_0-mlogloss:0.05714
# [85]	validation_0-merror:0.00662	validation_0-mlogloss:0.05646
# [86]	validation_0-merror:0.00642	validation_0-mlogloss:0.05596
# [87]	validation_0-merror:0.00595	validation_0-mlogloss:0.05509
# [88]	validation_0-merror:0.00582	validation_0-mlogloss:0.05429
# [89]	validation_0-merror:0.00556	validation_0-mlogloss:0.05334
# [90]	validation_0-merror:0.00543	validation_0-mlogloss:0.05259
# [91]	validation_0-merror:0.00523	validation_0-mlogloss:0.05173
# [92]	validation_0-merror:0.00516	validation_0-mlogloss:0.05115
# [93]	validation_0-merror:0.00490	validation_0-mlogloss:0.05047
# [94]	validation_0-merror:0.00490	validation_0-mlogloss:0.04990
# [95]	validation_0-merror:0.00463	validation_0-mlogloss:0.04925
# [96]	validation_0-merror:0.00456	validation_0-mlogloss:0.04844
# [97]	validation_0-merror:0.00443	validation_0-mlogloss:0.04799
# [98]	validation_0-merror:0.00423	validation_0-mlogloss:0.04737
# [99]	validation_0-merror:0.00390	validation_0-mlogloss:0.04677
# [100]	validation_0-merror:0.00377	validation_0-mlogloss:0.04631
# [101]	validation_0-merror:0.00364	validation_0-mlogloss:0.04568
# [102]	validation_0-merror:0.00331	validation_0-mlogloss:0.04490
# [103]	validation_0-merror:0.00324	validation_0-mlogloss:0.04427
# [104]	validation_0-merror:0.00324	validation_0-mlogloss:0.04376
# [105]	validation_0-merror:0.00311	validation_0-mlogloss:0.04329
# [106]	validation_0-merror:0.00291	validation_0-mlogloss:0.04262
# [107]	validation_0-merror:0.00291	validation_0-mlogloss:0.04186
# [108]	validation_0-merror:0.00291	validation_0-mlogloss:0.04136
# [109]	validation_0-merror:0.00271	validation_0-mlogloss:0.04095
# [110]	validation_0-merror:0.00265	validation_0-mlogloss:0.04039
# [111]	validation_0-merror:0.00245	validation_0-mlogloss:0.03983
# [112]	validation_0-merror:0.00245	validation_0-mlogloss:0.03934
# [113]	validation_0-merror:0.00231	validation_0-mlogloss:0.03892
# [114]	validation_0-merror:0.00218	validation_0-mlogloss:0.03849
# [115]	validation_0-merror:0.00212	validation_0-mlogloss:0.03795
# [116]	validation_0-merror:0.00198	validation_0-mlogloss:0.03745
# [117]	validation_0-merror:0.00192	validation_0-mlogloss:0.03714
# [118]	validation_0-merror:0.00179	validation_0-mlogloss:0.03666
# [119]	validation_0-merror:0.00179	validation_0-mlogloss:0.03633
# [120]	validation_0-merror:0.00172	validation_0-mlogloss:0.03580
# [121]	validation_0-merror:0.00159	validation_0-mlogloss:0.03539
# [122]	validation_0-merror:0.00139	validation_0-mlogloss:0.03498
# [123]	validation_0-merror:0.00112	validation_0-mlogloss:0.03469
# [124]	validation_0-merror:0.00112	validation_0-mlogloss:0.03419
# [125]	validation_0-merror:0.00112	validation_0-mlogloss:0.03391
# [126]	validation_0-merror:0.00106	validation_0-mlogloss:0.03348
# [127]	validation_0-merror:0.00093	validation_0-mlogloss:0.03319
# [128]	validation_0-merror:0.00099	validation_0-mlogloss:0.03286
# [129]	validation_0-merror:0.00099	validation_0-mlogloss:0.03258
# [130]	validation_0-merror:0.00093	validation_0-mlogloss:0.03227
# [131]	validation_0-merror:0.00093	validation_0-mlogloss:0.03191
# [132]	validation_0-merror:0.00079	validation_0-mlogloss:0.03149
# [133]	validation_0-merror:0.00073	validation_0-mlogloss:0.03098
# [134]	validation_0-merror:0.00066	validation_0-mlogloss:0.03072
# [135]	validation_0-merror:0.00066	validation_0-mlogloss:0.03031
# [136]	validation_0-merror:0.00066	validation_0-mlogloss:0.03004
# [137]	validation_0-merror:0.00066	validation_0-mlogloss:0.02971
# [138]	validation_0-merror:0.00060	validation_0-mlogloss:0.02941
# [139]	validation_0-merror:0.00053	validation_0-mlogloss:0.02909
# [140]	validation_0-merror:0.00053	validation_0-mlogloss:0.02876
# [141]	validation_0-merror:0.00053	validation_0-mlogloss:0.02844
# [142]	validation_0-merror:0.00053	validation_0-mlogloss:0.02821
# [143]	validation_0-merror:0.00053	validation_0-mlogloss:0.02796
# [144]	validation_0-merror:0.00053	validation_0-mlogloss:0.02764
# [145]	validation_0-merror:0.00053	validation_0-mlogloss:0.02731
# [146]	validation_0-merror:0.00046	validation_0-mlogloss:0.02707
# [147]	validation_0-merror:0.00046	validation_0-mlogloss:0.02671
# [148]	validation_0-merror:0.00040	validation_0-mlogloss:0.02647
# [149]	validation_0-merror:0.00040	validation_0-mlogloss:0.02613
# [150]	validation_0-merror:0.00040	validation_0-mlogloss:0.02589
# [151]	validation_0-merror:0.00040	validation_0-mlogloss:0.02563
# [152]	validation_0-merror:0.00033	validation_0-mlogloss:0.02539
# [153]	validation_0-merror:0.00033	validation_0-mlogloss:0.02522
# [154]	validation_0-merror:0.00026	validation_0-mlogloss:0.02493
# [155]	validation_0-merror:0.00020	validation_0-mlogloss:0.02464
# [156]	validation_0-merror:0.00020	validation_0-mlogloss:0.02439
# [157]	validation_0-merror:0.00020	validation_0-mlogloss:0.02419
# [158]	validation_0-merror:0.00020	validation_0-mlogloss:0.02395
# [159]	validation_0-merror:0.00020	validation_0-mlogloss:0.02377
# [160]	validation_0-merror:0.00020	validation_0-mlogloss:0.02352
# [161]	validation_0-merror:0.00020	validation_0-mlogloss:0.02329
# [162]	validation_0-merror:0.00013	validation_0-mlogloss:0.02307
# [163]	validation_0-merror:0.00013	validation_0-mlogloss:0.02286
# [164]	validation_0-merror:0.00013	validation_0-mlogloss:0.02269
# [165]	validation_0-merror:0.00007	validation_0-mlogloss:0.02244
# [166]	validation_0-merror:0.00007	validation_0-mlogloss:0.02227
# [167]	validation_0-merror:0.00007	validation_0-mlogloss:0.02211
# [168]	validation_0-merror:0.00007	validation_0-mlogloss:0.02188
# [169]	validation_0-merror:0.00007	validation_0-mlogloss:0.02170
# [170]	validation_0-merror:0.00007	validation_0-mlogloss:0.02155
# [171]	validation_0-merror:0.00007	validation_0-mlogloss:0.02137
# [172]	validation_0-merror:0.00007	validation_0-mlogloss:0.02109
# [173]	validation_0-merror:0.00007	validation_0-mlogloss:0.02090
# [174]	validation_0-merror:0.00007	validation_0-mlogloss:0.02066
# [175]	validation_0-merror:0.00007	validation_0-mlogloss:0.02047
# [176]	validation_0-merror:0.00007	validation_0-mlogloss:0.02024
# [177]	validation_0-merror:0.00007	validation_0-mlogloss:0.02008
# [178]	validation_0-merror:0.00007	validation_0-mlogloss:0.01990
# [179]	validation_0-merror:0.00007	validation_0-mlogloss:0.01977
# [180]	validation_0-merror:0.00007	validation_0-mlogloss:0.01961
# [181]	validation_0-merror:0.00007	validation_0-mlogloss:0.01941
# [182]	validation_0-merror:0.00007	validation_0-mlogloss:0.01930
# [183]	validation_0-merror:0.00007	validation_0-mlogloss:0.01915
# [184]	validation_0-merror:0.00007	validation_0-mlogloss:0.01894
# [185]	validation_0-merror:0.00007	validation_0-mlogloss:0.01878
# [186]	validation_0-merror:0.00007	validation_0-mlogloss:0.01860
# [187]	validation_0-merror:0.00007	validation_0-mlogloss:0.01845
# [188]	validation_0-merror:0.00007	validation_0-mlogloss:0.01833
# [189]	validation_0-merror:0.00007	validation_0-mlogloss:0.01819
# [190]	validation_0-merror:0.00007	validation_0-mlogloss:0.01799
# [191]	validation_0-merror:0.00007	validation_0-mlogloss:0.01782
# [192]	validation_0-merror:0.00007	validation_0-mlogloss:0.01769
# [193]	validation_0-merror:0.00007	validation_0-mlogloss:0.01751
# [194]	validation_0-merror:0.00007	validation_0-mlogloss:0.01740
# [195]	validation_0-merror:0.00000	validation_0-mlogloss:0.01727
# [196]	validation_0-merror:0.00000	validation_0-mlogloss:0.01711
# [197]	validation_0-merror:0.00000	validation_0-mlogloss:0.01697
# [198]	validation_0-merror:0.00000	validation_0-mlogloss:0.01679
# [199]	validation_0-merror:0.00000	validation_0-mlogloss:0.01665
# [200]	validation_0-merror:0.00000	validation_0-mlogloss:0.01652
# [201]	validation_0-merror:0.00000	validation_0-mlogloss:0.01641
# [202]	validation_0-merror:0.00000	validation_0-mlogloss:0.01622
# [203]	validation_0-merror:0.00000	validation_0-mlogloss:0.01608
# [204]	validation_0-merror:0.00000	validation_0-mlogloss:0.01598
# [205]	validation_0-merror:0.00000	validation_0-mlogloss:0.01581
# [206]	validation_0-merror:0.00000	validation_0-mlogloss:0.01566
# [207]	validation_0-merror:0.00000	validation_0-mlogloss:0.01555
# [208]	validation_0-merror:0.00000	validation_0-mlogloss:0.01544
# [209]	validation_0-merror:0.00000	validation_0-mlogloss:0.01529
# [210]	validation_0-merror:0.00000	validation_0-mlogloss:0.01516
# [211]	validation_0-merror:0.00000	validation_0-mlogloss:0.01504
# [212]	validation_0-merror:0.00000	validation_0-mlogloss:0.01489
# [213]	validation_0-merror:0.00000	validation_0-mlogloss:0.01480
# [214]	validation_0-merror:0.00000	validation_0-mlogloss:0.01467
# [215]	validation_0-merror:0.00000	validation_0-mlogloss:0.01457
# [216]	validation_0-merror:0.00000	validation_0-mlogloss:0.01442
# [217]	validation_0-merror:0.00000	validation_0-mlogloss:0.01430
# [218]	validation_0-merror:0.00000	validation_0-mlogloss:0.01418
# [219]	validation_0-merror:0.00000	validation_0-mlogloss:0.01409
# [220]	validation_0-merror:0.00000	validation_0-mlogloss:0.01401
# [221]	validation_0-merror:0.00000	validation_0-mlogloss:0.01389
# [222]	validation_0-merror:0.00000	validation_0-mlogloss:0.01381
# [223]	validation_0-merror:0.00000	validation_0-mlogloss:0.01370
# [224]	validation_0-merror:0.00000	validation_0-mlogloss:0.01362
# [225]	validation_0-merror:0.00000	validation_0-mlogloss:0.01348
# [226]	validation_0-merror:0.00000	validation_0-mlogloss:0.01338
# [227]	validation_0-merror:0.00000	validation_0-mlogloss:0.01329
# [228]	validation_0-merror:0.00000	validation_0-mlogloss:0.01318
# [229]	validation_0-merror:0.00000	validation_0-mlogloss:0.01308
# [230]	validation_0-merror:0.00000	validation_0-mlogloss:0.01299
# [231]	validation_0-merror:0.00000	validation_0-mlogloss:0.01288
# [232]	validation_0-merror:0.00000	validation_0-mlogloss:0.01278
# [233]	validation_0-merror:0.00000	validation_0-mlogloss:0.01268
# [234]	validation_0-merror:0.00000	validation_0-mlogloss:0.01260
# [235]	validation_0-merror:0.00000	validation_0-mlogloss:0.01250
# [236]	validation_0-merror:0.00000	validation_0-mlogloss:0.01241
# [237]	validation_0-merror:0.00000	validation_0-mlogloss:0.01230
# [238]	validation_0-merror:0.00000	validation_0-mlogloss:0.01223
# [239]	validation_0-merror:0.00000	validation_0-mlogloss:0.01215
# [240]	validation_0-merror:0.00000	validation_0-mlogloss:0.01206
# [241]	validation_0-merror:0.00000	validation_0-mlogloss:0.01199
# [242]	validation_0-merror:0.00000	validation_0-mlogloss:0.01189
# [243]	validation_0-merror:0.00000	validation_0-mlogloss:0.01179
# [244]	validation_0-merror:0.00000	validation_0-mlogloss:0.01172
# [245]	validation_0-merror:0.00000	validation_0-mlogloss:0.01163
# [246]	validation_0-merror:0.00000	validation_0-mlogloss:0.01155
# [247]	validation_0-merror:0.00000	validation_0-mlogloss:0.01149
# [248]	validation_0-merror:0.00000	validation_0-mlogloss:0.01141
# [249]	validation_0-merror:0.00000	validation_0-mlogloss:0.01132
# [250]	validation_0-merror:0.00000	validation_0-mlogloss:0.01125
# [251]	validation_0-merror:0.00000	validation_0-mlogloss:0.01116
# [252]	validation_0-merror:0.00000	validation_0-mlogloss:0.01109
# [253]	validation_0-merror:0.00000	validation_0-mlogloss:0.01103
# [254]	validation_0-merror:0.00000	validation_0-mlogloss:0.01095
# [255]	validation_0-merror:0.00000	validation_0-mlogloss:0.01088
# [256]	validation_0-merror:0.00000	validation_0-mlogloss:0.01081
# [257]	validation_0-merror:0.00000	validation_0-mlogloss:0.01075
# [258]	validation_0-merror:0.00000	validation_0-mlogloss:0.01070
# [259]	validation_0-merror:0.00000	validation_0-mlogloss:0.01061
# [260]	validation_0-merror:0.00000	validation_0-mlogloss:0.01055
# [261]	validation_0-merror:0.00000	validation_0-mlogloss:0.01048
# [262]	validation_0-merror:0.00000	validation_0-mlogloss:0.01041
# [263]	validation_0-merror:0.00000	validation_0-mlogloss:0.01034
# [264]	validation_0-merror:0.00000	validation_0-mlogloss:0.01029
# [265]	validation_0-merror:0.00000	validation_0-mlogloss:0.01022
# [266]	validation_0-merror:0.00000	validation_0-mlogloss:0.01013
# [267]	validation_0-merror:0.00000	validation_0-mlogloss:0.01004
# [268]	validation_0-merror:0.00000	validation_0-mlogloss:0.00996
# [269]	validation_0-merror:0.00000	validation_0-mlogloss:0.00990
# [270]	validation_0-merror:0.00000	validation_0-mlogloss:0.00983
# [271]	validation_0-merror:0.00000	validation_0-mlogloss:0.00978
# [272]	validation_0-merror:0.00000	validation_0-mlogloss:0.00973
# [273]	validation_0-merror:0.00000	validation_0-mlogloss:0.00967
# [274]	validation_0-merror:0.00000	validation_0-mlogloss:0.00963
# [275]	validation_0-merror:0.00000	validation_0-mlogloss:0.00955
# [276]	validation_0-merror:0.00000	validation_0-mlogloss:0.00949
# [277]	validation_0-merror:0.00000	validation_0-mlogloss:0.00945
# [278]	validation_0-merror:0.00000	validation_0-mlogloss:0.00939
# [279]	validation_0-merror:0.00000	validation_0-mlogloss:0.00931
# [280]	validation_0-merror:0.00000	validation_0-mlogloss:0.00925
# [281]	validation_0-merror:0.00000	validation_0-mlogloss:0.00920
# [282]	validation_0-merror:0.00000	validation_0-mlogloss:0.00915
# [283]	validation_0-merror:0.00000	validation_0-mlogloss:0.00908
# [284]	validation_0-merror:0.00000	validation_0-mlogloss:0.00903
# [285]	validation_0-merror:0.00000	validation_0-mlogloss:0.00898
# [286]	validation_0-merror:0.00000	validation_0-mlogloss:0.00892
# [287]	validation_0-merror:0.00000	validation_0-mlogloss:0.00885
# [288]	validation_0-merror:0.00000	validation_0-mlogloss:0.00882
# [289]	validation_0-merror:0.00000	validation_0-mlogloss:0.00876
# [290]	validation_0-merror:0.00000	validation_0-mlogloss:0.00870
# [291]	validation_0-merror:0.00000	validation_0-mlogloss:0.00864
# [292]	validation_0-merror:0.00000	validation_0-mlogloss:0.00858
# [293]	validation_0-merror:0.00000	validation_0-mlogloss:0.00852
# [294]	validation_0-merror:0.00000	validation_0-mlogloss:0.00846
# [295]	validation_0-merror:0.00000	validation_0-mlogloss:0.00841
# [296]	validation_0-merror:0.00000	validation_0-mlogloss:0.00834
# [297]	validation_0-merror:0.00000	validation_0-mlogloss:0.00830
# [298]	validation_0-merror:0.00000	validation_0-mlogloss:0.00823
# [299]	validation_0-merror:0.00000	validation_0-mlogloss:0.00817
# [300]	validation_0-merror:0.00000	validation_0-mlogloss:0.00812
# [301]	validation_0-merror:0.00000	validation_0-mlogloss:0.00807
# [302]	validation_0-merror:0.00000	validation_0-mlogloss:0.00803
# [303]	validation_0-merror:0.00000	validation_0-mlogloss:0.00797
# [304]	validation_0-merror:0.00000	validation_0-mlogloss:0.00795
# [305]	validation_0-merror:0.00000	validation_0-mlogloss:0.00790
# [306]	validation_0-merror:0.00000	validation_0-mlogloss:0.00785
# [307]	validation_0-merror:0.00000	validation_0-mlogloss:0.00782
# [308]	validation_0-merror:0.00000	validation_0-mlogloss:0.00776
# [309]	validation_0-merror:0.00000	validation_0-mlogloss:0.00772
# [310]	validation_0-merror:0.00000	validation_0-mlogloss:0.00767
# [311]	validation_0-merror:0.00000	validation_0-mlogloss:0.00762
# [312]	validation_0-merror:0.00000	validation_0-mlogloss:0.00757
# [313]	validation_0-merror:0.00000	validation_0-mlogloss:0.00754
# [314]	validation_0-merror:0.00000	validation_0-mlogloss:0.00748
# [315]	validation_0-merror:0.00000	validation_0-mlogloss:0.00744
# [316]	validation_0-merror:0.00000	validation_0-mlogloss:0.00741
# [317]	validation_0-merror:0.00000	validation_0-mlogloss:0.00737
# [318]	validation_0-merror:0.00000	validation_0-mlogloss:0.00733
# [319]	validation_0-merror:0.00000	validation_0-mlogloss:0.00727
# [320]	validation_0-merror:0.00000	validation_0-mlogloss:0.00723
# [321]	validation_0-merror:0.00000	validation_0-mlogloss:0.00718
# [322]	validation_0-merror:0.00000	validation_0-mlogloss:0.00715
# [323]	validation_0-merror:0.00000	validation_0-mlogloss:0.00711
# [324]	validation_0-merror:0.00000	validation_0-mlogloss:0.00705
# [325]	validation_0-merror:0.00000	validation_0-mlogloss:0.00700
# [326]	validation_0-merror:0.00000	validation_0-mlogloss:0.00696
# [327]	validation_0-merror:0.00000	validation_0-mlogloss:0.00693
# [328]	validation_0-merror:0.00000	validation_0-mlogloss:0.00689
# [329]	validation_0-merror:0.00000	validation_0-mlogloss:0.00685
# [330]	validation_0-merror:0.00000	validation_0-mlogloss:0.00680
# [331]	validation_0-merror:0.00000	validation_0-mlogloss:0.00676
# [332]	validation_0-merror:0.00000	validation_0-mlogloss:0.00672
# [333]	validation_0-merror:0.00000	validation_0-mlogloss:0.00668
# [334]	validation_0-merror:0.00000	validation_0-mlogloss:0.00664
# [335]	validation_0-merror:0.00000	validation_0-mlogloss:0.00660
# [336]	validation_0-merror:0.00000	validation_0-mlogloss:0.00658
# [337]	validation_0-merror:0.00000	validation_0-mlogloss:0.00656
# [338]	validation_0-merror:0.00000	validation_0-mlogloss:0.00652
# [339]	validation_0-merror:0.00000	validation_0-mlogloss:0.00648
# [340]	validation_0-merror:0.00000	validation_0-mlogloss:0.00644
# [341]	validation_0-merror:0.00000	validation_0-mlogloss:0.00640
# [342]	validation_0-merror:0.00000	validation_0-mlogloss:0.00637
# [343]	validation_0-merror:0.00000	validation_0-mlogloss:0.00634
# [344]	validation_0-merror:0.00000	validation_0-mlogloss:0.00630
# [345]	validation_0-merror:0.00000	validation_0-mlogloss:0.00627
# [346]	validation_0-merror:0.00000	validation_0-mlogloss:0.00624
# [347]	validation_0-merror:0.00000	validation_0-mlogloss:0.00621
# [348]	validation_0-merror:0.00000	validation_0-mlogloss:0.00617
# [349]	validation_0-merror:0.00000	validation_0-mlogloss:0.00614
# [350]	validation_0-merror:0.00000	validation_0-mlogloss:0.00611
# [351]	validation_0-merror:0.00000	validation_0-mlogloss:0.00609
# [352]	validation_0-merror:0.00000	validation_0-mlogloss:0.00605
# [353]	validation_0-merror:0.00000	validation_0-mlogloss:0.00601
# [354]	validation_0-merror:0.00000	validation_0-mlogloss:0.00599
# [355]	validation_0-merror:0.00000	validation_0-mlogloss:0.00597
# [356]	validation_0-merror:0.00000	validation_0-mlogloss:0.00593
# [357]	validation_0-merror:0.00000	validation_0-mlogloss:0.00591
# [358]	validation_0-merror:0.00000	validation_0-mlogloss:0.00589
# [359]	validation_0-merror:0.00000	validation_0-mlogloss:0.00587
# [360]	validation_0-merror:0.00000	validation_0-mlogloss:0.00584
# [361]	validation_0-merror:0.00000	validation_0-mlogloss:0.00582
# [362]	validation_0-merror:0.00000	validation_0-mlogloss:0.00578
# [363]	validation_0-merror:0.00000	validation_0-mlogloss:0.00575
# [364]	validation_0-merror:0.00000	validation_0-mlogloss:0.00572
# [365]	validation_0-merror:0.00000	validation_0-mlogloss:0.00569
# [366]	validation_0-merror:0.00000	validation_0-mlogloss:0.00568
# [367]	validation_0-merror:0.00000	validation_0-mlogloss:0.00565
# [368]	validation_0-merror:0.00000	validation_0-mlogloss:0.00562
# [369]	validation_0-merror:0.00000	validation_0-mlogloss:0.00560
# [370]	validation_0-merror:0.00000	validation_0-mlogloss:0.00558
# [371]	validation_0-merror:0.00000	validation_0-mlogloss:0.00556
# [372]	validation_0-merror:0.00000	validation_0-mlogloss:0.00554
# [373]	validation_0-merror:0.00000	validation_0-mlogloss:0.00552
# [374]	validation_0-merror:0.00000	validation_0-mlogloss:0.00549
# [375]	validation_0-merror:0.00000	validation_0-mlogloss:0.00546
# [376]	validation_0-merror:0.00000	validation_0-mlogloss:0.00545
# [377]	validation_0-merror:0.00000	validation_0-mlogloss:0.00543
# [378]	validation_0-merror:0.00000	validation_0-mlogloss:0.00541
# [379]	validation_0-merror:0.00000	validation_0-mlogloss:0.00538
# [380]	validation_0-merror:0.00000	validation_0-mlogloss:0.00537
# [381]	validation_0-merror:0.00000	validation_0-mlogloss:0.00535
# [382]	validation_0-merror:0.00000	validation_0-mlogloss:0.00533
# [383]	validation_0-merror:0.00000	validation_0-mlogloss:0.00531
# [384]	validation_0-merror:0.00000	validation_0-mlogloss:0.00529
# [385]	validation_0-merror:0.00000	validation_0-mlogloss:0.00526
# [386]	validation_0-merror:0.00000	validation_0-mlogloss:0.00524
# [387]	validation_0-merror:0.00000	validation_0-mlogloss:0.00522
# [388]	validation_0-merror:0.00000	validation_0-mlogloss:0.00520
# [389]	validation_0-merror:0.00000	validation_0-mlogloss:0.00518
# [390]	validation_0-merror:0.00000	validation_0-mlogloss:0.00516
# [391]	validation_0-merror:0.00000	validation_0-mlogloss:0.00514
# [392]	validation_0-merror:0.00000	validation_0-mlogloss:0.00512
# [393]	validation_0-merror:0.00000	validation_0-mlogloss:0.00510
# [394]	validation_0-merror:0.00000	validation_0-mlogloss:0.00509
# [395]	validation_0-merror:0.00000	validation_0-mlogloss:0.00507
# [396]	validation_0-merror:0.00000	validation_0-mlogloss:0.00505
# [397]	validation_0-merror:0.00000	validation_0-mlogloss:0.00502
# [398]	validation_0-merror:0.00000	validation_0-mlogloss:0.00500
# [399]	validation_0-merror:0.00000	validation_0-mlogloss:0.00498
# [400]	validation_0-merror:0.00000	validation_0-mlogloss:0.00497
# [401]	validation_0-merror:0.00000	validation_0-mlogloss:0.00495
# [402]	validation_0-merror:0.00000	validation_0-mlogloss:0.00494
# [403]	validation_0-merror:0.00000	validation_0-mlogloss:0.00492
# [404]	validation_0-merror:0.00000	validation_0-mlogloss:0.00490
# [405]	validation_0-merror:0.00000	validation_0-mlogloss:0.00488
# [406]	validation_0-merror:0.00000	validation_0-mlogloss:0.00485
# [407]	validation_0-merror:0.00000	validation_0-mlogloss:0.00482
# [408]	validation_0-merror:0.00000	validation_0-mlogloss:0.00481
# [409]	validation_0-merror:0.00000	validation_0-mlogloss:0.00479
# [410]	validation_0-merror:0.00000	validation_0-mlogloss:0.00477
# [411]	validation_0-merror:0.00000	validation_0-mlogloss:0.00476
# [412]	validation_0-merror:0.00000	validation_0-mlogloss:0.00475
# [413]	validation_0-merror:0.00000	validation_0-mlogloss:0.00473
# [414]	validation_0-merror:0.00000	validation_0-mlogloss:0.00471
# [415]	validation_0-merror:0.00000	validation_0-mlogloss:0.00469
# [416]	validation_0-merror:0.00000	validation_0-mlogloss:0.00466
# [417]	validation_0-merror:0.00000	validation_0-mlogloss:0.00465
# [418]	validation_0-merror:0.00000	validation_0-mlogloss:0.00463
# [419]	validation_0-merror:0.00000	validation_0-mlogloss:0.00461
# [420]	validation_0-merror:0.00000	validation_0-mlogloss:0.00458
# [421]	validation_0-merror:0.00000	validation_0-mlogloss:0.00457
# [422]	validation_0-merror:0.00000	validation_0-mlogloss:0.00455
# [423]	validation_0-merror:0.00000	validation_0-mlogloss:0.00453
# [424]	validation_0-merror:0.00000	validation_0-mlogloss:0.00451
# [425]	validation_0-merror:0.00000	validation_0-mlogloss:0.00449
# [426]	validation_0-merror:0.00000	validation_0-mlogloss:0.00448
# [427]	validation_0-merror:0.00000	validation_0-mlogloss:0.00447
# [428]	validation_0-merror:0.00000	validation_0-mlogloss:0.00446
# [429]	validation_0-merror:0.00000	validation_0-mlogloss:0.00444
# [430]	validation_0-merror:0.00000	validation_0-mlogloss:0.00443
# [431]	validation_0-merror:0.00000	validation_0-mlogloss:0.00441
# [432]	validation_0-merror:0.00000	validation_0-mlogloss:0.00439
# [433]	validation_0-merror:0.00000	validation_0-mlogloss:0.00438
# [434]	validation_0-merror:0.00000	validation_0-mlogloss:0.00436
# [435]	validation_0-merror:0.00000	validation_0-mlogloss:0.00435
# [436]	validation_0-merror:0.00000	validation_0-mlogloss:0.00433
# [437]	validation_0-merror:0.00000	validation_0-mlogloss:0.00431
# [438]	validation_0-merror:0.00000	validation_0-mlogloss:0.00430
# [439]	validation_0-merror:0.00000	validation_0-mlogloss:0.00429
# [440]	validation_0-merror:0.00000	validation_0-mlogloss:0.00427
# [441]	validation_0-merror:0.00000	validation_0-mlogloss:0.00426
# [442]	validation_0-merror:0.00000	validation_0-mlogloss:0.00425
# [443]	validation_0-merror:0.00000	validation_0-mlogloss:0.00424
# [444]	validation_0-merror:0.00000	validation_0-mlogloss:0.00423
# [445]	validation_0-merror:0.00000	validation_0-mlogloss:0.00422
# [446]	validation_0-merror:0.00000	validation_0-mlogloss:0.00420
# [447]	validation_0-merror:0.00000	validation_0-mlogloss:0.00419
# [448]	validation_0-merror:0.00000	validation_0-mlogloss:0.00417
# [449]	validation_0-merror:0.00000	validation_0-mlogloss:0.00415
# [450]	validation_0-merror:0.00000	validation_0-mlogloss:0.00415
# [451]	validation_0-merror:0.00000	validation_0-mlogloss:0.00413
# [452]	validation_0-merror:0.00000	validation_0-mlogloss:0.00412
# [453]	validation_0-merror:0.00000	validation_0-mlogloss:0.00411
# [454]	validation_0-merror:0.00000	validation_0-mlogloss:0.00409
# [455]	validation_0-merror:0.00000	validation_0-mlogloss:0.00408
# [456]	validation_0-merror:0.00000	validation_0-mlogloss:0.00407
# [457]	validation_0-merror:0.00000	validation_0-mlogloss:0.00405
# [458]	validation_0-merror:0.00000	validation_0-mlogloss:0.00404
# [459]	validation_0-merror:0.00000	validation_0-mlogloss:0.00402
# [460]	validation_0-merror:0.00000	validation_0-mlogloss:0.00401
# [461]	validation_0-merror:0.00000	validation_0-mlogloss:0.00399
# [462]	validation_0-merror:0.00000	validation_0-mlogloss:0.00398
# [463]	validation_0-merror:0.00000	validation_0-mlogloss:0.00397
# [464]	validation_0-merror:0.00000	validation_0-mlogloss:0.00396
# [465]	validation_0-merror:0.00000	validation_0-mlogloss:0.00394
# [466]	validation_0-merror:0.00000	validation_0-mlogloss:0.00393
# [467]	validation_0-merror:0.00000	validation_0-mlogloss:0.00392
# [468]	validation_0-merror:0.00000	validation_0-mlogloss:0.00391
# [469]	validation_0-merror:0.00000	validation_0-mlogloss:0.00390
# [470]	validation_0-merror:0.00000	validation_0-mlogloss:0.00389
# [471]	validation_0-merror:0.00000	validation_0-mlogloss:0.00388
# [472]	validation_0-merror:0.00000	validation_0-mlogloss:0.00386
# [473]	validation_0-merror:0.00000	validation_0-mlogloss:0.00385
# [474]	validation_0-merror:0.00000	validation_0-mlogloss:0.00383
# [475]	validation_0-merror:0.00000	validation_0-mlogloss:0.00381
# [476]	validation_0-merror:0.00000	validation_0-mlogloss:0.00381
# [477]	validation_0-merror:0.00000	validation_0-mlogloss:0.00379
# [478]	validation_0-merror:0.00000	validation_0-mlogloss:0.00378
# [479]	validation_0-merror:0.00000	validation_0-mlogloss:0.00377
# [480]	validation_0-merror:0.00000	validation_0-mlogloss:0.00375
# [481]	validation_0-merror:0.00000	validation_0-mlogloss:0.00374
# [482]	validation_0-merror:0.00000	validation_0-mlogloss:0.00373
# [483]	validation_0-merror:0.00000	validation_0-mlogloss:0.00372
# [484]	validation_0-merror:0.00000	validation_0-mlogloss:0.00371
# [485]	validation_0-merror:0.00000	validation_0-mlogloss:0.00370
# [486]	validation_0-merror:0.00000	validation_0-mlogloss:0.00369
# [487]	validation_0-merror:0.00000	validation_0-mlogloss:0.00367
# [488]	validation_0-merror:0.00000	validation_0-mlogloss:0.00366
# [489]	validation_0-merror:0.00000	validation_0-mlogloss:0.00365
# [490]	validation_0-merror:0.00000	validation_0-mlogloss:0.00365
# [491]	validation_0-merror:0.00000	validation_0-mlogloss:0.00363
# [492]	validation_0-merror:0.00000	validation_0-mlogloss:0.00362
# [493]	validation_0-merror:0.00000	validation_0-mlogloss:0.00361
# [494]	validation_0-merror:0.00000	validation_0-mlogloss:0.00360
# [495]	validation_0-merror:0.00000	validation_0-mlogloss:0.00359
# [496]	validation_0-merror:0.00000	validation_0-mlogloss:0.00357
# [497]	validation_0-merror:0.00000	validation_0-mlogloss:0.00356
# [498]	validation_0-merror:0.00000	validation_0-mlogloss:0.00355
# [499]	validation_0-merror:0.00000	validation_0-mlogloss:0.00354

# %%
y_pred = model.predict(X_normal_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.8518    0.7077    0.7731       609
# quasar-like radio AGN / high-excitation radio galaxy     0.5769    0.2381    0.3371        63
#                                      radio-quiet AGN     0.8088    0.7314    0.7682       376
#                                  star-forming galaxy     0.9345    0.9757    0.9546      3991
#
#                                             accuracy                         0.9159      5039
#                                            macro avg     0.7930    0.6632    0.7082      5039
#                                         weighted avg     0.9106    0.9159    0.9111      5039

# %%
import xgboost

# Putting the train data into a DMatrix
data = xgboost.DMatrix(X_normal_train, y_train)

parameters = {'num_class':4,
             'max_depth': 7, 
             'eta': 0.1,
             'tree_method':'hist',
              #'gpu_id':0,
             'nthread': 8,
             'objective':'multi:softprob',   
              'eval_metric':'merror'
             }

bst = xgboost.cv(dtrain=data, params=parameters, 
           num_boost_round=10**4, stratified=True, 
           nfold=16, early_stopping_rounds=50,
           verbose_eval=True, metrics=['merror'])
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [0]	train-merror:0.08315+0.00211	test-merror:0.11630+0.00965
# [1]	train-merror:0.07820+0.00086	test-merror:0.11458+0.00976
# ---------------------------------------------------------------------------
# XGBoostError                              Traceback (most recent call last)
# Input In [107], in <cell line: 16>()
#       4 data = xgboost.DMatrix(X_normal_train, y_train)
#       6 parameters = {'num_class':4,
#       7              'max_depth': 7,
#       8              'eta': 0.1,
#    (...)
#      13               'eval_metric':'merror'
#      14              }
# ---> 16 bst = xgboost.cv(dtrain=data, params=parameters,
#      17            num_boost_round=10**4, stratified=True,
#      18            nfold=8, early_stopping_rounds=50,
#      19            verbose_eval=True, metrics=['merror'])
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\training.py:515, in cv(params, dtrain, num_boost_round, nfold, stratified, folds, metrics, obj, feval, maximize, early_stopping_rounds, fpreproc, as_pandas, verbose_eval, show_stdv, seed, callbacks, shuffle)
#     513 if callbacks.before_iteration(booster, i, dtrain, None):
#     514     break
# --> 515 booster.update(i, obj)
#     517 should_break = callbacks.after_iteration(booster, i, dtrain, None)
#     518 res = callbacks.aggregated_cv
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\training.py:264, in _PackedBooster.update(self, iteration, obj)
#     262 '''Iterate through folds for update'''
#     263 for fold in self.cvfolds:
# --> 264     fold.update(iteration, obj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\training.py:250, in CVPack.update(self, iteration, fobj)
#     248 def update(self, iteration, fobj):
#     249     """"Update the boosters for one iteration"""
# --> 250     self.bst.update(self.dtrain, iteration, fobj)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\core.py:1280, in Booster.update(self, dtrain, iteration, fobj)
#    1277 self._validate_features(dtrain)
#    1279 if fobj is None:
# -> 1280     _check_call(_LIB.XGBoosterUpdateOneIter(self.handle,
#    1281                                             ctypes.c_int(iteration),
#    1282                                             dtrain.handle))
#    1283 else:
#    1284     pred = self.predict(dtrain, output_margin=True, training=True)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\core.py:189, in _check_call(ret)
#     178 """Check the return value of C API call
#     179
#     180 This function will raise exception when error occurs.
#    (...)
#     186     return value from API calls
#     187 """
#     188 if ret != 0:
# --> 189     raise XGBoostError(py_str(_LIB.XGBGetLastError()))
#
# XGBoostError: bad allocation

# %%
X_normal_train
# Out:
#         Total_flux    Peak_flux  FUV_flux_corr  NUV_flux_corr  g_flux_corr  \
# 5449    240.860071   176.348425            NaN            NaN     0.776278
# 21559   370.996103   326.533595       0.033081       0.021027     0.761756
# 2265    364.491167   151.726592       3.173771       1.931813    20.715910
# 7489    288.169681   277.723020       1.613003       1.040517     5.575343
# 26561  1097.427227   113.763786            NaN            NaN     0.453263
# ...            ...          ...            ...            ...          ...
# 16201   403.411910   310.443902            NaN            NaN     0.667227
# 715     286.581894   275.426455       0.184518       0.115982     5.040021
# 21944   326.289005   169.744440       0.021646       0.014323     0.390368
# 17421   182.469058   197.263704       0.327046       0.212748     1.202284
# 4585   1983.267138  1720.151329       0.164532       0.106386     0.119472
#
#        r_flux_corr  i_flux_corr  z_flux_corr  y_flux_corr  g_hsc_flux_corr  \
# 5449      2.035265     4.061224     8.465590    11.216141         1.072404
# 21559     1.704754     5.022224     7.721030     8.805650         0.824968
# 2265     45.057171    66.432251    86.727440    97.537643        22.126055
# 7489      9.933268    14.401316    13.103798    15.449107         6.349408
# 26561     1.387818     3.743378     6.419131     8.267488         0.895050
# ...            ...          ...          ...          ...              ...
# 16201     0.695144     1.070410     1.573667     1.797302         0.710252
# 715      22.597513    45.056282    62.278759    75.163261         5.238141
# 21944     1.036379     1.985984     4.028953     4.777966         0.594911
# 17421     3.361639     5.091513     6.661453     8.308106         1.368055
# 4585      0.483795     2.287598     4.855179     9.081196         0.115346
#
#        ...  ch1_servs_flux_corr  ch2_servs_flux_corr   F_MIPS_24  F_PACS_100  \
# 5449   ...            82.401375                  NaN  202.595760  13872.9700
# 21559  ...            65.105034            50.817139  450.613700  13049.8480
# 2265   ...                  NaN                  NaN  527.494930  14606.4380
# 7489   ...            23.245649            19.532967  253.932890  10402.3400
# 26561  ...                  NaN                  NaN   81.321060   6109.4214
# ...    ...                  ...                  ...         ...         ...
# 16201  ...                  NaN                  NaN  568.151978  19765.6930
# 715    ...                  NaN                  NaN   28.522871   9472.5940
# 21944  ...                  NaN                  NaN  346.962600  16891.6700
# 17421  ...            21.914240            21.083996  167.978360   4856.5680
# 4585   ...                  NaN                  NaN    2.306241  35285.2150
#
#        F_PACS_160   F_SPIRE_250   F_SPIRE_350   F_SPIRE_500  Z_BEST       EBV
# 5449    38061.660  18141.909000  16824.257000  12503.284000  1.0746  0.010675
# 21559   19983.688  19268.240000   6057.095500   1449.890600  0.8171  0.008618
# 2265    36092.348  19192.514000   3943.035000   3562.991000  0.2304  0.010972
# 7489    17236.750   6940.386000   2800.546000   2987.424000  0.5672  0.007813
# 26561   28557.004  28384.672165  19816.379547  21170.837402  0.8226  0.009108
# ...           ...           ...           ...           ...     ...       ...
# 16201   34786.360  40635.650635  32786.563873  17377.866745  1.9808  0.008286
# 715     49014.203   2508.078800   8129.263000   9459.089000  0.4090  0.009223
# 21944   29593.771  12445.210000   5331.346000   9056.259000  1.0779  0.006430
# 17421   11603.822   3493.653300   2155.926200   3878.562700  0.4985  0.007357
# 4585    19123.715   3387.733459   3806.690693   5858.889103  1.1639  0.007685
#
# [15116 rows x 31 columns]
