# %%
import pandas as pd
import numpy as np
from sklearn.impute import SimpleImputer
from sklearn.model_selection import train_test_split, GridSearchCV, cross_val_score
from sklearn.preprocessing import StandardScaler, OneHotEncoder, LabelEncoder, OrdinalEncoder, MinMaxScaler, RobustScaler, MaxAbsScaler
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.decomposition import PCA
from sklearn.utils.class_weight import compute_class_weight

from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt

from xgboost import XGBClassifier, XGBRegressor
import xgboost as xgb
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\compat.py:31: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
features_num = [
    'Total_flux', 'Peak_flux', 
       'NUV_flux_corr', 'u_flux_corr', 'Bw_flux_corr', 'R_flux_corr',
       'I_flux_corr', 'z_flux_corr', 'y_flux_corr',
       'J_flux_corr', 'H_flux_corr', 'K_flux_corr', 'Ks_flux_corr',
       'ch1_flux_corr', 'ch2_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr',
       'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350',
       'F_SPIRE_500', 'Z_BEST', 'r_rcs_flux_corr',
       'g_flux_corr', 'nb921_hsc_flux_corr'
    ]
y_column = "Classification"

classes = ['jet-mode radio AGN/low-excitation radio galaxy', 'quasar-like radio AGN / high-excitation radio galaxy', 
           'radio-quiet AGN', 'star-forming galaxy']

# %%
data = pd.read_csv("../../../Data/Fangyou_data/Cleaned/combined_using_similar_columns.csv")

# %%
X = data[features_num]
y = data[y_column]

# %%
le = LabelEncoder()
labels = np.unique(y.astype(str))
y = le.fit_transform(y)

# %% [markdown]
# ## BH data

# %%
Best_Heckman_data = pd.read_csv("../../../Data/Best&Heckman/BestHeckman+SDSS+wise+LOFAR.csv")

# %%
# Only selecting data with a classification
Best_Heckman_data = Best_Heckman_data[Best_Heckman_data['Classification'] != 'Radio-loud AGN']

# %%
Best_Heckman_X = Best_Heckman_data[[c for c in Best_Heckman_data.columns if c != 'Classification']]
Best_Heckman_y = Best_Heckman_data['Classification']

# %%
Best_Heckman_y = le.transform(Best_Heckman_y)

# %%
y = np.append(y, Best_Heckman_y)

# %%
Best_Heckman_X = Best_Heckman_X[['Z_BEST', 'u_flux_corr',
       'g_flux_corr', 'R_flux_corr', 'I_flux_corr', 'z_flux_corr', 'ch1_flux_corr', 'ch2_flux_corr',
       'J_flux_corr', 'H_flux_corr', 'Ks_flux_corr', 'Peak_flux', 'Total_flux']]

# Copying R column
Best_Heckman_X['r_rcs_flux_corr'] = Best_Heckman_X['R_flux_corr']

# Adding nans to missing columns
Best_Heckman_X[['NUV_flux_corr', 'Bw_flux_corr', 'y_flux_corr', 'K_flux_corr', 
                'F_MIPS_24', 'F_PACS_100', 'F_PACS_160', 'F_SPIRE_250', 'F_SPIRE_350',
                'F_SPIRE_500', 'nb921_hsc_flux_corr', 'ch3_flux_corr', 'ch4_flux_corr']] = np.nan

# %%
X = pd.concat([X, Best_Heckman_X]).reset_index(drop=True)

# %%
# Creating new features
columns = X.columns
for i in range(len(columns)):
    if columns[i]!='Z_BEST':
        for j in range(i+1, len(columns)):
            if columns[j]!='Z_BEST':
                X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
                X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# Out:
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# ...
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:7: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}/{columns[j]}"] = X[columns[i]]/X[columns[j]]
# C:\Users\jespe\AppData\Local\Temp\ipykernel_10476\2770299810.py:8: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   X[f"{columns[i]}-{columns[j]}"] = X[columns[i]]-X[columns[j]]

# %% [markdown]
# ## Running the model

# %%
# Creating training and testing set
X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)
X_test, X_val, y_test, y_val = train_test_split(X_test, y_test, train_size=0.8, stratify=y_test, random_state=42)

from sklearn.utils import class_weight
classes_weights = class_weight.compute_sample_weight(
    class_weight='balanced',
    y=y_train
)

# %%
model = XGBClassifier(use_label_encoder=False, 
                      max_depth=12, 
                      #reg_alpha=1,   
                      #min_child_weight=0.5, 
                      #reg_lambda=5,
                      #subsample=0.5,
                      eta=0.3, # Remember to reduce to 0.1 or 0.05 for better results
                      tree_method='gpu_hist', # exact is more precies, but this is much faster
                      gpu_id=0,
                      objective='multi:softprob',
                      eval_metric =['merror'],
                      nthread=8,
                      n_estimators=10000,
                      )

# %%
bst = model.fit(X_train, y_train, 
                eval_set=[
                    (X_val, y_val)
                ], 
                early_stopping_rounds=100,
                verbose=True, 
                sample_weight=classes_weights,
               ) #
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [0]	validation_0-merror:0.15918
# [1]	validation_0-merror:0.14266
# [2]	validation_0-merror:0.13550
# [3]	validation_0-merror:0.13275
# [4]	validation_0-merror:0.12806
# [5]	validation_0-merror:0.12669
# [6]	validation_0-merror:0.12173
# [7]	validation_0-merror:0.11787
# [8]	validation_0-merror:0.11292
# [9]	validation_0-merror:0.11347
# [10]	validation_0-merror:0.11209
# [11]	validation_0-merror:0.10934
# [12]	validation_0-merror:0.10741
# [13]	validation_0-merror:0.10796
# [14]	validation_0-merror:0.10741
# [15]	validation_0-merror:0.10548
# [16]	validation_0-merror:0.10493
# [17]	validation_0-merror:0.10218
# [18]	validation_0-merror:0.10107
# [19]	validation_0-merror:0.10052
# [20]	validation_0-merror:0.09915
# [21]	validation_0-merror:0.09887
# [22]	validation_0-merror:0.09804
# [23]	validation_0-merror:0.09749
# [24]	validation_0-merror:0.09832
# [25]	validation_0-merror:0.09887
# [26]	validation_0-merror:0.09887
# [27]	validation_0-merror:0.09915
# [28]	validation_0-merror:0.09887
# [29]	validation_0-merror:0.09860
# [30]	validation_0-merror:0.09749
# [31]	validation_0-merror:0.09887
# [32]	validation_0-merror:0.09832
# [33]	validation_0-merror:0.09832
# [34]	validation_0-merror:0.09942
# [35]	validation_0-merror:0.09832
# [36]	validation_0-merror:0.09887
# [37]	validation_0-merror:0.09915
# [38]	validation_0-merror:0.09915
# [39]	validation_0-merror:0.09777
# [40]	validation_0-merror:0.09749
# [41]	validation_0-merror:0.09722
# [42]	validation_0-merror:0.09667
# [43]	validation_0-merror:0.09694
# [44]	validation_0-merror:0.09694
# [45]	validation_0-merror:0.09694
# [46]	validation_0-merror:0.09667
# [47]	validation_0-merror:0.09584
# [48]	validation_0-merror:0.09557
# [49]	validation_0-merror:0.09502
# [50]	validation_0-merror:0.09502
# [51]	validation_0-merror:0.09529
# [52]	validation_0-merror:0.09529
# [53]	validation_0-merror:0.09584
# [54]	validation_0-merror:0.09474
# [55]	validation_0-merror:0.09502
# [56]	validation_0-merror:0.09612
# [57]	validation_0-merror:0.09446
# [58]	validation_0-merror:0.09612
# [59]	validation_0-merror:0.09502
# [60]	validation_0-merror:0.09474
# [61]	validation_0-merror:0.09446
# [62]	validation_0-merror:0.09446
# [63]	validation_0-merror:0.09446
# [64]	validation_0-merror:0.09474
# [65]	validation_0-merror:0.09474
# [66]	validation_0-merror:0.09474
# [67]	validation_0-merror:0.09474
# [68]	validation_0-merror:0.09502
# [69]	validation_0-merror:0.09502
# [70]	validation_0-merror:0.09502
# [71]	validation_0-merror:0.09529
# [72]	validation_0-merror:0.09502
# [73]	validation_0-merror:0.09474
# [74]	validation_0-merror:0.09474
# [75]	validation_0-merror:0.09419
# [76]	validation_0-merror:0.09364
# [77]	validation_0-merror:0.09336
# [78]	validation_0-merror:0.09336
# [79]	validation_0-merror:0.09309
# [80]	validation_0-merror:0.09309
# [81]	validation_0-merror:0.09336
# [82]	validation_0-merror:0.09391
# [83]	validation_0-merror:0.09419
# [84]	validation_0-merror:0.09474
# [85]	validation_0-merror:0.09474
# [86]	validation_0-merror:0.09446
# [87]	validation_0-merror:0.09419
# [88]	validation_0-merror:0.09446
# [89]	validation_0-merror:0.09419
# [90]	validation_0-merror:0.09391
# [91]	validation_0-merror:0.09336
# [92]	validation_0-merror:0.09254
# [93]	validation_0-merror:0.09254
# [94]	validation_0-merror:0.09336
# [95]	validation_0-merror:0.09391
# [96]	validation_0-merror:0.09474
# [97]	validation_0-merror:0.09364
# [98]	validation_0-merror:0.09309
# [99]	validation_0-merror:0.09391
# [100]	validation_0-merror:0.09364
# [101]	validation_0-merror:0.09281
# [102]	validation_0-merror:0.09281
# [103]	validation_0-merror:0.09309
# [104]	validation_0-merror:0.09336
# [105]	validation_0-merror:0.09281
# [106]	validation_0-merror:0.09364
# [107]	validation_0-merror:0.09336
# [108]	validation_0-merror:0.09281
# [109]	validation_0-merror:0.09309
# [110]	validation_0-merror:0.09281
# [111]	validation_0-merror:0.09281
# [112]	validation_0-merror:0.09254
# [113]	validation_0-merror:0.09254
# [114]	validation_0-merror:0.09309
# [115]	validation_0-merror:0.09309
# [116]	validation_0-merror:0.09281
# [117]	validation_0-merror:0.09281
# [118]	validation_0-merror:0.09254
# [119]	validation_0-merror:0.09226
# [120]	validation_0-merror:0.09336
# [121]	validation_0-merror:0.09391
# [122]	validation_0-merror:0.09419
# [123]	validation_0-merror:0.09364
# [124]	validation_0-merror:0.09336
# [125]	validation_0-merror:0.09336
# [126]	validation_0-merror:0.09309
# [127]	validation_0-merror:0.09281
# [128]	validation_0-merror:0.09309
# [129]	validation_0-merror:0.09226
# [130]	validation_0-merror:0.09171
# [131]	validation_0-merror:0.09144
# [132]	validation_0-merror:0.09144
# [133]	validation_0-merror:0.09144
# [134]	validation_0-merror:0.09171
# [135]	validation_0-merror:0.09199
# [136]	validation_0-merror:0.09116
# [137]	validation_0-merror:0.09309
# [138]	validation_0-merror:0.09226
# [139]	validation_0-merror:0.09254
# [140]	validation_0-merror:0.09309
# [141]	validation_0-merror:0.09254
# [142]	validation_0-merror:0.09226
# [143]	validation_0-merror:0.09254
# [144]	validation_0-merror:0.09226
# [145]	validation_0-merror:0.09199
# [146]	validation_0-merror:0.09199
# [147]	validation_0-merror:0.09199
# [148]	validation_0-merror:0.09199
# [149]	validation_0-merror:0.09171
# [150]	validation_0-merror:0.09226
# [151]	validation_0-merror:0.09199
# [152]	validation_0-merror:0.09171
# [153]	validation_0-merror:0.09171
# [154]	validation_0-merror:0.09116
# [155]	validation_0-merror:0.09116
# [156]	validation_0-merror:0.09116
# [157]	validation_0-merror:0.09088
# [158]	validation_0-merror:0.09088
# [159]	validation_0-merror:0.09116
# [160]	validation_0-merror:0.09116
# [161]	validation_0-merror:0.09144
# [162]	validation_0-merror:0.09088
# [163]	validation_0-merror:0.09088
# [164]	validation_0-merror:0.09088
# [165]	validation_0-merror:0.09116
# [166]	validation_0-merror:0.09116
# [167]	validation_0-merror:0.09116
# [168]	validation_0-merror:0.09144
# [169]	validation_0-merror:0.09144
# [170]	validation_0-merror:0.09144
# [171]	validation_0-merror:0.09144
# [172]	validation_0-merror:0.09171
# [173]	validation_0-merror:0.09144
# [174]	validation_0-merror:0.09116
# [175]	validation_0-merror:0.09144
# [176]	validation_0-merror:0.09144
# [177]	validation_0-merror:0.09116
# [178]	validation_0-merror:0.09144
# [179]	validation_0-merror:0.09144
# [180]	validation_0-merror:0.09171
# [181]	validation_0-merror:0.09144
# [182]	validation_0-merror:0.09144
# [183]	validation_0-merror:0.09144
# [184]	validation_0-merror:0.09144
# [185]	validation_0-merror:0.09144
# [186]	validation_0-merror:0.09116
# [187]	validation_0-merror:0.09171
# [188]	validation_0-merror:0.09144
# [189]	validation_0-merror:0.09171
# [190]	validation_0-merror:0.09199
# [191]	validation_0-merror:0.09199
# [192]	validation_0-merror:0.09226
# [193]	validation_0-merror:0.09254
# [194]	validation_0-merror:0.09226
# [195]	validation_0-merror:0.09226
# [196]	validation_0-merror:0.09199
# [197]	validation_0-merror:0.09199
# [198]	validation_0-merror:0.09226
# [199]	validation_0-merror:0.09199
# [200]	validation_0-merror:0.09226
# [201]	validation_0-merror:0.09226
# [202]	validation_0-merror:0.09226
# [203]	validation_0-merror:0.09226
# [204]	validation_0-merror:0.09281
# [205]	validation_0-merror:0.09281
# [206]	validation_0-merror:0.09281
# [207]	validation_0-merror:0.09281
# [208]	validation_0-merror:0.09254
# [209]	validation_0-merror:0.09281
# [210]	validation_0-merror:0.09254
# [211]	validation_0-merror:0.09199
# [212]	validation_0-merror:0.09199
# [213]	validation_0-merror:0.09254
# [214]	validation_0-merror:0.09226
# [215]	validation_0-merror:0.09199
# [216]	validation_0-merror:0.09199
# [217]	validation_0-merror:0.09199
# [218]	validation_0-merror:0.09199
# [219]	validation_0-merror:0.09199
# [220]	validation_0-merror:0.09171
# [221]	validation_0-merror:0.09171
# [222]	validation_0-merror:0.09171
# [223]	validation_0-merror:0.09171
# [224]	validation_0-merror:0.09171
# [225]	validation_0-merror:0.09199
# [226]	validation_0-merror:0.09226
# [227]	validation_0-merror:0.09226
# [228]	validation_0-merror:0.09226
# [229]	validation_0-merror:0.09199
# [230]	validation_0-merror:0.09199
# [231]	validation_0-merror:0.09171
# [232]	validation_0-merror:0.09199
# [233]	validation_0-merror:0.09199
# [234]	validation_0-merror:0.09226
# [235]	validation_0-merror:0.09226
# [236]	validation_0-merror:0.09254
# [237]	validation_0-merror:0.09254
# [238]	validation_0-merror:0.09199
# [239]	validation_0-merror:0.09226
# [240]	validation_0-merror:0.09226
# [241]	validation_0-merror:0.09199
# [242]	validation_0-merror:0.09199
# [243]	validation_0-merror:0.09199
# [244]	validation_0-merror:0.09199
# [245]	validation_0-merror:0.09171
# [246]	validation_0-merror:0.09199
# [247]	validation_0-merror:0.09226
# [248]	validation_0-merror:0.09226
# [249]	validation_0-merror:0.09226
# [250]	validation_0-merror:0.09226
# [251]	validation_0-merror:0.09226
# [252]	validation_0-merror:0.09199
# [253]	validation_0-merror:0.09254
# [254]	validation_0-merror:0.09199
# [255]	validation_0-merror:0.09226
# [256]	validation_0-merror:0.09226
# [257]	validation_0-merror:0.09226

# %%
y_pred = model.predict(X_test)
print(classification_report(y_test, y_pred, target_names=labels, digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.9053    0.8882    0.8967      3606
# quasar-like radio AGN / high-excitation radio galaxy     0.6096    0.4793    0.5367       290
#                                      radio-quiet AGN     0.7875    0.7589    0.7729      1099
#                                  star-forming galaxy     0.9364    0.9531    0.9447      9529
#
#                                             accuracy                         0.9128     14524
#                                            macro avg     0.8097    0.7699    0.7877     14524
#                                         weighted avg     0.9109    0.9128    0.9116     14524

# %% [markdown]
# ### Accuracy report per data set

# %% [markdown]
# #### Original

# %%
y_pred = model.predict(X_test[X_test.index<77609])
print(classification_report(y_test[X_test.index<77609], y_pred, target_names=labels, digits=4))
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.8713    0.8271    0.8486      2013
# quasar-like radio AGN / high-excitation radio galaxy     0.6190    0.5253    0.5683       198
#                                      radio-quiet AGN     0.7875    0.7589    0.7729      1099
#                                  star-forming galaxy     0.9382    0.9561    0.9471      9057
#
#                                             accuracy                         0.9106     12367
#                                            macro avg     0.8040    0.7668    0.7842     12367
#                                         weighted avg     0.9088    0.9106    0.9095     12367

# %% [markdown]
# #### B&H

# %%
y_pred = model.predict(X_test[X_test.index>=77609])
print(classification_report(y_test[X_test.index>=77609], y_pred, target_names=labels[[0,1,3]], digits=4))
# Out:
#                                                       precision    recall  f1-score   support
#
#       jet-mode radio AGN/low-excitation radio galaxy     0.9453    0.9655    0.9553      1593
# quasar-like radio AGN / high-excitation radio galaxy     0.5833    0.3804    0.4605        92
#                                  star-forming galaxy     0.9000    0.8962    0.8981       472
#
#                                             accuracy                         0.9254      2157
#                                            macro avg     0.8095    0.7474    0.7713      2157
#                                         weighted avg     0.9199    0.9254    0.9217      2157
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\xgboost\data.py:192: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %% [markdown]
# ### Bayesian optimisation

# %%
from bayes_opt import BayesianOptimization

# %%
def optimise_xgboost(max_depth):
    max_depth = int(max_depth)
    
    model = XGBClassifier(use_label_encoder=False, 
                      max_depth=6, 
                      #reg_alpha=reg_alpha,   
                      #min_child_weight=min_child_weight, 
                      #reg_lambda=reg_lambda,
                      eta=0.1, # Remember to reduce to 0.1 or 0.05 for better results
                      tree_method='gpu_hist', # exact is more precies, but this is much faster
                      gpu_id=0,
                      objective='multi:softprob',
                      eval_metric =['merror'],
                      nthread=8,
                      n_estimators=10000,
                      )
    bst = model.fit(X_train, y_train, 
                eval_set=[
                    (X_val, y_val)
                ], 
                early_stopping_rounds=250,
                verbose=False, 
                sample_weight=classes_weights,
               )
    y_pred = model.predict(X_val)
    return accuracy_score(y_val, y_pred)

# %%
# Bounded region of parameter space
pbounds = {
    'max_depth': (5, 30),
    #'reg_alpha': (0, 5),
    #'reg_lambda': (0, 10),
    #'#min_child_weight': (0, 5),
}

# %%
optimizer = BayesianOptimization(
    f=optimise_xgboost,
    pbounds=pbounds,
    verbose=2, # verbose = 1 prints only when a maximum is observed, verbose = 0 is silent
    random_state=42,
)

# %%
with warnings.catch_warnings():
    warnings.simplefilter("ignore")
    optimizer.maximize(
        init_points=5,
        n_iter=100,
    )
# Out:
# |   iter    |  target   | max_depth |
# -------------------------------------
# |  1        |  0.8967   |  14.36    |
# |  2        |  0.8992   |  28.77    |
# |  3        |  0.8998   |  23.3     |
# |  4        |  0.9009   |  19.97    |
# |  5        |  0.8978   |  8.9      |
# |  6        |  0.8995   |  18.29    |
# |  7        |  0.8998   |  5.0      |
# |  8        |  0.8984   |  21.32    |
# |  9        |  0.9009   |  5.0      |
# |  10       |  0.8995   |  9.548    |
# |  11       |  0.8953   |  19.97    |
# |  12       |  0.9011   |  19.97    |
# |  13       |  0.8992   |  19.97    |
# |  14       |  0.9009   |  18.29    |
# KeyboardInterrupt

# %% [markdown]
# ### Automl

# %%
from flaml import AutoML
automl = AutoML()
# Out:
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\searcher\blendsearch.py:14: DeprecationWarning: The module `ray.tune.suggest` has been moved to `ray.tune.search` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest` with `ray.tune.search`.
#   from ray.tune.suggest import Searcher
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\searcher\blendsearch.py:15: DeprecationWarning: The module `ray.tune.suggest.optuna` has been moved to `ray.tune.search.optuna` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.optuna` with `ray.tune.search.optuna`.
#   from ray.tune.suggest.optuna import OptunaSearch as GlobalSearch
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\tune\sample.py:39: DeprecationWarning: The module `ray.tune.sample` has been moved to `ray.tune.search.sample` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.sample` with `ray.tune.search.sample`.
#   from ray.tune.sample import _BackwardsCompatibleNumpyRng
# C:\Users\jespe\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\tune\space.py:6: DeprecationWarning: The module `ray.tune.suggest.variant_generator` has been moved to `ray.tune.search.variant_generator` and the old location will be deprecated soon. Please adjust your imports to point to the new location. Example: Do a global search and replace `ray.tune.suggest.variant_generator` with `ray.tune.search.variant_generator`.
#   from ray.tune.suggest.variant_generator import generate_variants

# %%
import warnings

X_train, X_test, y_train, y_test = train_test_split(X, y, train_size=0.8, stratify=y, random_state=42)

estimators = ['xgb_limitdepth']
#estimators = ['extra_tree']

with warnings.catch_warnings():
    warnings.simplefilter("ignore")

    automl.fit(X_train, y_train, task="classification", metric='accuracy',
                                #X_val=X_val , y_val=y_val,
                                #ensemble=True,
                                #estimator_list=estimators, 
                                time_budget=7200, n_jobs=8,
                                eval_method='cv',
                                #log_file_name='general_extra_features3.log',
                                #starting_points=automl.best_config_per_estimator
              )
# Out:
# [flaml.automl: 10-03 12:51:03] {2390} INFO - task = classification
# [flaml.automl: 10-03 12:51:03] {2392} INFO - Data split method: stratified
# [flaml.automl: 10-03 12:51:03] {2396} INFO - Evaluation method: cv
# [flaml.automl: 10-03 12:51:03] {2465} INFO - Minimizing error metric: 1-accuracy
# [flaml.automl: 10-03 12:51:05] {2605} INFO - List of ML learners in AutoML Run: ['lgbm', 'rf', 'catboost', 'xgboost', 'extra_tree', 'xgb_limitdepth', 'lrl1']
# [flaml.automl: 10-03 12:51:05] {2897} INFO - iteration 0, current learner lgbm
# [flaml.automl: 10-03 12:51:29] {3025} INFO - Estimated sufficient time budget=246296s. Estimated necessary time budget=6047s.
# [flaml.automl: 10-03 12:51:29] {3072} INFO -  at 246.2s,	estimator lgbm's best error=0.2256,	best estimator lgbm's best error=0.2256
# [flaml.automl: 10-03 12:51:29] {2897} INFO - iteration 1, current learner lgbm
# [flaml.automl: 10-03 12:51:57] {3072} INFO -  at 273.6s,	estimator lgbm's best error=0.2256,	best estimator lgbm's best error=0.2256
# [flaml.automl: 10-03 12:51:57] {2897} INFO - iteration 2, current learner lgbm
# [flaml.automl: 10-03 12:52:20] {3072} INFO -  at 297.4s,	estimator lgbm's best error=0.1612,	best estimator lgbm's best error=0.1612
# [flaml.automl: 10-03 12:52:20] {2897} INFO - iteration 3, current learner xgboost
# [flaml.automl: 10-03 12:52:56] {3072} INFO -  at 332.6s,	estimator xgboost's best error=0.1815,	best estimator lgbm's best error=0.1612
# [flaml.automl: 10-03 12:52:56] {2897} INFO - iteration 4, current learner lgbm
# [flaml.automl: 10-03 12:53:27] {3072} INFO -  at 364.4s,	estimator lgbm's best error=0.1365,	best estimator lgbm's best error=0.1365
# [flaml.automl: 10-03 12:53:27] {2897} INFO - iteration 5, current learner lgbm
# [flaml.automl: 10-03 12:53:51] {3072} INFO -  at 387.6s,	estimator lgbm's best error=0.1365,	best estimator lgbm's best error=0.1365
# [flaml.automl: 10-03 12:53:51] {2897} INFO - iteration 6, current learner lgbm
# [flaml.automl: 10-03 12:54:20] {3072} INFO -  at 416.9s,	estimator lgbm's best error=0.1365,	best estimator lgbm's best error=0.1365
# [flaml.automl: 10-03 12:54:20] {2897} INFO - iteration 7, current learner lgbm
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [19], in <cell line: 8>()
#       8 with warnings.catch_warnings():
#       9     warnings.simplefilter("ignore")
# ---> 11     automl.fit(X_train, y_train, task="classification", metric='accuracy',
#      12                                 #X_val=X_val , y_val=y_val,
#      13                                 #ensemble=True,
#      14                                 #estimator_list=estimators,
#      15                                 time_budget=7200, n_jobs=8,
#      16                                 eval_method='cv',
#      17                                 #log_file_name='general_extra_features3.log',
#      18                                 #starting_points=automl.best_config_per_estimator
#      19               )
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\automl.py:2634, in AutoML.fit(self, X_train, y_train, dataframe, label, metric, task, n_jobs, log_file_name, estimator_list, time_budget, max_iter, sample, ensemble, eval_method, log_type, model_history, split_ratio, n_splits, log_training_metric, mem_thres, pred_time_limit, train_time_limit, X_val, y_val, sample_weight_val, groups_val, groups, verbose, retrain_full, split_type, learner_selector, hpo_method, starting_points, seed, n_concurrent_trials, keep_search_state, early_stop, append_log, auto_augment, min_sample_size, use_ray, metric_constraints, custom_hp, fit_kwargs_by_estimator, **fit_kwargs)
#    2632 else:
#    2633     self._training_log = None
# -> 2634     self._search()
#    2635 if self._best_estimator:
#    2636     logger.info("fit succeeded")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\automl.py:3180, in AutoML._search(self)
#    3174     state.best_config = (
#    3175         state.init_config
#    3176         if isinstance(state.init_config, dict)
#    3177         else state.init_config[0]
#    3178     )
#    3179 elif self._use_ray is False:
# -> 3180     self._search_sequential()
#    3181 else:
#    3182     self._search_parallel()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\automl.py:2998, in AutoML._search_sequential(self)
#    2992         search_state.search_alg.searcher.set_search_properties(
#    2993             metric=None,
#    2994             mode=None,
#    2995             metric_target=self._state.best_loss,
#    2996         )
#    2997 start_run_time = time.time()
# -> 2998 analysis = tune.run(
#    2999     search_state.training_function,
#    3000     search_alg=search_state.search_alg,
#    3001     time_budget_s=min(budget_left, self._state.train_time_limit),
#    3002     verbose=max(self.verbose - 3, 0),
#    3003     use_ray=False,
#    3004 )
#    3005 time_used = time.time() - start_run_time
#    3006 better = False
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\tune\tune.py:507, in run(evaluation_function, config, low_cost_partial_config, cat_hp_cost, metric, mode, time_budget_s, points_to_evaluate, evaluated_rewards, resource_attr, min_resource, max_resource, reduction_factor, scheduler, search_alg, verbose, local_dir, num_samples, resources_per_trial, config_constraints, metric_constraints, max_failure, use_ray, use_incumbent_result_in_evaluation, **ray_args)
#     505 if verbose:
#     506     logger.info(f"trial {num_trials} config: {trial_to_run.config}")
# --> 507 result = evaluation_function(trial_to_run.config)
#     508 if result is not None:
#     509     if isinstance(result, dict):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\automl.py:351, in AutoMLState._compute_with_config_base(config_w_resource, state, estimator)
#     333     del config["FLAML_sample_size"]
#     334 budget = (
#     335     None
#     336     if state.time_budget is None
#    (...)
#     342     / state.data_size[0]
#     343 )
#     345 (
#     346     trained_estimator,
#     347     val_loss,
#     348     metric_for_logging,
#     349     _,
#     350     pred_time,
# --> 351 ) = compute_estimator(
#     352     sampled_X_train,
#     353     sampled_y_train,
#     354     state.X_val,
#     355     state.y_val,
#     356     state.weight_val,
#     357     state.groups_val,
#     358     state.train_time_limit
#     359     if budget is None
#     360     else min(budget, state.train_time_limit),
#     361     state.kf,
#     362     config,
#     363     state.task,
#     364     estimator,
#     365     state.eval_method,
#     366     state.metric,
#     367     state.best_loss,
#     368     state.n_jobs,
#     369     state.learner_classes.get(estimator),
#     370     state.log_training_metric,
#     371     this_estimator_kwargs,
#     372 )
#     373 if state.retrain_final and not state.model_history:
#     374     trained_estimator.cleanup()
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\ml.py:615, in compute_estimator(X_train, y_train, X_val, y_val, weight_val, groups_val, budget, kf, config_dic, task, estimator_name, eval_method, eval_metric, best_val_loss, n_jobs, estimator_class, log_training_metric, fit_kwargs)
#     596     val_loss, metric_for_logging, train_time, pred_time = get_val_loss(
#     597         config_dic,
#     598         estimator,
#    (...)
#     612         fit_kwargs=fit_kwargs,
#     613     )
#     614 else:
# --> 615     val_loss, metric_for_logging, train_time, pred_time = evaluate_model_CV(
#     616         config_dic,
#     617         estimator,
#     618         X_train,
#     619         y_train,
#     620         budget,
#     621         kf,
#     622         task,
#     623         eval_metric,
#     624         best_val_loss,
#     625         log_training_metric=log_training_metric,
#     626         fit_kwargs=fit_kwargs,
#     627     )
#     629 if isinstance(estimator, TransformersEstimator):
#     630     del fit_kwargs["metric"], fit_kwargs["X_val"], fit_kwargs["y_val"]
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\ml.py:516, in evaluate_model_CV(config, estimator, X_train_all, y_train_all, budget, kf, task, eval_metric, best_val_loss, log_training_metric, fit_kwargs)
#     514 else:
#     515     groups_val = None
# --> 516 val_loss_i, metric_i, train_time_i, pred_time_i = get_val_loss(
#     517     config,
#     518     estimator,
#     519     X_train,
#     520     y_train,
#     521     X_val,
#     522     y_val,
#     523     weight_val,
#     524     groups_val,
#     525     eval_metric,
#     526     task,
#     527     labels,
#     528     budget_per_train,
#     529     log_training_metric=log_training_metric,
#     530     fit_kwargs=fit_kwargs,
#     531 )
#     532 if weight is not None:
#     533     fit_kwargs["sample_weight"] = weight
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\ml.py:427, in get_val_loss(config, estimator, X_train, y_train, X_val, y_val, weight_val, groups_val, eval_metric, obj, labels, budget, log_training_metric, fit_kwargs)
#     422 start = time.time()
#     423 # if groups_val is not None:
#     424 #     fit_kwargs['groups_val'] = groups_val
#     425 #     fit_kwargs['X_val'] = X_val
#     426 #     fit_kwargs['y_val'] = y_val
# --> 427 estimator.fit(X_train, y_train, budget, **fit_kwargs)
#     428 val_loss, metric_for_logging, pred_time, _ = _eval_estimator(
#     429     config,
#     430     estimator,
#    (...)
#     441     fit_kwargs,
#     442 )
#     443 if hasattr(estimator, "intermediate_results"):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\model.py:1114, in LGBMEstimator.fit(self, X_train, y_train, budget, **kwargs)
#    1112 else:
#    1113     callbacks = self._callbacks(start_time, deadline)
# -> 1114 self._fit(
#    1115     X_train,
#    1116     y_train,
#    1117     callbacks=callbacks,
#    1118     **kwargs,
#    1119 )
#    1120 best_iteration = (
#    1121     self._model.get_booster().best_iteration
#    1122     if isinstance(self, XGBoostSklearnEstimator)
#    1123     else self._model.best_iteration_
#    1124 )
#    1125 if best_iteration is not None:
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\flaml\model.py:159, in BaseEstimator._fit(self, X_train, y_train, **kwargs)
#     157 if logger.level == logging.DEBUG:
#     158     logger.debug(f"flaml.model - {model} fit started")
# --> 159 model.fit(X_train, y_train, **kwargs)
#     160 if logger.level == logging.DEBUG:
#     161     logger.debug(f"flaml.model - {model} fit finished")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\sklearn.py:967, in LGBMClassifier.fit(self, X, y, sample_weight, init_score, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     964         else:
#     965             valid_sets[i] = (valid_x, self._le.transform(valid_y))
# --> 967 super().fit(X, _y, sample_weight=sample_weight, init_score=init_score, eval_set=valid_sets,
#     968             eval_names=eval_names, eval_sample_weight=eval_sample_weight,
#     969             eval_class_weight=eval_class_weight, eval_init_score=eval_init_score,
#     970             eval_metric=eval_metric, early_stopping_rounds=early_stopping_rounds,
#     971             verbose=verbose, feature_name=feature_name, categorical_feature=categorical_feature,
#     972             callbacks=callbacks, init_model=init_model)
#     973 return self
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\sklearn.py:748, in LGBMModel.fit(self, X, y, sample_weight, init_score, group, eval_set, eval_names, eval_sample_weight, eval_class_weight, eval_init_score, eval_group, eval_metric, early_stopping_rounds, verbose, feature_name, categorical_feature, callbacks, init_model)
#     745 evals_result = {}
#     746 callbacks.append(record_evaluation(evals_result))
# --> 748 self._Booster = train(
#     749     params=params,
#     750     train_set=train_set,
#     751     num_boost_round=self.n_estimators,
#     752     valid_sets=valid_sets,
#     753     valid_names=eval_names,
#     754     fobj=self._fobj,
#     755     feval=eval_metrics_callable,
#     756     init_model=init_model,
#     757     feature_name=feature_name,
#     758     callbacks=callbacks
#     759 )
#     761 if evals_result:
#     762     self._evals_result = evals_result
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\engine.py:271, in train(params, train_set, num_boost_round, valid_sets, valid_names, fobj, feval, init_model, feature_name, categorical_feature, early_stopping_rounds, evals_result, verbose_eval, learning_rates, keep_training_booster, callbacks)
#     269 # construct booster
#     270 try:
# --> 271     booster = Booster(params=params, train_set=train_set)
#     272     if is_valid_contain_train:
#     273         booster.set_train_data_name(train_data_name)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py:2605, in Booster.__init__(self, params, train_set, model_file, model_str, silent)
#    2598     self.set_network(
#    2599         machines=machines,
#    2600         local_listen_port=params["local_listen_port"],
#    2601         listen_time_out=params.get("time_out", 120),
#    2602         num_machines=params["num_machines"]
#    2603     )
#    2604 # construct booster object
# -> 2605 train_set.construct()
#    2606 # copy the parameters from train_set
#    2607 params.update(train_set.get_params())
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py:1815, in Dataset.construct(self)
#    1812             self._set_init_score_by_predictor(self._predictor, self.data, used_indices)
#    1813 else:
#    1814     # create train
# -> 1815     self._lazy_init(self.data, label=self.label,
#    1816                     weight=self.weight, group=self.group,
#    1817                     init_score=self.init_score, predictor=self._predictor,
#    1818                     silent=self.silent, feature_name=self.feature_name,
#    1819                     categorical_feature=self.categorical_feature, params=self.params)
#    1820 if self.free_raw_data:
#    1821     self.data = None
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py:1538, in Dataset._lazy_init(self, data, label, reference, weight, group, init_score, predictor, silent, feature_name, categorical_feature, params)
#    1536     self.__init_from_csc(data, params_str, ref_dataset)
#    1537 elif isinstance(data, np.ndarray):
# -> 1538     self.__init_from_np2d(data, params_str, ref_dataset)
#    1539 elif isinstance(data, list) and len(data) > 0:
#    1540     if all(isinstance(x, np.ndarray) for x in data):
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.9_qbz5n2kfra8p0\LocalCache\local-packages\Python39\site-packages\lightgbm\basic.py:1659, in Dataset.__init_from_np2d(self, mat, params_str, ref_dataset)
#    1656     data = np.array(mat.reshape(mat.size), dtype=np.float32)
#    1658 ptr_data, type_ptr_data, _ = c_float_array(data)
# -> 1659 _safe_call(_LIB.LGBM_DatasetCreateFromMat(
#    1660     ptr_data,
#    1661     ctypes.c_int(type_ptr_data),
#    1662     ctypes.c_int32(mat.shape[0]),
#    1663     ctypes.c_int32(mat.shape[1]),
#    1664     ctypes.c_int(C_API_IS_ROW_MAJOR),
#    1665     c_str(params_str),
#    1666     ref_dataset,
#    1667     ctypes.byref(self.handle)))
#    1668 return self
#
# KeyboardInterrupt:
